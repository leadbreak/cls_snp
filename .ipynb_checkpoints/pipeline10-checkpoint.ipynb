# %% [markdown]
# # CONCEPT
#
# 0. trait 관련 변수 제외
# 1. A분류/B분류/C분류
# 2. B&C분류 : 'AUTO' / 1,000 / 1,200&1,000
#
# - 총 열두 개(Classifier&Regressor)의 모델 성능을 복합적으로 고려

# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import gc
import math
import random
import pickle
import pandas as pd
import numpy as np
import multiprocessing
from tqdm.auto import tqdm

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler

from transformers import get_cosine_schedule_with_warmup

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset, sampler

from imblearn.over_sampling import SMOTE

# %%
device = torch.device('cuda:1') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda', index=1)

# %%
train = pd.read_csv('./data/df_train00.csv')
test = pd.read_csv('./data/df_test00.csv')

# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import gc
import math
import random
import pickle
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split, StratifiedKFold

from xgboost import XGBClassifier, XGBRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from imblearn.over_sampling import SMOTE, SMOTENC

# %%
random_seed = 6327
strategy = {0:1000, 1:1000}
# strategy = 'auto'

# %%
train['class'].value_counts()
# Out:
# 1    114
# 2     79
# 0     69
# Name: class, dtype: int64

# %%
ae = pd.read_csv("./data/ae_values.csv")
# target_idx = train[train['class'] != 0].index.tolist()
train2 = train.copy().reset_index(drop=True)
# train2['class'] = train2['class'] -1

train2 = pd.concat([train2, ae[:len(train2)]], axis=1)
test2 = pd.concat([test, ae[len(train2):].reset_index(drop=True)], axis=1)
train2['class'].value_counts()
# Out:
# 1    114
# 2     79
# 0     69
# Name: class, dtype: int64

# %% [markdown]
# # STEP 01
# - 각 레이블 독립적으로 구분하는 모델

# %%
y1 = (train2['class'].values == 0).astype(int)
y2 = (train2['class'].values == 1).astype(int)
y3 = (train2['class'].values == 2).astype(int)

X = train2.drop(['id', 'class', 'trait', 'trait_ratio'], axis=1)
X.iloc[:,:15] = X.iloc[:,:15].astype('category')


X_test = test2.drop(['id', 'class', 'trait', 'trait_ratio'], axis=1)
X_test.iloc[:,:15] = X_test.iloc[:,:15].astype('category')

smote = SMOTENC(categorical_features=[x for x in range(15)], random_state=random_seed, sampling_strategy=strategy)
X_train1, y_train1 = smote.fit_resample(X, y1)
X_train2, y_train2 = smote.fit_resample(X, y2)
X_train3, y_train3 = smote.fit_resample(X, y3)

X_train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 38 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SNP_01        2000 non-null   category
#  1   SNP_02        2000 non-null   category
#  2   SNP_03        2000 non-null   category
#  3   SNP_04        2000 non-null   category
#  4   SNP_05        2000 non-null   category
#  5   SNP_06        2000 non-null   category
#  6   SNP_07        2000 non-null   category
#  7   SNP_08        2000 non-null   category
#  8   SNP_09        2000 non-null   category
#  9   SNP_10        2000 non-null   category
#  10  SNP_11        2000 non-null   category
#  11  SNP_12        2000 non-null   category
#  12  SNP_13        2000 non-null   category
#  13  SNP_14        2000 non-null   category
#  14  SNP_15        2000 non-null   category
#  15  SNP_01_ratio  2000 non-null   float64
#  16  SNP_02_ratio  2000 non-null   float64
#  17  SNP_03_ratio  2000 non-null   float64
#  18  SNP_04_ratio  2000 non-null   float64
#  19  SNP_05_ratio  2000 non-null   float64
#  20  SNP_06_ratio  2000 non-null   float64
#  21  SNP_07_ratio  2000 non-null   float64
#  22  SNP_08_ratio  2000 non-null   float64
#  23  SNP_09_ratio  2000 non-null   float64
#  24  SNP_10_ratio  2000 non-null   float64
#  25  SNP_11_ratio  2000 non-null   float64
#  26  SNP_12_ratio  2000 non-null   float64
#  27  SNP_13_ratio  2000 non-null   float64
#  28  SNP_14_ratio  2000 non-null   float64
#  29  SNP_15_ratio  2000 non-null   float64
#  30  encodings_0   2000 non-null   float64
#  31  encodings_1   2000 non-null   float64
#  32  encodings_2   2000 non-null   float64
#  33  encodings_3   2000 non-null   float64
#  34  encodings_4   2000 non-null   float64
#  35  encodings_5   2000 non-null   float64
#  36  encodings_6   2000 non-null   float64
#  37  errors        2000 non-null   float64
# dtypes: category(15), float64(23)
# memory usage: 390.7 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 38 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SNP_01        175 non-null    category
#  1   SNP_02        175 non-null    category
#  2   SNP_03        175 non-null    category
#  3   SNP_04        175 non-null    category
#  4   SNP_05        175 non-null    category
#  5   SNP_06        175 non-null    category
#  6   SNP_07        175 non-null    category
#  7   SNP_08        175 non-null    category
#  8   SNP_09        175 non-null    category
#  9   SNP_10        175 non-null    category
#  10  SNP_11        175 non-null    category
#  11  SNP_12        175 non-null    category
#  12  SNP_13        175 non-null    category
#  13  SNP_14        175 non-null    category
#  14  SNP_15        175 non-null    category
#  15  SNP_01_ratio  175 non-null    float64
#  16  SNP_02_ratio  175 non-null    float64
#  17  SNP_03_ratio  175 non-null    float64
#  18  SNP_04_ratio  175 non-null    float64
#  19  SNP_05_ratio  175 non-null    float64
#  20  SNP_06_ratio  175 non-null    float64
#  21  SNP_07_ratio  175 non-null    float64
#  22  SNP_08_ratio  175 non-null    float64
#  23  SNP_09_ratio  175 non-null    float64
#  24  SNP_10_ratio  175 non-null    float64
#  25  SNP_11_ratio  175 non-null    float64
#  26  SNP_12_ratio  175 non-null    float64
#  27  SNP_13_ratio  175 non-null    float64
#  28  SNP_14_ratio  175 non-null    float64
#  29  SNP_15_ratio  175 non-null    float64
#  30  encodings_0   106 non-null    float64
#  31  encodings_1   106 non-null    float64
#  32  encodings_2   106 non-null    float64
#  33  encodings_3   106 non-null    float64
#  34  encodings_4   106 non-null    float64
#  35  encodings_5   106 non-null    float64
#  36  encodings_6   106 non-null    float64
#  37  errors        106 non-null    float64
# dtypes: category(15), float64(23)
# memory usage: 36.1 KB

# %%
def lgbmc(inputX, inputY) :  
    var_categ = inputX.columns.tolist()[:15]
    model = CatBoostClassifier(
        cat_features=var_categ,
        iterations=100,
        learning_rate=0.3,
        task_type='GPU',
        devices='0',
        # random_state=random_seed
        )
  
    model.fit(
        inputX, inputY,
        eval_set=(inputX, inputY),
        verbose=10
        );     

    pred = model.predict(inputX)
    score = f1_score(inputY, pred, average='macro')
    print(score)
    
    return model

# %%
def lgbmr(inputX, inputY) :  
    var_categ = inputX.columns.tolist()[:15]
    model = CatBoostRegressor(
        cat_features=var_categ,
        iterations=100,
        learning_rate=0.3,
        task_type='GPU',
        devices='5',
        # random_state=random_seed
        )
  
    model.fit(
        inputX, inputY,
        eval_set=(inputX, inputY),
        verbose=10
        );     

    pred = model.predict(inputX)
    score = f1_score(inputY, np.round(pred), average='macro')
    print(score)
    
    return model

# %%
model1_c = lgbmc(X_train1, y_train1)
model1_r = lgbmr(X_train1, y_train1)
# Out:
# 0:	learn: 0.1517713	test: 0.1517713	best: 0.1517713 (0)	total: 9.45ms	remaining: 935ms
# 10:	learn: 0.0020150	test: 0.0020150	best: 0.0020150 (10)	total: 94.2ms	remaining: 762ms
# 20:	learn: 0.0007192	test: 0.0007192	best: 0.0007192 (20)	total: 177ms	remaining: 668ms
# 30:	learn: 0.0004221	test: 0.0004221	best: 0.0004221 (30)	total: 260ms	remaining: 579ms
# 40:	learn: 0.0003002	test: 0.0003002	best: 0.0003002 (40)	total: 345ms	remaining: 497ms
# 50:	learn: 0.0002315	test: 0.0002315	best: 0.0002315 (50)	total: 430ms	remaining: 413ms
# 60:	learn: 0.0001872	test: 0.0001872	best: 0.0001872 (60)	total: 515ms	remaining: 329ms
# 70:	learn: 0.0001552	test: 0.0001552	best: 0.0001552 (70)	total: 600ms	remaining: 245ms
# 80:	learn: 0.0001329	test: 0.0001329	best: 0.0001329 (80)	total: 685ms	remaining: 161ms
# 90:	learn: 0.0001162	test: 0.0001162	best: 0.0001162 (90)	total: 769ms	remaining: 76.1ms
# 99:	learn: 0.0001053	test: 0.0001053	best: 0.0001053 (99)	total: 846ms	remaining: 0us
# bestTest = 0.0001052957624
# bestIteration = 99
# 1.0
# 0:	learn: 0.3541271	test: 0.3541270	best: 0.3541270 (0)	total: 5.29ms	remaining: 523ms
# 10:	learn: 0.0180216	test: 0.0180216	best: 0.0180216 (10)	total: 42.6ms	remaining: 344ms
# 20:	learn: 0.0077603	test: 0.0077594	best: 0.0077594 (20)	total: 81.4ms	remaining: 306ms
# 30:	learn: 0.0059132	test: 0.0059250	best: 0.0059250 (30)	total: 120ms	remaining: 268ms
# 40:	learn: 0.0049062	test: 0.0049168	best: 0.0049168 (40)	total: 159ms	remaining: 229ms
# 50:	learn: 0.0041353	test: 0.0041437	best: 0.0041437 (50)	total: 198ms	remaining: 190ms
# 60:	learn: 0.0037434	test: 0.0037511	best: 0.0037511 (60)	total: 237ms	remaining: 151ms
# 70:	learn: 0.0032298	test: 0.0032356	best: 0.0032356 (70)	total: 276ms	remaining: 113ms
# 80:	learn: 0.0029360	test: 0.0029426	best: 0.0029426 (80)	total: 315ms	remaining: 73.9ms
# 90:	learn: 0.0027114	test: 0.0027183	best: 0.0027183 (90)	total: 354ms	remaining: 35ms
# 99:	learn: 0.0025469	test: 0.0025542	best: 0.0025542 (99)	total: 388ms	remaining: 0us
# bestTest = 0.00255423597
# bestIteration = 99
# 1.0

# %%
model2_c = lgbmc(X_train2, y_train2)
model2_r = lgbmr(X_train2, y_train2)
# Out:
# 0:	learn: 0.2591650	test: 0.2591649	best: 0.2591649 (0)	total: 9.24ms	remaining: 915ms
# 10:	learn: 0.0195781	test: 0.0195660	best: 0.0195660 (10)	total: 95.8ms	remaining: 775ms
# 60:	learn: 0.0015045	test: 0.0015009	best: 0.0015009 (60)	total: 530ms	remaining: 339ms
# 70:	learn: 0.0012884	test: 0.0012866	best: 0.0012866 (70)	total: 616ms	remaining: 252ms
# 80:	learn: 0.0011223	test: 0.0011194	best: 0.0011194 (80)	total: 703ms	remaining: 165ms
# 90:	learn: 0.0009299	test: 0.0009282	best: 0.0009282 (90)	total: 790ms	remaining: 78.1ms
# 99:	learn: 0.0007906	test: 0.0007878	best: 0.0007878 (99)	total: 868ms	remaining: 0us
# bestTest = 0.00078783077
# bestIteration = 99
# 1.0
# 0:	learn: 0.3736734	test: 0.3736734	best: 0.3736734 (0)	total: 5.05ms	remaining: 500ms
# 10:	learn: 0.0946193	test: 0.0946073	best: 0.0946073 (10)	total: 47.4ms	remaining: 383ms
# 20:	learn: 0.0668964	test: 0.0666380	best: 0.0666380 (20)	total: 89.8ms	remaining: 338ms
# 30:	learn: 0.0556272	test: 0.0554556	best: 0.0554556 (30)	total: 133ms	remaining: 295ms
# 40:	learn: 0.0488466	test: 0.0490706	best: 0.0490706 (40)	total: 175ms	remaining: 252ms
# 50:	learn: 0.0426618	test: 0.0430071	best: 0.0430071 (50)	total: 218ms	remaining: 210ms
# 60:	learn: 0.0382744	test: 0.0388079	best: 0.0388079 (60)	total: 261ms	remaining: 167ms
# 70:	learn: 0.0346366	test: 0.0352854	best: 0.0352854 (70)	total: 303ms	remaining: 124ms
# 80:	learn: 0.0320135	test: 0.0327621	best: 0.0327621 (80)	total: 346ms	remaining: 81.1ms
# 90:	learn: 0.0298934	test: 0.0307630	best: 0.0307630 (90)	total: 388ms	remaining: 38.4ms
# 99:	learn: 0.0282157	test: 0.0291172	best: 0.0291172 (99)	total: 426ms	remaining: 0us
# bestTest = 0.02911722875
# bestIteration = 99
# 1.0

# %% [markdown]
# # STEP 02. 복합적으로 고려하는 모델
# - B와 C만 있을 때 구분
# - 모두 있을 때 각각 구분

# %%
train3 = train2[train2['class'] != 0].copy()

y4 = (train3['class'].values).astype(int) - 1

X2 = train3.drop(['id', 'class', 'trait', 'trait_ratio'], axis=1)
X2.iloc[:,:15] = X2.iloc[:,:15].astype('category')

strategy1 = 'auto'
strategy2 = {0:1000, 1:1000}
strategy3 = {0:1000, 1:1200}

smote1 = SMOTENC(categorical_features=[x for x in range(15)], random_state=random_seed, sampling_strategy=strategy1)
smote2 = SMOTENC(categorical_features=[x for x in range(15)], random_state=random_seed, sampling_strategy=strategy2)
smote3 = SMOTENC(categorical_features=[x for x in range(15)], random_state=random_seed, sampling_strategy=strategy3)
X_train4, y_train4 = smote1.fit_resample(X2, y4)
X_train5, y_train5 = smote1.fit_resample(X2, y4)
X_train5, y_train6 = smote1.fit_resample(X2, y4)
train3['class'].value_counts(), train3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 261
# Data columns (total 42 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            193 non-null    object
#  1   trait         193 non-null    int64
#  2   SNP_01        193 non-null    int64
#  3   SNP_02        193 non-null    int64
#  4   SNP_03        193 non-null    int64
#  5   SNP_04        193 non-null    int64
#  6   SNP_05        193 non-null    int64
#  7   SNP_06        193 non-null    int64
#  8   SNP_07        193 non-null    int64
#  9   SNP_08        193 non-null    int64
#  10  SNP_09        193 non-null    int64
#  11  SNP_10        193 non-null    int64
#  12  SNP_11        193 non-null    int64
#  13  SNP_12        193 non-null    int64
#  14  SNP_13        193 non-null    int64
#  15  SNP_14        193 non-null    int64
#  16  SNP_15        193 non-null    int64
#  17  class         193 non-null    int64
#  18  SNP_01_ratio  193 non-null    float64
#  19  SNP_02_ratio  193 non-null    float64
#  20  SNP_03_ratio  193 non-null    float64
#  21  SNP_04_ratio  193 non-null    float64
#  22  SNP_05_ratio  193 non-null    float64
#  23  SNP_06_ratio  193 non-null    float64
#  24  SNP_07_ratio  193 non-null    float64
#  25  SNP_08_ratio  193 non-null    float64
#  26  SNP_09_ratio  193 non-null    float64
#  27  SNP_10_ratio  193 non-null    float64
#  28  SNP_11_ratio  193 non-null    float64
#  29  SNP_12_ratio  193 non-null    float64
#  30  SNP_13_ratio  193 non-null    float64
#  31  SNP_14_ratio  193 non-null    float64
#  32  SNP_15_ratio  193 non-null    float64
#  33  trait_ratio   193 non-null    float64
#  34  encodings_0   193 non-null    float64
#  35  encodings_1   193 non-null    float64
#  36  encodings_2   193 non-null    float64
#  37  encodings_3   193 non-null    float64
#  38  encodings_4   193 non-null    float64
#  39  encodings_5   193 non-null    float64
#  40  encodings_6   193 non-null    float64
#  41  errors        193 non-null    float64
# dtypes: float64(24), int64(17), object(1)
# memory usage: 64.8+ KB
# (1    114
#  2     79
#  Name: class, dtype: int64,
#  None)

# %%
model4_c = lgbmc(X_train4, y_train4)
model4_r = lgbmr(X_train4, y_train4)
# Out:
# 0:	learn: 0.4263382	test: 0.4263382	best: 0.4263382 (0)	total: 10.4ms	remaining: 1.02s
# 10:	learn: 0.0705201	test: 0.0707894	best: 0.0707894 (10)	total: 97.7ms	remaining: 790ms
# 20:	learn: 0.0308901	test: 0.0327608	best: 0.0327608 (20)	total: 185ms	remaining: 697ms
# 30:	learn: 0.0184407	test: 0.0202124	best: 0.0202124 (30)	total: 272ms	remaining: 606ms
# 40:	learn: 0.0119299	test: 0.0135959	best: 0.0135959 (40)	total: 359ms	remaining: 517ms
# 50:	learn: 0.0090353	test: 0.0106403	best: 0.0106403 (50)	total: 447ms	remaining: 430ms
# 60:	learn: 0.0070060	test: 0.0082949	best: 0.0082949 (60)	total: 534ms	remaining: 341ms
# 70:	learn: 0.0057834	test: 0.0069752	best: 0.0069752 (70)	total: 621ms	remaining: 254ms
# 80:	learn: 0.0048260	test: 0.0060313	best: 0.0060313 (80)	total: 708ms	remaining: 166ms
# 90:	learn: 0.0041153	test: 0.0052301	best: 0.0052301 (90)	total: 795ms	remaining: 78.6ms
# 99:	learn: 0.0037026	test: 0.0047410	best: 0.0047410 (99)	total: 873ms	remaining: 0us
# bestTest = 0.004740983771
# bestIteration = 99
# 1.0
# 0:	learn: 0.4170837	test: 0.4170837	best: 0.4170837 (0)	total: 5.88ms	remaining: 582ms
# 10:	learn: 0.1650172	test: 0.1660523	best: 0.1660523 (10)	total: 48.2ms	remaining: 390ms
columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   trait         175 non-null    category
#  1   SNP_01        175 non-null    category
#  2   SNP_02        175 non-null    category
#  3   SNP_03        175 non-null    category
#  4   SNP_04        175 non-null    category
#  5   SNP_05        175 non-null    category
#  6   SNP_06        175 non-null    category
#  7   SNP_07        175 non-null    category
#  8   SNP_08        175 non-null    category
#  9   SNP_09        175 non-null    category
#  10  SNP_10        175 non-null    category
#  11  SNP_11        175 non-null    category
#  12  SNP_12        175 non-null    category
#  13  SNP_13        175 non-null    category
#  14  SNP_14        175 non-null    category
#  15  SNP_15        175 non-null    int64
#  16  SNP_01_ratio  175 non-null    float64
#  17  SNP_02_ratio  175 non-null    float64
#  18  SNP_03_ratio  175 non-null    float64
#  19  SNP_04_ratio  175 non-null    float64
#  20  SNP_05_ratio  175 non-null    float64
#  21  SNP_06_ratio  175 non-null    float64
#  22  SNP_07_ratio  175 non-null    float64
#  23  SNP_08_ratio  175 non-null    float64
#  24  SNP_09_ratio  175 non-null    float64
#  25  SNP_10_ratio  175 non-null    float64
#  26  SNP_11_ratio  175 non-null    float64
#  27  SNP_12_ratio  175 non-null    float64
#  28  SNP_13_ratio  175 non-null    float64
#  29  SNP_14_ratio  175 non-null    float64
#  30  SNP_15_ratio  175 non-null    float64
#  31  trait_ratio   175 non-null    float64
#  32  encodings_0   106 non-null    float64
#  33  encodings_1   106 non-null    float64
#  34  encodings_2   106 non-null    float64
#  35  encodings_3   106 non-null    float64
#  36  encodings_4   106 non-null    float64
#  37  encodings_5   106 non-null    float64
#  38  encodings_6   106 non-null    float64
#  39  errors        106 non-null    float64
# dtypes: category(15), float64(24), int64(1)
# memory usage: 38.8 KB

# %%
pred1 = model1_c.predict_proba(X_test)[:,1]
pred2 = model1_r.predict(X_test)
pred3 = model2_c.predict_proba(X_test)[:,1]
pred4 = model2_r.predict(X_test)
pred5 = model3_c.predict_proba(X_test)[:,1]
pred6 = model3_r.predict(X_test)

pred7 = model4_c.predict_proba(X_test)[:,1]
pred8 = model4_r.predict(X_test)
pred9 = model5_c.predict_proba(X_test)[:,1]
pred10 = model5_r.predict(X_test)
pred11 = model6_c.predict_proba(X_test)[:,1]
pred12 = model6_r.predict(X_test)

A_prob = (pred1+pred2) / 2
B_prob = (pred3+pred4) / 2
C_prob = (pred5+pred6) / 2
BC_prob_auto = (pred7+pred8) / 2
BC_prob_1000 = (pred9+pred10) / 2
BC_prob_1200 = (pred11+pred12) / 2

# %%
high1 = pd.read_csv("./data/submit_0.99078.csv")
high2 = pd.read_csv("./data/submit_0.99078_2.csv")
high3 = pd.read_csv("./data/submit_0.99078_3.csv")
high4 = pd.read_csv("./data/submit_0.99078_4.csv")

total = pd.DataFrame()
total['high1'] = high1['class']
total['high2'] = high2['class']
total['high3'] = high3['class']
total['high4'] = high4['class']

total['pred1'] = pred1
total['pred2'] = pred2
total['pred3'] = pred3
total['pred4'] = pred4
total['pred5'] = pred5
total['pred6'] = pred6
total['pred7'] = pred7
total['pred8'] = pred8
total['pred9'] = pred9
total['pred10'] = pred10
total['pred11'] = pred11
total['pred12'] = pred12

total['a_prob'] = A_prob
total['b_prob'] = B_prob
total['c_prob'] = C_prob
total['bc_prob_auto'] = BC_prob_auto
total['bc_prob_1000'] = BC_prob_1000
total['bc_prob_1200'] = BC_prob_1200

total
# Out:
#     high1 high2 high3 high4     pred1     pred2     pred3     pred4     pred5  \
# 0       A     A     A     A  0.967424  0.754704  0.000024  0.003470  0.000975
# 1       B     B     B     B  0.000066 -0.007479  0.999980  1.055193  0.000097
# 2       C     C     C     C  0.000984  0.023447  0.000046 -0.034731  0.999864
# 3       C     C     C     C  0.000298 -0.001993  0.991672  0.828912  0.255339
# 4       A     A     A     A  0.999968  1.000619  0.000020 -0.002506  0.000149
# ..    ...   ...   ...   ...       ...       ...       ...       ...       ...
# 170     B     B     B     B  0.000119 -0.006254  0.988850  0.931199  0.023737
# 171     C     C     C     C  0.000273 -0.010404  0.000310  0.003947  0.999806
# 172     C     C     C     C  0.000432 -0.001483  0.005906  0.065229  0.997321
# 173     B     B     B     B  0.000075 -0.007725  0.999851  1.016167  0.000692
# 174     B     B     B     B  0.000765  0.098726  0.991925  0.899688  0.022385
#
#         pred6  ...     pred9    pred10    pred11    pred12    a_prob  \
# 0    0.018098  ...  0.973565  0.780386  0.973565  0.780386  0.861064
# 1   -0.024093  ...  0.002701 -0.040449  0.002701 -0.040449 -0.003707
# 2    1.046110  ...  0.998099  0.854307  0.998099  0.854307  0.012215
# 3    0.400911  ...  0.057667  0.301193  0.057667  0.301193 -0.000847
# 4    0.025838  ...  0.818956  0.696908  0.818956  0.696908  1.000294
# ..        ...  ...       ...       ...       ...       ...       ...
# 170  0.059499  ...  0.096798  0.246846  0.096798  0.246846 -0.003068
# 171  0.995161  ...  0.996449  1.015029  0.996449  1.015029 -0.005066
# 172  0.841661  ...  0.964454  0.658497  0.964454  0.658497 -0.000526
# 173 -0.054259  ...  0.018407 -0.020830  0.018407 -0.020830 -0.003825
# 174  0.157067  ...  0.086325  0.277395  0.086325  0.277395  0.049745
#
#        b_prob    c_prob  bc_prob_auto  bc_prob_1000  bc_prob_1200
# 0    0.001747  0.009536      0.876975      0.876975      0.876975
# 1    1.027587 -0.011998     -0.018874     -0.018874     -0.018874
# 2   -0.017343  1.022987      0.926203      0.926203      0.926203
# 3    0.910292  0.328125      0.179430      0.179430      0.179430
# 4   -0.001243  0.012993      0.757932      0.757932      0.757932
# ..        ...       ...           ...           ...           ...
# 170  0.960024  0.041618      0.171822      0.171822      0.171822
# 171  0.002129  0.997484      1.005739      1.005739      1.005739
# 172  0.035568  0.919491      0.811476      0.811476      0.811476
# 173  1.008009 -0.026783     -0.001212     -0.001212     -0.001212
# 174  0.945806  0.089726      0.181860      0.181860      0.181860
#
# [175 rows x 22 columns]

# %%
a_index = total[total.a_prob >= 0.5].index.tolist()
b_index = total[total.b_prob >= 0.5].index.tolist()
c_index = total[total.c_prob >= 0.5].index.tolist()
ab_index = total[(total.b_prob >= 0.5) & (total.a_prob >= 0.5)].index.tolist()
ac_index = total[(total.a_prob >= 0.5) & (total.c_prob >= 0.5)].index.tolist()
bc_index = total[(total.b_prob >= 0.5) & (total.c_prob >= 0.5)].index.tolist()
abc_index = total[(total.a_prob >= 0.3) & (total.b_prob >= 0.3) & (total.c_prob >= 0.3)].index.tolist()

print(len(a_index), len(b_index), len(c_index), len(ab_index), len(ac_index), len(bc_index), len(abc_index), len(a_index)+len(b_index)+len(c_index))
# Out:
# 49 87 36 0 0 1 0 172

# %% [markdown]
# ### Summary
# 1. A랑은 헷갈려하지 않는다.
# 2. B와 C랑은 헷갈려하기 때문에 이에 대한 기준이 필요해보인다.

# %%
total.iloc[bc_index]
# Out:
#   high1 high2 high3 high4     pred1     pred2     pred3     pred4     pred5  \
# 5     C     C     C     C  0.000021 -0.003667  0.752677  0.679453  0.596063
#
#       pred6  ...     pred9    pred10    pred11    pred12    a_prob    b_prob  \
# 5  0.709532  ...  0.659294  0.576198  0.659294  0.576198 -0.001823  0.716065
#
#      c_prob  bc_prob_auto  bc_prob_1000  bc_prob_1200
# 5  0.652798      0.617746      0.617746      0.617746
#
# [1 rows x 22 columns]

# %%
total.iloc[[3,5,12,119,126,162,168], -16:]
# Out:
#         pred3     pred4     pred5     pred6     pred7     pred8     pred9  \
# 3    0.991672  0.828912  0.255339  0.400911  0.057667  0.301193  0.057667
# 5    0.752677  0.679453  0.596063  0.709532  0.659294  0.576198  0.659294
# 12   0.141866  0.934535  0.372069  0.130681  0.226753  0.351016  0.226753
# 119  0.358697  0.405463  0.513283  0.371022  0.440553  0.406170  0.440553
# 126  0.941046  0.504828  0.047124  0.578554  0.289778  0.519929  0.289778
# 162  0.778572  0.388347  0.234096  0.480320  0.612613  0.675717  0.612613
# 168  0.950857  0.539172  0.422303  0.149167  0.098313  0.165957  0.098313
#
#        pred10    pred11    pred12    a_prob    b_prob    c_prob  bc_prob_auto  \
# 3    0.301193  0.057667  0.301193 -0.000847  0.910292  0.328125      0.179430
# 5    0.576198  0.659294  0.576198 -0.001823  0.716065  0.652798      0.617746
# 12   0.351016  0.226753  0.351016  0.000756  0.538201  0.251375      0.288884
# 119  0.406170  0.440553  0.406170 -0.004899  0.382080  0.442153      0.423361
# 126  0.519929  0.289778  0.519929  0.079126  0.722937  0.312839      0.404854
# 162  0.675717  0.612613  0.675717  0.017900  0.583460  0.357208      0.644165
# 168  0.165957  0.098313  0.165957  0.003895  0.745014  0.285735      0.132135
#
#      bc_prob_1000  bc_prob_1200
# 3        0.179430      0.179430
# 5        0.617746      0.617746
# 12       0.288884      0.288884
# 119      0.423361      0.423361
# 126      0.404854      0.404854
# 162      0.644165      0.644165
# 168      0.132135      0.132135

# %%
total[(total.pred1 > 0.4) & (total.pred2 > 0.4)]
# Out:
#     high1 high2 high3 high4     pred1     pred2     pred3     pred4     pred5  \
# 0       A     A     A     A  0.967424  0.754704  0.000024  0.003470  0.000975
# 4       A     A     A     A  0.999968  1.000619  0.000020 -0.002506  0.000149
# 8       A     A     A     A  0.999939  0.999156  0.000121 -0.055126  0.044177
# 9       A     A     A     A  0.999993  1.000067  0.000011 -0.004582  0.000063
# 13      A     A     A     A  0.999967  1.008395  0.000039 -0.003780  0.000084
# 16      A     A     A     A  0.999941  0.999850  0.000022 -0.007721  0.000043
# 23      A     A     A     A  0.999965  0.999647  0.000019 -0.001381  0.000026
# 27      A     A     A     A  0.999793  1.005098  0.000073 -0.009666  0.000167
# 152  0.001060      0.661768      0.661768      0.661768     0.0
# 155  0.006994      0.665319      0.665319      0.665319     0.0
# 156  0.004335      0.727822      0.727822      0.727822     0.0
# 159  0.001631      0.733297      0.733297      0.733297     0.0
# 164 -0.003552      0.664413      0.664413      0.664413     0.0
# 165  0.050681      0.546911      0.546911      0.546911     0.0
# 169 -0.001595      0.663574      0.663574      0.663574     0.0
#
# [49 rows x 23 columns]

# %%
all_idx = [x for x in range(len(X_test))]
all_idx = [x for x in all_idx if (x not in a_index) & (x not in b_index) & (x not in c_index)]
all_idx
# Out:
# [19, 60, 119, 140]

# %%
total.iloc[[19,60,119,140]]
# Out:
#     high1 high2 high3 high4     pred1     pred2     pred3     pred4     pred5  \
# 19      C     C     C     C  0.000010  0.007093  0.077313  0.231380  0.306772
# 60      A     A     A     A  0.004989  0.073998  0.009301  0.370499  0.016599
# 119     C     C     C     C  0.001203 -0.011001  0.358697  0.405463  0.513283
# 140     A     A     A     A  0.479806  0.123098  0.119487  0.294518  0.042923
#
#         pred6  ...    pred10    pred11    pred12    a_prob    b_prob  \
# 19   0.607652  ...  0.938561  0.843300  0.938561  0.003551  0.154347
# 60   0.114375  ...  0.636287  0.850982  0.636287  0.039494  0.189900
# 119  0.371022  ...  0.406170  0.440553  0.406170 -0.004899  0.382080
# 140  0.218272  ...  0.511234  0.676596  0.511234  0.301452  0.207003
#
#        c_prob  bc_prob_auto  bc_prob_1000  bc_prob_1200  answer
# 19   0.457212      0.890930      0.890930      0.890930     0.0
# 60   0.065487      0.743635      0.743635      0.743635     0.0
# 119  0.442153      0.423361      0.423361      0.423361     0.0
# 140  0.130598      0.593915      0.593915      0.593915     0.0
#
# [4 rows x 23 columns]

# %%
answer = np.zeros(len(X_test))
a_index = total[total.a_prob > 0.5].index.tolist()
b_index = total[total.b_prob > 0.5].index.tolist()
c_index = total[total.c_prob > 0.5].index.tolist()

target = [x for x in b_index if x in c_index]
for t in target :
    score = np.mean(total.iloc[t, -3:])
    if score > 0.5 :
        b_index.remove(t)
    else :
        c_index.remove(t)
        

if (len(a_index)+len(b_index)+len(c_index)) != len(X_test) :
    zero_idx = [x for x in range(len(X_test))]
    zero_idx = [x for x in all_idx if (x not in a_index) & (x not in b_index) & (x not in c_index)]
    c_opinion = np.argmax(total.loc[zero_idx, ['pred1', 'pred3', 'pred5']], axis=1)
    r_opinion = np.argmax(total.loc[zero_idx, ['pred2', 'pred4', 'pred6']], axis=1)
    opinions = []
    for i in range(len(c_opinion)) :
        if c_opinion[i] == r_opinion[i] : 
            opinions.append(c_opinion[i])
        else :
            
        

answer[a_index] = 0
answer[b_index] = 1
answer[c_index] = 2

total['answer'] = answer

print(len(a_index), len(b_index), len(c_index), len(a_index)+len(b_index)+len(c_index))
# Out:
# 49 86 36 171

# %%
total['target'] = total.answer.map(lambda x : 'A' if x==0 else ('B' if x==1 else 'C'))
total[total.high1 != total.target]
# Out:
#     high1 high2 high3 high4     pred1     pred2     pred3     pred4     pred5  \
# 3       C     C     C     C  0.168860  0.057801  0.917920  0.945956  0.438959
# 12      B     C     C     C  0.000052  0.001597  0.296680  0.443346  0.373061
# 119     C     C     C     C  0.000095  0.005052  0.698994  0.780585  0.115815
# 126     B     C     B     B  0.000099  0.034037  0.767498  0.586070  0.391295
#
#         pred6  ...    pred11    pred12    a_prob    b_prob    c_prob  \
# 3    0.390259  ...  0.109921  0.158754  0.197760  1.390898  0.634089
# 12   0.289546  ...  0.615802  0.431371  0.000850  0.518353  0.517834
# 119  0.406309  ...  0.662537  0.479001  0.002621  1.089287  0.318969
# 126  0.486659  ...  0.649863  0.625625  0.017117  1.060534  0.634624
#
#      bc_prob_auto  bc_prob_1000  bc_prob_1200  answer  target
# 3        0.189298      0.189298      0.189298     1.0       B
# 12       0.831488      0.831488      0.831488     2.0       C
# 119      0.902038      0.902038      0.902038     1.0       B
# 126      0.962676      0.962676      0.962676     2.0       C
#
# [4 rows x 24 columns]

# %%
X_test.iloc[[168]]
# Out:
#     trait SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_07 SNP_08 SNP_09  ...  \
# 168     1      2      1      0      0      2      0      0      1      0  ...
#
#     SNP_15_ratio trait_ratio encodings_0 encodings_1 encodings_2 encodings_3  \
# 168      0.68932    0.590674         NaN         NaN         NaN         NaN
#
#      encodings_4  encodings_5  encodings_6  errors
# 168          NaN          NaN          NaN     NaN
#
# [1 rows x 40 columns]

# %%
train2[train2['class']==0]
# Out:
#             id  trait  SNP_01  SNP_02  SNP_03  SNP_04  SNP_05  SNP_06  SNP_07  \
# 0    TRAIN_000      1       2       1       0       1       1       0       0
# 1    TRAIN_001      1       1       1       1       0       0       1       0
# 2    TRAIN_002      1       2       2       0       1       2       2       0
# 3    TRAIN_003      0       0       2       0       1       0       2       2
# 4    TRAIN_004      1       2       2       2       0       2       0       0
# ..         ...    ...     ...     ...     ...     ...     ...     ...     ...
# 257  TRAIN_257      1       1       1       0       1       2       1       0
# 258  TRAIN_258      1       2       0       1       0       0       1       1
# 259  TRAIN_259      0       1       2       0       1       0       1       2
# 260  TRAIN_260      0       0       2       0       1       0       2       2
# 261  TRAIN_261      1       2       1       1       2       2       1       0
#
#      SNP_08  ...  SNP_15_ratio  trait_ratio  encodings_0  encodings_1  \
# 0         2  ...      0.689320     0.590674     0.038362    -0.123360
# 1         1  ...      0.689320     0.590674     0.018671     0.003465
# 2         1  ...      0.689320     0.590674     0.160368     0.028850
# 3         0  ...      0.272727     0.000000    -0.052722     0.162948
# 4         0  ...      0.506329     0.590674     0.016150     0.077639
# ..      ...  ...           ...          ...          ...          ...
# 257       1  ...      0.689320     0.590674    -0.068305    -0.129912
# 258       1  ...      0.506329     0.590674     0.687875     1.094408
# 259       1  ...      0.272727     0.000000    -0.041655    -0.117549
# 260       0  ...      0.272727     0.000000     3.596450     7.185980
# 261       0  ...      0.506329     0.590674     3.390476     7.853312
#
#      encodings_2  encodings_3  encodings_4  encodings_5  encodings_6    errors
# 0       0.028561    -0.007297    -0.014100    -0.022615    -0.071094  0.027966
# 1      -0.168691    -0.089982    -0.076945     0.159816     0.338336  0.047560
# 2       0.055501    -0.033374     0.042429     0.094334    -0.099921  0.078756
# 3      -0.049646     0.077969    -0.072254     0.062971    -0.052153  0.046547
# 4      -0.008436     0.060002    -0.028739     0.026300    -0.134074  0.024998
# ..           ...          ...          ...          ...          ...       ...
# 257    -0.057470    -0.021480    -0.067259    -0.049244     0.006264  0.035129
# 258     0.116105    -0.169651     0.719153     0.076116    -0.062590  0.059244
# 259     0.120116    -0.090664     0.001641    -0.154535     0.020693  0.064420
# 260    -0.153397    -0.001454     4.507180     0.414904    -0.121423  0.053174
# 261    -0.143190    -0.002447     5.351220     0.624516    -0.014161  0.065646
#
# [262 rows x 42 columns]

# %%
submit = high1.copy()
submit['class'] = total.target
submit
# Out:
#            id class
# 0    TEST_000     A
# 1    TEST_001     B
# 2    TEST_002     C
# 3    TEST_003     B
# 4    TEST_004     A
# ..        ...   ...
# 170  TEST_170     B
# 171  TEST_171     C
# 172  TEST_172     C
# 173  TEST_173     B
# 174  TEST_174     B
#
# [175 rows x 2 columns]

# %%
submit.to_csv("submit.csv", index=False)

# %%
df1 = pd.read_csv("./data/submit_0.99078.csv")
df2 = pd.read_csv("./data/submit_0.99078_2.csv")
df3 = pd.read_csv("./data/submit_0.99078_3.csv")
df4 = pd.read_csv("./data/submit_0.99078_4.csv")

# %%
# submit 기준
display(submit[submit['class'] != df1['class']],submit[submit['class'] != df2['class']],submit[submit['class'] != df3['class']],submit[submit['class'] != df4['class']])
# Out:
#            id class
# 3    TEST_003     B
# 5    TEST_005     B
# 126  TEST_126     C
#           id class
# 3   TEST_003     B
# 5   TEST_005     B
# 12  TEST_012     B
#            id class
# 3    TEST_003     B
# 5    TEST_005     B
# 12   TEST_012     B
# 126  TEST_126     C
#            id class
# 3    TEST_003     B
# 5    TEST_005     B
# 12   TEST_012     B
# 126  TEST_126     C
# 168  TEST_168     B

# %%
total['answer'] = total_index
total.iloc[[3, 5, 12, 119, 168], [0,1,2,3,-4, -3, -2, -1]]
# Out:
#     high1 high2 high3 high4    a_prob    b_prob    c_prob  answer
# 3       C     C     C     C  0.059954  1.816940  0.610793       1
# 5       C     C     C     C -0.000880  1.602311  1.031356       1
# 12      B     C     C     C  0.006151  0.867814  0.338562       1
# 119     C     C     C     C  0.000587  1.078331  0.992099       1
# 168     B     B     B     C -0.001244  1.410336  0.296742       1

# %%
total[(total.b_prob > 1.0) & (total.c_prob > 0.5)]
# Out:
#     high1 high2 high3 high4     pred1     pred2     pred3     pred4     pred5  \
# 3       C     C     C     C  0.000703  0.059251  0.989858  0.827082  0.257562
# 5       C     C     C     C  0.000287 -0.001167  0.975314  0.626997  0.490775
# 35      B     B     B     B  0.000482  0.001193  0.811900  0.645094  0.223033
# 119     C     C     C     C  0.000229  0.000358  0.413266  0.665065  0.578031
# 126     B     C     B     B  0.000968  0.049571  0.669163  0.379141  0.249582
#
#         pred6    a_prob    b_prob    c_prob  answer
# 3    0.353230  0.059954  1.816940  0.610793       1
# 5    0.540581 -0.000880  1.602311  1.031356       1
# 35   0.364383  0.001676  1.456993  0.587417       1
# 119  0.414068  0.000587  1.078331  0.992099       1
# 126  0.501944  0.050539  1.048304  0.751527       1

# %%
total_index2 = np.where(a_prob > 1.0, 0, np.where(c_prob > 0.6, 2,

# %%
# submit 기준
display(submit[submit['class'] != df1['class']],submit[submit['class'] != df2['class']],submit[submit['class'] != df3['class']],submit[submit['class'] != df4['class']])

# %%
sum(high1['class'] == submit['class'])
# Out:
# 172

# %%
submit['class'].value_counts()
# Out:
# B    85
# A    51
# C    39
# Name: class, dtype: int64

# %%
high1['class'].value_counts()
# Out:
# B    84
# A    51
# C    40
# Name: class, dtype: int64

# %%
submit.to_csv("submit.csv", index=False)

# %%
high1 = pd.read_csv("./data/submit_0.99078.csv")
high2 = pd.read_csv("./data/submit_0.99078_2.csv")
high3 = pd.read_csv("./data/submit_0.99078_3.csv")
high4 = pd.read_csv("./data/submit_0.99078_4.csv")

middle1 = pd.read_csv("./data/submit_0.98142.csv")

low1 = pd.read_csv("./submit_0.9622.csv")
low2 = pd.read_csv("./submit_0.9622_2.csv")
low3 = pd.read_csv("./submit_0.9719.csv")

# %%
targets = [high1, high2, high3, high4, middle1, low1, low2, low3]

idx_list = []
for i in range(len(targets)-1) :
    target = targets[i]
    for j in range(len(targets[i+1:])) :
        diff_idx = target[target['class'] != targets[j]['class']].index.tolist()
        idx_list += diff_idx
        
idx_list = sorted(list(set(idx_list)))
idx_list
# Out:
# [3, 5, 12, 119, 126, 168]

# %%
idx_list = sorted(idx_list+[162])

# %%
display(high1.iloc[idx_list],high2.iloc[idx_list],high3.iloc[idx_list],high4.iloc[idx_list],middle1.iloc[idx_list],low1.iloc[idx_list],low2.iloc[idx_list],low3.iloc[idx_list])
# Out:
#            id class
# 3    TEST_003     C
# 5    TEST_005     C
# 12   TEST_012     B
# 119  TEST_119     C
# 126  TEST_126     B
# 162  TEST_162     C
# 168  TEST_168     B
#            id class
# 3    TEST_003     C
# 5    TEST_005     C
# 12   TEST_012     C
# 119  TEST_119     C
# 126  TEST_126     C
# 162  TEST_162     C
# 168  TEST_168     B
#            id class
# 3    TEST_003     C
# 5    TEST_005     C
# 12   TEST_012     C
# 119  TEST_119     C
# 126  TEST_126     B
# 162  TEST_162     C
# 168  TEST_168     B
#            id class
# 3    TEST_003     C
# 5    TEST_005     C
# 12   TEST_012     C
# 119  TEST_119     C
# 126  TEST_126     B
# 162  TEST_162     C
# 168  TEST_168     C
#            id class
# 3    TEST_003     C
# 5    TEST_005     B
# 12   TEST_012     B
# 119  TEST_119     C
# 126  TEST_126     C
# 162  TEST_162     C
# 168  TEST_168     B
#            id class
# 3    TEST_003     B
# 5    TEST_005     B
# 12   TEST_012     A
# 119  TEST_119     B
# 126  TEST_126     B
# 162  TEST_162     C
# 168  TEST_168     B
#            id class
# 3    TEST_003     B
# 5    TEST_005     B
# 12   TEST_012     B
# 119  TEST_119     B
# 126  TEST_126     B
# 162  TEST_162     C
# 168  TEST_168     B
#            id class
# 3    TEST_003     B
# 5    TEST_005     B
# 12   TEST_012     B
# 119  TEST_119     C
# 126  TEST_126     C
# 162  TEST_162     C
# 168  TEST_168     B

# %%
display(low3[low3['class'] != low1['class']], low1[low3['class'] != low1['class']])
# Out:
#            id class
# 12   TEST_012     B
# 119  TEST_119     C
# 126  TEST_126     C
#            id class
# 12   TEST_012     A
# 119  TEST_119     B
# 126  TEST_126     B

# %%
display(high3[high3['class'] != high1['class']], high1[high3['class'] != high1['class']])
# Out:
#           id class
# 12  TEST_012     C
#           id class
# 12  TEST_012     B

# %%
display(high3[high3['class'] != high2['class']], high2[high3['class'] != high2['class']])
# Out:
#            id class
# 126  TEST_126     B
#            id class
# 126  TEST_126     C
