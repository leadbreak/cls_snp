# %% [markdown]
# # 01. EDA

# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import gc
import math
import random
import pickle
import pandas as pd
import numpy as np
import multiprocessing
from tqdm.auto import tqdm

from sklearn.metrics import f1_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset, sampler

from xgboost import XGBClassifier, XGBRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from imblearn.over_sampling import SMOTE, SMOTENC, SMOTEN

import shap
import catboost

pd.set_option('display.max_columns', 500)

# %%
train = pd.read_csv("./data/train.csv")
train.drop_duplicates(subset=train.columns.tolist()[5:20], inplace=True, ignore_index=True)
test = pd.read_csv("./data/test.csv")

train2 = pd.concat([pd.get_dummies(train.iloc[:, 5:20]), train['class']], axis=1)
test2 = pd.get_dummies(test.iloc[:, 5:20])

train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 46 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  256 non-null    uint8
#  1   SNP_01_A G  256 non-null    uint8
#  2   SNP_01_G G  256 non-null    uint8
#  3   SNP_02_A A  256 non-null    uint8
#  4   SNP_02_A G  256 non-null    uint8
#  5   SNP_02_G G  256 non-null    uint8
#  6   SNP_03_A A  256 non-null    uint8
#  7   SNP_03_C A  256 non-null    uint8
#  8   SNP_03_C C  256 non-null    uint8
#  9   SNP_04_A A  256 non-null    uint8
#  10  SNP_04_G A  256 non-null    uint8
#  11  SNP_04_G G  256 non-null    uint8
#  12  SNP_05_A A  256 non-null    uint8
#  13  SNP_05_C A  256 non-null    uint8
#  14  SNP_05_C C  256 non-null    uint8
#  15  SNP_06_A A  256 non-null    uint8
#  16  SNP_06_A G  256 non-null    uint8
#  17  SNP_06_G G  256 non-null    uint8
#  18  SNP_07_A A  256 non-null    uint8
#  19  SNP_07_G A  256 non-null    uint8
#  20  SNP_07_G G  256 non-null    uint8
#  21  SNP_08_A A  256 non-null    uint8
#  22  SNP_08_G A  256 non-null    uint8
#  23  SNP_08_G G  256 non-null    uint8
#  24  SNP_09_A A  256 non-null    uint8
#  25  SNP_09_G A  256 non-null    uint8
#  26  SNP_09_G G  256 non-null    uint8
#  27  SNP_10_A A  256 non-null    uint8
#  28  SNP_10_A G  256 non-null    uint8
#  29  SNP_10_G G  256 non-null    uint8
#  30  SNP_11_A A  256 non-null    uint8
#  31  SNP_11_A G  256 non-null    uint8
#  32  SNP_11_G G  256 non-null    uint8
#  33  SNP_12_A A  256 non-null    uint8
#  34  SNP_12_G A  256 non-null    uint8
#  35  SNP_12_G G  256 non-null    uint8
#  36  SNP_13_A A  256 non-null    uint8
#  37  SNP_13_A G  256 non-null    uint8
#  38  SNP_13_G G  256 non-null    uint8
#  39  SNP_14_A A  256 non-null    uint8
#  40  SNP_14_C A  256 non-null    uint8
#  41  SNP_14_C C  256 non-null    uint8
#  42  SNP_15_A A  256 non-null    uint8
#  43  SNP_15_G A  256 non-null    uint8
#  44  SNP_15_G G  256 non-null    uint8
#  45  class       256 non-null    object
# dtypes: object(1), uint8(45)
# memory usage: 13.4+ KB

# %%
test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 45 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  175 non-null    uint8
#  1   SNP_01_A G  175 non-null    uint8
#  2   SNP_01_G G  175 non-null    uint8
#  3   SNP_02_A A  175 non-null    uint8
#  4   SNP_02_A G  175 non-null    uint8
#  5   SNP_02_G G  175 non-null    uint8
#  6   SNP_03_A A  175 non-null    uint8
#  7   SNP_03_C A  175 non-null    uint8
#  8   SNP_03_C C  175 non-null    uint8
#  9   SNP_04_A A  175 non-null    uint8
#  10  SNP_04_G A  175 non-null    uint8
#  11  SNP_04_G G  175 non-null    uint8
#  12  SNP_05_A A  175 non-null    uint8
#  13  SNP_05_C A  175 non-null    uint8
#  14  SNP_05_C C  175 non-null    uint8
#  15  SNP_06_A A  175 non-null    uint8
#  16  SNP_06_A G  175 non-null    uint8
#  17  SNP_06_G G  175 non-null    uint8
#  18  SNP_07_A A  175 non-null    uint8
#  19  SNP_07_G A  175 non-null    uint8
#  20  SNP_07_G G  175 non-null    uint8
#  21  SNP_08_A A  175 non-null    uint8
#  22  SNP_08_G A  175 non-null    uint8
#  23  SNP_08_G G  175 non-null    uint8
#  24  SNP_09_A A  175 non-null    uint8
#  25  SNP_09_G A  175 non-null    uint8
#  26  SNP_09_G G  175 non-null    uint8
#  27  SNP_10_A A  175 non-null    uint8
#  28  SNP_10_A G  175 non-null    uint8
#  29  SNP_10_G G  175 non-null    uint8
#  30  SNP_11_A A  175 non-null    uint8
#  31  SNP_11_A G  175 non-null    uint8
#  32  SNP_11_G G  175 non-null    uint8
#  33  SNP_12_A A  175 non-null    uint8
#  34  SNP_12_G A  175 non-null    uint8
#  35  SNP_12_G G  175 non-null    uint8
#  36  SNP_13_A A  175 non-null    uint8
#  37  SNP_13_A G  175 non-null    uint8
#  38  SNP_13_G G  175 non-null    uint8
#  39  SNP_14_A A  175 non-null    uint8
#  40  SNP_14_C A  175 non-null    uint8
#  41  SNP_14_C C  175 non-null    uint8
#  42  SNP_15_A A  175 non-null    uint8
#  43  SNP_15_G A  175 non-null    uint8
#  44  SNP_15_G G  175 non-null    uint8
# dtypes: uint8(45)
# memory usage: 7.8 KB

# %%
train2.describe()
# Out:
#        SNP_01_A A  SNP_01_A G  SNP_01_G G  SNP_02_A A  SNP_02_A G  SNP_02_G G  \
# count  256.000000  256.000000  256.000000  256.000000  256.000000  256.000000
# mean     0.175781    0.277344    0.546875    0.222656    0.378906    0.398438
# std      0.381380    0.448565    0.498773    0.416844    0.486065    0.490535
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      0.000000    1.000000    1.000000    0.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP_03_A A  SNP_03_C A  SNP_03_C C  SNP_04_A A  SNP_04_G A  SNP_04_G G  \
# count  256.000000  256.000000  256.000000   256.00000  256.000000  256.000000
# mean     0.457031    0.355469    0.187500     0.46875    0.355469    0.175781
# std      0.499126    0.479593    0.391077     0.50000    0.479593    0.381380
# min      0.000000    0.000000    0.000000     0.00000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000     0.00000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000     0.00000    0.000000    0.000000
# 75%      1.000000    1.000000    0.000000     1.00000    1.000000    0.000000
# max      1.000000    1.000000    1.000000     1.00000    1.000000    1.000000
#
#        SNP_05_A A  SNP_05_C A  SNP_05_C C  SNP_06_A A  SNP_06_A G  SNP_06_G G  \
# count  256.000000  256.000000  256.000000  256.000000  256.000000  256.000000
# mean     0.347656    0.335938    0.316406    0.234375    0.476562    0.289062
# std      0.477159    0.473242    0.465984    0.424437    0.500429    0.454215
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    0.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP
000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    0.000000    1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP_13_A A  SNP_13_A G  SNP_13_G G  SNP_14_A A  SNP_14_C A  SNP_14_C C  \
# count  113.000000  113.000000  113.000000       113.0       113.0       113.0
# mean     0.371681    0.469027    0.159292         1.0         0.0         0.0
# std      0.485406    0.501263    0.367578         0.0         0.0         0.0
# min      0.000000    0.000000    0.000000         1.0         0.0         0.0
# 25%      0.000000    0.000000    0.000000         1.0         0.0         0.0
# 50%      0.000000    0.000000    0.000000         1.0         0.0         0.0
# 75%      1.000000    1.000000    0.000000         1.0         0.0         0.0
# max      1.000000    1.000000    1.000000         1.0         0.0         0.0
#
#        SNP_15_A A  SNP_15_G A  SNP_15_G G
# count  113.000000  113.000000  113.000000
# mean     0.628319    0.345133    0.026549
# std      0.485406    0.477529    0.161476
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000

# %%
train2[train2['class']=='C'].describe()
# Out:
#        SNP_01_A A  SNP_01_A G  SNP_01_G G  SNP_02_A A  SNP_02_A G  SNP_02_G G  \
# count   79.000000   79.000000   79.000000   79.000000   79.000000   79.000000
# mean     0.063291    0.316456    0.620253    0.481013    0.417722    0.101266
# std      0.245042    0.468065    0.488425    0.502832    0.496335    0.303608
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      0.000000    1.000000    1.000000    1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP_03_A A  SNP_03_C A  SNP_03_C C  SNP_04_A A  SNP_04_G A  SNP_04_G G  \
# count   79.000000   79.000000    79.00000   79.000000   79.000000        79.0
# mean     0.367089    0.417722     0.21519    0.886076    0.113924         0.0
# std      0.485091    0.496335     0.41358    0.319749    0.319749         0.0
# min      0.000000    0.000000     0.00000    0.000000    0.000000         0.0
# 25%      0.000000    0.000000     0.00000    1.000000    0.000000         0.0
# 50%      0.000000    0.000000     0.00000    1.000000    0.000000         0.0
# 75%      1.000000    1.000000     0.00000    1.000000    0.000000         0.0
# max      1.000000    1.000000     1.00000    1.000000    1.000000         0.0
#
#        SNP_05_A A  SNP_05_C A  SNP_05_C C  SNP_06_A A  SNP_06_A G  SNP_06_G G  \
# count   79.000000   79.000000   79.000000   79.000000   79.000000   79.000000
# mean     0.405063    0.468354    0.126582    0.354430    0.518987    0.126582
# std      0.494041    0.502186    0.334629    0.481397    0.502832    0.334629
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# 75%      1.000000    1.000000    0.000000    1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP_07_A A  SNP_07_G A  SNP_07_G G  SNP_08_A A  SNP_08_G A  SNP_08_G G  \
# count   79.000000   79.000000        79.0   79.000000   79.000000   79.000000
# mean     0.734177    0.265823         0.0    0.265823    0.556962    0.177215
# std      0.444593    0.444593         0.0    0.444593    0.499919    0.384291
# min      0.000000    0.000000         0.0    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000         0.0    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000         0.0    0.000000    1.000000    0.000000
# 75%      1.000000    1.000000         0.0    1.000000    1.000000    0.000000
# max      1.000000    1.000000         0.0    1.000000    1.000000    1.000000
#
#        SNP_09_A A  SNP_09_G A  SNP_09_G G  SNP_10_A A  SNP_10_A G  SNP_10_G G  \
# count   79.000000   79.000000        79.0   79.000000   79.000000   79.000000
# mean     0.987342    0.012658         0.0    0.139241    0.379747    0.481013
# std      0.112509    0.112509         0.0    0.348409    0.488425    0.502832
# min      0.000000    0.000000         0.0    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000         0.0    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000         0.0    0.000000    0.000000    0.000000
# 75%      1.000000    0.000
000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP_11_A A  SNP_11_A G  SNP_11_G G  SNP_12_A A  SNP_12_G A  SNP_12_G G  \
# count  175.000000  175.000000  175.000000  175.000000  175.000000  175.000000
# mean     0.234286    0.388571    0.377143    0.531429    0.274286    0.194286
# std      0.424767    0.488824    0.486062    0.500443    0.447434    0.396785
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    1.000000    0.000000    0.000000
# 75%      0.000000    1.000000    1.000000    1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP_13_A A  SNP_13_A G  SNP_13_G G  SNP_14_A A  SNP_14_C A  SNP_14_C C  \
# count  175.000000  175.000000  175.000000  175.000000  175.000000  175.000000
# mean     0.234286    0.331429    0.434286    0.685714    0.188571    0.125714
# std      0.424767    0.472077    0.497085    0.465563    0.392290    0.332478
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    1.000000    0.000000    0.000000
# 75%      0.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        SNP_15_A A  SNP_15_G A  SNP_15_G G
# count  175.000000  175.000000  175.000000
# mean     0.388571    0.388571    0.222857
# std      0.488824    0.488824    0.417357
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000

# %%
class Autoencoder(nn.Module):
    def __init__(self, encoding_dim):
        super().__init__()
        self.encoding_dim = encoding_dim
        self.encoder = nn.Sequential(
            nn.Linear(45, 32),
            nn.GELU(),
            nn.Linear(32, 8),
            nn.GELU(),
            nn.Linear(8, encoding_dim),
            nn.GELU(),
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 8),
            nn.GELU(),
            nn.Linear(8, 32),
            nn.GELU(),
            nn.Linear(32, 45)
        )

    def forward(self, x):
        x1 = self.encoder(x)
        x2 = self.decoder(x1)
        return x1, x2

def ae_train(model, data_loader, criterion, optimizer, device, epochs=10):
    model.to(device)
    for epoch in range(epochs):
        epoch_loss = 0
        for x in data_loader:
            x = x[0].to(device)
            _, x_hat = model(x)
            loss = criterion(x_hat, x)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f'Epoch {epoch}: loss = {epoch_loss / len(data_loader):.4f}')

# %%
class VAE(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(VAE, self).__init__()
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, input_dim*2),
            nn.ReLU(),
            nn.Linear(input_dim*2, input_dim),
            nn.ReLU(),
            nn.Linear(input_dim, input_dim//2),
            nn.ReLU()
            )
        self.fc_mu = nn.Linear(input_dim//2, latent_dim)
        self.fc_logvar = nn.Linear(input_dim//2, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, input_dim//2),
            nn.ReLU(),
            nn.Linear(input_dim//2, input_dim),
            nn.ReLU(),
            nn.Linear(input_dim, input_dim*2),
            nn.ReLU(),
            nn.Linear(input_dim*2, input_dim)
        )

    def encode(self, x):
        h = self.encoder(x)
        return self.fc_mu(h), self.fc_logvar(h)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

def loss_fn(recon_x, x, mu, logvar):
    reconstruction_loss = F.mse_loss(recon_x, x, reduction='sum')
    kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return reconstruction_loss + kl_loss

def train(model, optimizer, train_loader, device):
    model.train()
    train_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss = loss_fn(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        
        optimizer.step()
        
    return train_loss / len(train_loader.dataset)

def test(model, test_loader, device):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)
            recon_batch, mu, logvar = model(data)
            test_loss += loss_fn(recon_batch, data, mu, logvar).item()
    return test_loss / len(test_loader.dataset)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X = torch.Tensor(train2.drop(columns=['class']).to_numpy())

# Create a dataset and data loader
dataset = torch.utils.data.TensorDataset(X)
data_loader = torch.utils.data.DataLoader(dataset, batch_size=256, shuffle=True)

# Initialize the model, criterion, and optimizer
encoding_dim = 12
model = Autoencoder(encoding_dim)
criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters())
epochs=1000

# Train the model
ae_train(model, data_loader, criterion, optimizer, device, epochs)
# Out:
# Epoch 0: loss = 0.3332
# Epoch 1: loss = 0.3306
# Epoch 2: loss = 0.3280
# Epoch 3: loss = 0.3255
# Epoch 4: loss = 0.3230
# Epoch 5: loss = 0.3206
# Epoch 6: loss = 0.3182
# Epoch 7: loss = 0.3158
# Epoch 8: loss = 0.3134
# Epoch 9: loss = 0.3110
# Epoch 10: loss = 0.3087
# Epoch 11: loss = 0.3064
# Epoch 12: loss = 0.3042
# Epoch 13: loss = 0.3019
# Epoch 14: loss = 0.2997
# Epoch 15: loss = 0.2975
# Epoch 16: loss = 0.2953
# Epoch 17: loss = 0.2931
# Epoch 18: loss = 0.2909
# Epoch 19: loss = 0.2887
# Epoch 20: loss = 0.2865
# Epoch 21: loss = 0.2844
# Epoch 22: loss = 0.2822
# Epoch 23: loss = 0.2800
# Epoch 24: loss = 0.2778
# Epoch 25: loss = 0.2756
# Epoch 26: loss = 0.2734
# Epoch 27: loss = 0.2711
# Epoch 28: loss = 0.2688
# Epoch 29: loss = 0.2665
# Epoch 30: loss = 0.2642
# Epoch 31: loss = 0.2618
# Epoch 32: loss = 0.2593
# Epoch 33: loss = 0.2568
# Epoch 34: loss = 0.2542
# Epoch 35: loss = 0.2516
# Epoch 36: loss = 0.2489
# Epoch 37: loss = 0.2462
# Epoch 38: loss = 0.2434
# Epoch 39: loss = 0.2406
# Epoch 40: loss = 0.2379
# Epoch 41: loss = 0.2351
# Epoch 42: loss = 0.2325
# Epoch 43: loss = 0.2300
# Epoch 44: loss = 0.2276
# Epoch 45: loss = 0.2255
# Epoch 46: loss = 0.2236
# Epoch 47: loss = 0.2220
# Epoch 48: loss = 0.2205
# Epoch 49: loss = 0.2192
# Epoch 50: loss = 0.2179
# Epoch 51: loss = 0.2166
# Epoch 52: loss = 0.2152
# Epoch 53: loss = 0.2138
# Epoch 54: loss = 0.2124
# Epoch 55: loss = 0.2110
# Epoch 56: loss = 0.2098
# Epoch 57: loss = 0.2086
# Epoch 58: loss = 0.2075
# Epoch 59: loss = 0.2066
# Epoch 60: loss = 0.2058
# Epoch 61: loss = 0.2050
# Epoch 62: loss = 0.2043
# Epoch 63: loss = 0.2037
# Epoch 64: loss = 0.2030
# Epoch 65: loss = 0.2024
# Epoch 66: loss = 0.2018
# Epoch 67: loss = 0.2012
# Epoch 68: loss = 0.2006
# Epoch 69: loss = 0.2001
# Epoch 70: loss = 0.1996
# Epoch 71: loss = 0.1991
# Epoch 72: loss = 0.1986
# Epoch 73: loss = 0.1981
# Epoch 74: loss = 0.1976
# Epoch 75: loss = 0.1971
# Epoch 76: loss = 0.1966
# Epoch 77: loss = 0.1961
# Epoch 78: loss = 0.1956
# Epoch 79: loss = 0.1951
# Epoch 80: loss = 0.1945
# Epoch 81: loss = 0.1939
# Epoch 82: loss = 0.1934
# Epoch 83: loss = 0.1928
# Epoch 84: loss = 0.1922
# Epoch 85: loss = 0.1916
# Epoch 86: loss = 0.1909
# Epoch 87: loss = 0.1903
# Epoch 88: loss = 0.1896
# Epoch 89: loss = 0.1889
# Epoch 90: loss = 0.1881
# Epoch 91: loss = 0.1873
# Epoch 92: loss = 0.1865
# Epoch 93: loss = 0.1857
# Epoch 94: loss = 0.1848
# Epoch 95: loss = 0.1839
# Epoch 96: loss = 0.1829
# Epoch 97: loss = 0.1819
# Epoch 98: loss = 0.1808
# Epoch 99: loss = 0.1798
# Epoch 100: loss = 0.1787
# Epoch 101: loss = 0.1775
# Epoch 102: loss = 0.1764
# Epoch 103: loss = 0.1752
# Epoch 104: loss = 0.1740
# Epoch 105: loss = 0.1728
# Epoch 106: loss = 0.1716
# Epoch 107: loss = 0.1704
# Epoch 108: loss = 0.1693
# Epoch 109: loss = 0.1681
# Epoch 110: loss = 0.1671
# Epoch 111: loss = 0.1660
# Epoch 112: loss = 0.1650
# Epoch 113: loss = 0.1641
# Epoch 114: loss = 0.1632
# Epoch 115: loss = 0.1625
# Epoch 116: loss = 0.1617
# Epoch 117: loss = 0.1610
# Epoch 118: loss = 0.1604
# Epoch 119: loss = 0.1598
# Epoch 120: loss = 0.1592
# Epoch 121: loss = 0.1586
# Epoch 122: loss = 0.1580
# Epoch 123: loss = 0.1574
# Epoch 124: loss = 0.1568
# Epoch 125: loss = 0.1562
# Epoch 126: loss = 0.1556
# Epoch 127: loss = 0.1551
# Epoch 128: loss = 0.1545
# Epoch 129: loss = 0.1540
# Epoch 130: loss = 0.1535
# Epoch 131: loss = 0.1530
# Epoch 132: loss = 0.1526
# Epoch 133: loss = 0.1522
# Epoch 134: loss = 0.1518
# Epoch 135: loss = 0.1514
# Epoch 136: loss = 0.1510
# Epoch 137: loss = 0.1507
# Epoch 138: loss = 0.1503
# Epoch 139: loss = 0.1500
# Epoch 140: loss = 0.1497
# Epoch 141: loss = 0.1494
# Epoch 142: loss = 0.1491
# Epoch 143: loss = 0.1488
# Epoch 144: loss = 0.1485
# Epoch 145: loss = 0.1482
# Epoch 146: loss = 0.1480
# Epoch 147: loss = 0.1477
# Epoch 148: loss = 0.1474
# Epoch 149: loss = 0.1472
# Epoch 150: loss = 0.1470
# Epoch 151: loss = 0.1467
# Epoch 152: loss = 0.1465
# Epoch 153: loss = 0.1462
# Epoch 154: loss = 0.1460
# Epoch 155: loss = 0.1457
# Epoch 156: loss = 0.1455
# Epoch 157: loss = 0.1453
# Epoch 158: loss = 0.1450
# Epoch 159: loss = 0.1448
# Epoch 160: loss = 0.1445
# Epoch 161: loss = 0.1443
# Epoch 162: loss = 0.1441
# Epoch 163: loss = 0.1439
# Epoch 164: loss = 0.1436
# Epoch 165: loss = 0.1434
# Epoch 166: loss = 0.1432
# Epoch 167: loss = 0.1429
# Epoch 168: loss = 0.1427
# Epoch 169: loss = 0.1425
# Epoch 170: loss = 0.1423
# Epoch 171: loss = 0.1421
# Epoch 172: loss = 0.1418
# Epoch 173: loss = 0.1416
# Epoch 174: loss = 0.1414
# Epoch 175: loss = 0.1412
# Epoch 176: loss = 0.1410
# Epoch 177: loss = 0.1408
# Epoch 178: loss = 0.1406
# Epoch 179: loss = 0.1404
# Epoch 180: loss = 0.1402
# Epoch 181: loss = 0.1400
# Epoch 182: loss = 0.1398
# Epoch 183: loss = 0.1396
# Epoch 184: loss = 0.1394
# Epoch 185: loss = 0.1392
# Epoch 186: loss = 0.1390
# Epoch 187: loss = 0.1388
# Epoch 188: loss = 0.1386
# Epoch 189: loss = 0.1385
# Epoch 190: loss = 0.1383
# Epoch 191: loss = 0.1381
# Epoch 192: loss = 0.1379
# Epoch 193: loss = 0.1377
# Epoch 194: loss = 0.1375
# Epoch 195: loss = 0.1373
# Epoch 196: loss = 0.1372
# Epoch 197: loss = 0.1370
# Epoch 198: loss = 0.1368
# Epoch 199: loss = 0.1366
# Epoch 200: loss = 0.1364
# Epoch 201: loss = 0.1363
# Epoch 202: loss = 0.1361
# Epoch 203: loss = 0.1359
# Epoch 204: loss = 0.1357
# Epoch 205: loss = 0.1356
# Epoch 206: loss = 0.1354
# Epoch 207: loss = 0.1352
# Epoch 208: loss = 0.1350
# Epoch 209: loss = 0.1349
# Epoch 210: loss = 0.1347
# Epoch 211: loss = 0.1345
# Epoch 212: loss = 0.1344
# Epoch 213: loss = 0.1342
# Epoch 214: loss = 0.1340
# Epoch 215: loss = 0.1339
# Epoch 216: loss = 0.1337
# Epoch 217: loss = 0.1335
# Epoch 218: loss = 0.1334
# Epoch 219: loss = 0.1332
# Epoch 220: loss = 0.1331
# Epoch 221: loss = 0.1329
# Epoch 222: loss = 0.1328
# Epoch 223: loss = 0.1326
# Epoch 224: loss = 0.1325
# Epoch 225: loss = 0.1323
# Epoch 226: loss = 0.1322
# Epoch 227: loss = 0.1320
# Epoch 228: loss = 0.1319
# Epoch 229: loss = 0.1317
# Epoch 230: loss = 0.1316
# Epoch 231: loss = 0.1314
# Epoch 232: loss = 0.1313
# Epoch 233: loss = 0.1311
# Epoch 234: loss = 0.1310
# Epoch 235: loss = 0.1308
# Epoch 236: loss = 0.1307
# Epoch 237: loss = 0.1305
# Epoch 238: loss = 0.1304
# Epoch 239: loss = 0.1303
# Epoch 240: loss = 0.1301
# Epoch 241: loss = 0.1300
# Epoch 242: loss = 0.1298
# Epoch 243: loss = 0.1297
# Epoch 244: loss = 0.1295
# Epoch 245: loss = 0.1294
# Epoch 246: loss = 0.1292
# Epoch 247: loss = 0.1290
# Epoch 248: loss = 0.1289
# Epoch 249: loss = 0.1287
# Epoch 250: loss = 0.1286
# Epoch 251: loss = 0.1284
# Epoch 252: loss = 0.1283
# Epoch 253: loss = 0.1281
# Epoch 254: loss = 0.1279
# Epoch 255: loss = 0.1278
# Epoch 256: loss = 0.1276
# Epoch 257: loss = 0.1274
# Epoch 258: loss = 0.1273
# Epoch 259: loss = 0.1271
# Epoch 260: loss = 0.1269
# Epoch 261: loss = 0.1267
# Epoch 262: loss = 0.1266
# Epoch 263: loss = 0.1264
# Epoch 264: loss = 0.1262
# Epoch 265: loss = 0.1260
# Epoch 266: loss = 0.1258
# Epoch 267: loss = 0.1256
# Epoch 268: loss = 0.1254
# Epoch 269: loss = 0.1252
# Epoch 270: loss = 0.1250
# Epoch 271: loss = 0.1248
# Epoch 272: loss = 0.1246
# Epoch 273: loss = 0.1244
# Epoch 274: loss = 0.1241
# Epoch 275: loss = 0.1239
# Epoch 276: loss = 0.1237
# Epoch 277: loss = 0.1235
# Epoch 278: loss = 0.1232
# Epoch 279: loss = 0.1230
# Epoch 280: loss = 0.1228
# Epoch 281: loss = 0.1226
# Epoch 282: loss = 0.1224
# Epoch 283: loss = 0.1222
# Epoch 284: loss = 0.1219
# Epoch 285: loss = 0.1217
# Epoch 286: loss = 0.1215
# Epoch 287: loss = 0.1213
# Epoch 288: loss = 0.1211
# Epoch 289: loss = 0.1209
# Epoch 290: loss = 0.1207
# Epoch 291: loss = 0.1205
# Epoch 292: loss = 0.1203
# Epoch 293: loss = 0.1201
# Epoch 294: loss = 0.1200
# Epoch 295: loss = 0.1198
# Epoch 296: loss = 0.1197
# Epoch 297: loss = 0.1194
# Epoch 298: loss = 0.1192
# Epoch 299: loss = 0.1190
# Epoch 300: loss = 0.1188
# Epoch 301: loss = 0.1186
# Epoch 302: loss = 0.1184
# Epoch 303: loss = 0.1182
# Epoch 304: loss = 0.1181
# Epoch 305: loss = 0.1179
# Epoch 306: loss = 0.1177
# Epoch 307: loss = 0.1175
# Epoch 308: loss = 0.1173
# Epoch 309: loss = 0.1171
# Epoch 310: loss = 0.1169
# Epoch 311: loss = 0.1168
# Epoch 312: loss = 0.1166
# Epoch 313: loss = 0.1164
# Epoch 314: loss = 0.1162
# Epoch 315: loss = 0.1160
# Epoch 316: loss = 0.1159
# Epoch 317: loss = 0.1157
# Epoch 318: loss = 0.1155
# Epoch 319: loss = 0.1153
# Epoch 320: loss = 0.1151
# Epoch 321: loss = 0.1149
# Epoch 322: loss = 0.1148
# Epoch 323: loss = 0.1146
# Epoch 324: loss = 0.1144
# Epoch 325: loss = 0.1142
# Epoch 326: loss = 0.1141
# Epoch 327: loss = 0.1139
# Epoch 328: loss = 0.1137
# Epoch 329: loss = 0.1135
# Epoch 330: loss = 0.1134
# Epoch 331: loss = 0.1132
# Epoch 332: loss = 0.1130
# Epoch 333: loss = 0.1128
# Epoch 334: loss = 0.1127
# Epoch 335: loss = 0.1125
# Epoch 336: loss = 0.1123
# Epoch 337: loss = 0.1122
# Epoch 338: loss = 0.1120
# Epoch 339: loss = 0.1119
# Epoch 340: loss = 0.1117
# Epoch 341: loss = 0.1115
# Epoch 342: loss = 0.1114
# Epoch 343: loss = 0.1112
# Epoch 344: loss = 0.1110
# Epoch 345: loss = 0.1109
# Epoch 346: loss = 0.1107
# Epoch 347: loss = 0.1106
# Epoch 348: loss = 0.1104
# Epoch 349: loss = 0.1102
# Epoch 350: loss = 0.1101
# Epoch 351: loss = 0.1099
# Epoch 352: loss = 0.1098
# Epoch 353: loss = 0.1096
# Epoch 354: loss = 0.1094
# Epoch 355: loss = 0.1093
# Epoch 356: loss = 0.1091
# Epoch 357: loss = 0.1090
# Epoch 358: loss = 0.1088
# Epoch 359: loss = 0.1087
# Epoch 360: loss = 0.1085
# Epoch 361: loss = 0.1083
# Epoch 362: loss = 0.1082
# Epoch 363: loss = 0.1080
# Epoch 364: loss = 0.1079
# Epoch 365: loss = 0.1077
# Epoch 366: loss = 0.1076
# Epoch 367: loss = 0.1074
# Epoch 368: loss = 0.1073
# Epoch 369: loss = 0.1071
# Epoch 370: loss = 0.1070
# Epoch 371: loss = 0.1069
# Epoch 372: loss = 0.1067
# Epoch 373: loss = 0.1066
# Epoch 374: loss = 0.1064
# Epoch 375: loss = 0.1063
# Epoch 376: loss = 0.1061
# Epoch 377: loss = 0.1060
# Epoch 378: loss = 0.1059
# Epoch 379: loss = 0.1057
# Epoch 380: loss = 0.1056
# Epoch 381: loss = 0.1055
# Epoch 382: loss = 0.1053
# Epoch 383: loss = 0.1052
# Epoch 384: loss = 0.1051
# Epoch 385: loss = 0.1050
# Epoch 386: loss = 0.1049
# Epoch 387: loss = 0.1048
# Epoch 388: loss = 0.1047
# Epoch 389: loss = 0.1045
# Epoch 390: loss = 0.1043
# Epoch 391: loss = 0.1042
# Epoch 392: loss = 0.1042
# Epoch 393: loss = 0.1040
# Epoch 394: loss = 0.1039
# Epoch 395: loss = 0.1038
# Epoch 396: loss = 0.1037
# Epoch 397: loss = 0.1036
# Epoch 398: loss = 0.1034
# Epoch 399: loss = 0.1033
# Epoch 400: loss = 0.1033
# Epoch 401: loss = 0.1031
# Epoch 402: loss = 0.1030
# Epoch 403: loss = 0.1029
# Epoch 404: loss = 0.1028
# Epoch 405: loss = 0.1027
# Epoch 406: loss = 0.1026
# Epoch 407: loss = 0.1025
# Epoch 408: loss = 0.1024
# Epoch 409: loss = 0.1023
# Epoch 410: loss = 0.1022
# Epoch 411: loss = 0.1021
# Epoch 412: loss = 0.1020
# Epoch 413: loss = 0.1020
# Epoch 414: loss = 0.1019
# Epoch 415: loss = 0.1018
# Epoch 416: loss = 0.1017
# Epoch 417: loss = 0.1016
# Epoch 418: loss = 0.1015
# Epoch 419: loss = 0.1014
# Epoch 420: loss = 0.1013
# Epoch 421: loss = 0.1013
# Epoch 422: loss = 0.1012
# Epoch 423: loss = 0.1011
# Epoch 424: loss = 0.1010
# Epoch 425: loss = 0.1009
# Epoch 426: loss = 0.1008
# Epoch 427: loss = 0.1008
# Epoch 428: loss = 0.1007
# Epoch 429: loss = 0.1006
# Epoch 430: loss = 0.1005
# Epoch 431: loss = 0.1004
# Epoch 432: loss = 0.1004
# Epoch 433: loss = 0.1003
# Epoch 434: loss = 0.1002
# Epoch 435: loss = 0.1001
# Epoch 436: loss = 0.1001
# Epoch 437: loss = 0.1000
# Epoch 438: loss = 0.0999
# Epoch 439: loss = 0.0998
# Epoch 440: loss = 0.0998
# Epoch 441: loss = 0.0997
# Epoch 442: loss = 0.0996
# Epoch 443: loss = 0.0995
# Epoch 444: loss = 0.0995
# Epoch 445: loss = 0.0994
# Epoch 446: loss = 0.0993
# Epoch 447: loss = 0.0993
# Epoch 448: loss = 0.0992
# Epoch 449: loss = 0.0991
# Epoch 450: loss = 0.0991
# Epoch 451: loss = 0.0990
# Epoch 452: loss = 0.0989
# Epoch 453: loss = 0.0989
# Epoch 454: loss = 0.0988
# Epoch 455: loss = 0.0987
# Epoch 456: loss = 0.0987
# Epoch 457: loss = 0.0986
# Epoch 458: loss = 0.0985
# Epoch 459: loss = 0.0985
# Epoch 460: loss = 0.0984
# Epoch 461: loss = 0.0983
# Epoch 462: loss = 0.0983
# Epoch 463: loss = 0.0982
# Epoch 464: loss = 0.0981
# Epoch 465: loss = 0.0981
# Epoch 466: loss = 0.0980
# Epoch 467: loss = 0.0980
# Epoch 468: loss = 0.0979
# Epoch 469: loss = 0.0978
# Epoch 470: loss = 0.0978
# Epoch 471: loss = 0.0977
# Epoch 472: loss = 0.0977
# Epoch 473: loss = 0.0976
# Epoch 474: loss = 0.0976
# Epoch 475: loss = 0.0976
# Epoch 476: loss = 0.0975
# Epoch 477: loss = 0.0974
# Epoch 478: loss = 0.0973
# Epoch 479: loss = 0.0973
# Epoch 480: loss = 0.0972
# Epoch 481: loss = 0.0972
# Epoch 482: loss = 0.0971
# Epoch 483: loss = 0.0971
# Epoch 484: loss = 0.0970
# Epoch 485: loss = 0.0969
# Epoch 486: loss = 0.0969
# Epoch 487: loss = 0.0969
# Epoch 488: loss = 0.0968
# Epoch 489: loss = 0.0967
# Epoch 490: loss = 0.0967
# Epoch 491: loss = 0.0966
# Epoch 492: loss = 0.0966
# Epoch 493: loss = 0.0965
# Epoch 494: loss = 0.0965
# Epoch 495: loss = 0.0964
# Epoch 496: loss = 0.0964
# Epoch 497: loss = 0.0963
# Epoch 498: loss = 0.0963
# Epoch 499: loss = 0.0962
# Epoch 500: loss = 0.0962
# Epoch 501: loss = 0.0961
# Epoch 502: loss = 0.0961
# Epoch 503: loss = 0.0960
# Epoch 504: loss = 0.0960
# Epoch 505: loss = 0.0959
# Epoch 506: loss = 0.0959
# Epoch 507: loss = 0.0958
# Epoch 508: loss = 0.0958
# Epoch 509: loss = 0.0957
# Epoch 510: loss = 0.0957
# Epoch 511: loss = 0.0956
# Epoch 512: loss = 0.0956
# Epoch 513: loss = 0.0956
# Epoch 514: loss = 0.0955
# Epoch 515: loss = 0.0955
# Epoch 516: loss = 0.0954
# Epoch 517: loss = 0.0954
# Epoch 518: loss = 0.0953
# Epoch 519: loss = 0.0953
# Epoch 520: loss = 0.0952
# Epoch 521: loss = 0.0952
# Epoch 522: loss = 0.0951
# Epoch 523: loss = 0.0951
# Epoch 524: loss = 0.0951
# Epoch 525: loss = 0.0950
# Epoch 526: loss = 0.0950
# Epoch 527: loss = 0.0949
# Epoch 528: loss = 0.0949
# Epoch 529: loss = 0.0948
# Epoch 530: loss = 0.0948
# Epoch 531: loss = 0.0947
# Epoch 532: loss = 0.0947
# Epoch 533: loss = 0.0947
# Epoch 534: loss = 0.0946
# Epoch 535: loss = 0.0946
# Epoch 536: loss = 0.0945
# Epoch 537: loss = 0.0945
# Epoch 538: loss = 0.0945
# Epoch 539: loss = 0.0944
# Epoch 540: loss = 0.0944
# Epoch 541: loss = 0.0943
# Epoch 542: loss = 0.0943
# Epoch 543: loss = 0.0943
# Epoch 544: loss = 0.0942
# Epoch 545: loss = 0.0942
# Epoch 546: loss = 0.0942
# Epoch 547: loss = 0.0941
# Epoch 548: loss = 0.0941
# Epoch 549: loss = 0.0940
# Epoch 550: loss = 0.0940
# Epoch 551: loss = 0.0939
# Epoch 552: loss = 0.0939
# Epoch 553: loss = 0.0939
# Epoch 554: loss = 0.0938
# Epoch 555: loss = 0.0938
# Epoch 556: loss = 0.0937
# Epoch 557: loss = 0.0937
# Epoch 558: loss = 0.0937
# Epoch 559: loss = 0.0936
# Epoch 560: loss = 0.0936
# Epoch 561: loss = 0.0936
# Epoch 562: loss = 0.0935
# Epoch 563: loss = 0.0935
# Epoch 564: loss = 0.0934
# Epoch 565: loss = 0.0934
# Epoch 566: loss = 0.0934
# Epoch 567: loss = 0.0933
# Epoch 568: loss = 0.0933
# Epoch 569: loss = 0.0933
# Epoch 570: loss = 0.0932
# Epoch 571: loss = 0.0932
# Epoch 572: loss = 0.0931
# Epoch 573: loss = 0.0931
# Epoch 574: loss = 0.0931
# Epoch 575: loss = 0.0930
# Epoch 576: loss = 0.0930
# Epoch 577: loss = 0.0930
# Epoch 578: loss = 0.0929
# Epoch 579: loss = 0.0929
# Epoch 580: loss = 0.0929
# Epoch 581: loss = 0.0928
# Epoch 582: loss = 0.0928
# Epoch 583: loss = 0.0928
# Epoch 584: loss = 0.0927
# Epoch 585: loss = 0.0927
# Epoch 586: loss = 0.0926
# Epoch 587: loss = 0.0926
# Epoch 588: loss = 0.0926
# Epoch 589: loss = 0.0925
# Epoch 590: loss = 0.0925
# Epoch 591: loss = 0.0925
# Epoch 592: loss = 0.0924
# Epoch 593: loss = 0.0924
# Epoch 594: loss = 0.0924
# Epoch 595: loss = 0.0923
# Epoch 596: loss = 0.0923
# Epoch 597: loss = 0.0923
# Epoch 598: loss = 0.0922
# Epoch 599: loss = 0.0922
# Epoch 600: loss = 0.0922
# Epoch 601: loss = 0.0921
# Epoch 602: loss = 0.0921
# Epoch 603: loss = 0.0921
# Epoch 604: loss = 0.0920
# Epoch 605: loss = 0.0920
# Epoch 606: loss = 0.0920
# Epoch 607: loss = 0.0919
# Epoch 608: loss = 0.0919
# Epoch 609: loss = 0.0919
# Epoch 610: loss = 0.0918
# Epoch 611: loss = 0.0918
# Epoch 612: loss = 0.0918
# Epoch 613: loss = 0.0917
# Epoch 614: loss = 0.0917
# Epoch 615: loss = 0.0917
# Epoch 616: loss = 0.0916
# Epoch 617: loss = 0.0916
# Epoch 618: loss = 0.0916
# Epoch 619: loss = 0.0915
# Epoch 620: loss = 0.0915
# Epoch 621: loss = 0.0914
# Epoch 622: loss = 0.0914
# Epoch 623: loss = 0.0914
# Epoch 624: loss = 0.0913
# Epoch 625: loss = 0.0913
# Epoch 626: loss = 0.0913
# Epoch 627: loss = 0.0912
# Epoch 628: loss = 0.0912
# Epoch 629: loss = 0.0911
# Epoch 630: loss = 0.0911
# Epoch 631: loss = 0.0911
# Epoch 632: loss = 0.0910
# Epoch 633: loss = 0.0910
# Epoch 634: loss = 0.0910
# Epoch 635: loss = 0.0909
# Epoch 636: loss = 0.0909
# Epoch 637: loss = 0.0909
# Epoch 638: loss = 0.0908
# Epoch 639: loss = 0.0908
# Epoch 640: loss = 0.0908
# Epoch 641: loss = 0.0907
# Epoch 642: loss = 0.0907
# Epoch 643: loss = 0.0907
# Epoch 644: loss = 0.0907
# Epoch 645: loss = 0.0906
# Epoch 646: loss = 0.0905
# Epoch 647: loss = 0.0905
# Epoch 648: loss = 0.0904
# Epoch 649: loss = 0.0904
# Epoch 650: loss = 0.0904
# Epoch 651: loss = 0.0903
# Epoch 652: loss = 0.0903
# Epoch 653: loss = 0.0902
# Epoch 654: loss = 0.0902
# Epoch 655: loss = 0.0902
# Epoch 656: loss = 0.0901
# Epoch 657: loss = 0.0901
# Epoch 658: loss = 0.0900
# Epoch 659: loss = 0.0900
# Epoch 660: loss = 0.0899
# Epoch 661: loss = 0.0899
# Epoch 662: loss = 0.0899
# Epoch 663: loss = 0.0898
# Epoch 664: loss = 0.0898
# Epoch 665: loss = 0.0897
# Epoch 666: loss = 0.0897
# Epoch 667: loss = 0.0897
# Epoch 668: loss = 0.0896
# Epoch 669: loss = 0.0896
# Epoch 670: loss = 0.0895
# Epoch 671: loss = 0.0895
# Epoch 672: loss = 0.0894
# Epoch 673: loss = 0.0894
# Epoch 674: loss = 0.0894
# Epoch 675: loss = 0.0893
# Epoch 676: loss = 0.0893
# Epoch 677: loss = 0.0892
# Epoch 678: loss = 0.0892
# Epoch 679: loss = 0.0891
# Epoch 680: loss = 0.0891
# Epoch 681: loss = 0.0890
# Epoch 682: loss = 0.0890
# Epoch 683: loss = 0.0889
# Epoch 684: loss = 0.0889
# Epoch 685: loss = 0.0889
# Epoch 686: loss = 0.0888
# Epoch 687: loss = 0.0888
# Epoch 688: loss = 0.0887
# Epoch 689: loss = 0.0887
# Epoch 690: loss = 0.0886
# Epoch 691: loss = 0.0886
# Epoch 692: loss = 0.0885
# Epoch 693: loss = 0.0885
# Epoch 694: loss = 0.0884
# Epoch 695: loss = 0.0884
# Epoch 696: loss = 0.0884
# Epoch 697: loss = 0.0883
# Epoch 698: loss = 0.0883
# Epoch 699: loss = 0.0882
# Epoch 700: loss = 0.0882
# Epoch 701: loss = 0.0881
# Epoch 702: loss = 0.0881
# Epoch 703: loss = 0.0880
# Epoch 704: loss = 0.0880
# Epoch 705: loss = 0.0879
# Epoch 706: loss = 0.0879
# Epoch 707: loss = 0.0878
# Epoch 708: loss = 0.0878
# Epoch 709: loss = 0.0878
# Epoch 710: loss = 0.0877
# Epoch 711: loss = 0.0877
# Epoch 712: loss = 0.0876
# Epoch 713: loss = 0.0876
# Epoch 714: loss = 0.0875
# Epoch 715: loss = 0.0875
# Epoch 716: loss = 0.0874
# Epoch 717: loss = 0.0874
# Epoch 718: loss = 0.0873
# Epoch 719: loss = 0.0873
# Epoch 720: loss = 0.0872
# Epoch 721: loss = 0.0872
# Epoch 722: loss = 0.0872
# Epoch 723: loss = 0.0871
# Epoch 724: loss = 0.0871
# Epoch 725: loss = 0.0871
# Epoch 726: loss = 0.0870
# Epoch 727: loss = 0.0869
# Epoch 728: loss = 0.0869
# Epoch 729: loss = 0.0868
# Epoch 730: loss = 0.0868
# Epoch 731: loss = 0.0868
# Epoch 732: loss = 0.0867
# Epoch 733: loss = 0.0867
# Epoch 734: loss = 0.0866
# Epoch 735: loss = 0.0866
# Epoch 736: loss = 0.0865
# Epoch 737: loss = 0.0865
# Epoch 738: loss = 0.0864
# Epoch 739: loss = 0.0864
# Epoch 740: loss = 0.0863
# Epoch 741: loss = 0.0863
# Epoch 742: loss = 0.0862
# Epoch 743: loss = 0.0862
# Epoch 744: loss = 0.0862
# Epoch 745: loss = 0.0861
# Epoch 746: loss = 0.0861
# Epoch 747: loss = 0.0860
# Epoch 748: loss = 0.0860
# Epoch 749: loss = 0.0859
# Epoch 750: loss = 0.0859
# Epoch 751: loss = 0.0859
# Epoch 752: loss = 0.0858
# Epoch 753: loss = 0.0858
# Epoch 754: loss = 0.0857
# Epoch 755: loss = 0.0857
# Epoch 756: loss = 0.0856
# Epoch 757: loss = 0.0856
# Epoch 758: loss = 0.0856
# Epoch 759: loss = 0.0855
# Epoch 760: loss = 0.0855
# Epoch 761: loss = 0.0854
# Epoch 762: loss = 0.0854
# Epoch 763: loss = 0.0854
# Epoch 764: loss = 0.0853
# Epoch 765: loss = 0.0853
# Epoch 766: loss = 0.0852
# Epoch 767: loss = 0.0852
# Epoch 768: loss = 0.0851
# Epoch 769: loss = 0.0851
# Epoch 770: loss = 0.0851
# Epoch 771: loss = 0.0850
# Epoch 772: loss = 0.0850
# Epoch 773: loss = 0.0849
# Epoch 774: loss = 0.0849
# Epoch 775: loss = 0.0849
# Epoch 776: loss = 0.0848
# Epoch 777: loss = 0.0848
# Epoch 778: loss = 0.0847
# Epoch 779: loss = 0.0847
# Epoch 780: loss = 0.0847
# Epoch 781: loss = 0.0846
# Epoch 782: loss = 0.0846
# Epoch 783: loss = 0.0845
# Epoch 784: loss = 0.0845
# Epoch 785: loss = 0.0845
# Epoch 786: loss = 0.0844
# Epoch 787: loss = 0.0844
# Epoch 788: loss = 0.0843
# Epoch 789: loss = 0.0843
# Epoch 790: loss = 0.0843
# Epoch 791: loss = 0.0842
# Epoch 792: loss = 0.0842
# Epoch 793: loss = 0.0841
# Epoch 794: loss = 0.0841
# Epoch 795: loss = 0.0841
# Epoch 796: loss = 0.0840
# Epoch 797: loss = 0.0840
# Epoch 798: loss = 0.0839
# Epoch 799: loss = 0.0839
# Epoch 800: loss = 0.0839
# Epoch 801: loss = 0.0838
# Epoch 802: loss = 0.0838
# Epoch 803: loss = 0.0838
# Epoch 804: loss = 0.0837
# Epoch 805: loss = 0.0837
# Epoch 806: loss = 0.0836
# Epoch 807: loss = 0.0836
# Epoch 808: loss = 0.0836
# Epoch 809: loss = 0.0835
# Epoch 810: loss = 0.0835
# Epoch 811: loss = 0.0835
# Epoch 812: loss = 0.0834
# Epoch 813: loss = 0.0834
# Epoch 814: loss = 0.0834
# Epoch 815: loss = 0.0833
# Epoch 816: loss = 0.0833
# Epoch 817: loss = 0.0833
# Epoch 818: loss = 0.0832
# Epoch 819: loss = 0.0832
# Epoch 820: loss = 0.0832
# Epoch 821: loss = 0.0831
# Epoch 822: loss = 0.0831
# Epoch 823: loss = 0.0830
# Epoch 824: loss = 0.0830
# Epoch 825: loss = 0.0830
# Epoch 826: loss = 0.0829
# Epoch 827: loss = 0.0829
# Epoch 828: loss = 0.0828
# Epoch 829: loss = 0.0828
# Epoch 830: loss = 0.0828
# Epoch 831: loss = 0.0827
# Epoch 832: loss = 0.0827
# Epoch 833: loss = 0.0827
# Epoch 834: loss = 0.0826
# Epoch 835: loss = 0.0826
# Epoch 836: loss = 0.0825
# Epoch 837: loss = 0.0825
# Epoch 838: loss = 0.0825
# Epoch 839: loss = 0.0824
# Epoch 840: loss = 0.0824
# Epoch 841: loss = 0.0824
# Epoch 842: loss = 0.0823
# Epoch 843: loss = 0.0823
# Epoch 844: loss = 0.0823
# Epoch 845: loss = 0.0822
# Epoch 846: loss = 0.0822
# Epoch 847: loss = 0.0822
# Epoch 848: loss = 0.0821
# Epoch 849: loss = 0.0821
# Epoch 850: loss = 0.0821
# Epoch 851: loss = 0.0820
# Epoch 852: loss = 0.0820
# Epoch 853: loss = 0.0820
# Epoch 854: loss = 0.0819
# Epoch 855: loss = 0.0819
# Epoch 856: loss = 0.0819
# Epoch 857: loss = 0.0818
# Epoch 858: loss = 0.0818
# Epoch 859: loss = 0.0818
# Epoch 860: loss = 0.0817
# Epoch 861: loss = 0.0817
# Epoch 862: loss = 0.0817
# Epoch 863: loss = 0.0816
# Epoch 864: loss = 0.0816
# Epoch 865: loss = 0.0815
# Epoch 866: loss = 0.0815
# Epoch 867: loss = 0.0815
# Epoch 868: loss = 0.0814
# Epoch 869: loss = 0.0814
# Epoch 870: loss = 0.0814
# Epoch 871: loss = 0.0813
# Epoch 872: loss = 0.0813
# Epoch 873: loss = 0.0813
# Epoch 874: loss = 0.0812
# Epoch 875: loss = 0.0812
# Epoch 876: loss = 0.0812
# Epoch 877: loss = 0.0811
# Epoch 878: loss = 0.0811
# Epoch 879: loss = 0.0811
# Epoch 880: loss = 0.0810
# Epoch 881: loss = 0.0810
# Epoch 882: loss = 0.0810
# Epoch 883: loss = 0.0809
# Epoch 884: loss = 0.0809
# Epoch 885: loss = 0.0809
# Epoch 886: loss = 0.0808
# Epoch 887: loss = 0.0808
# Epoch 888: loss = 0.0808
# Epoch 889: loss = 0.0807
# Epoch 890: loss = 0.0807
# Epoch 891: loss = 0.0807
# Epoch 892: loss = 0.0806
# Epoch 893: loss = 0.0806
# Epoch 894: loss = 0.0806
# Epoch 895: loss = 0.0805
# Epoch 896: loss = 0.0805
# Epoch 897: loss = 0.0805
# Epoch 898: loss = 0.0804
# Epoch 899: loss = 0.0804
# Epoch 900: loss = 0.0804
# Epoch 901: loss = 0.0804
# Epoch 902: loss = 0.0803
# Epoch 903: loss = 0.0803
# Epoch 904: loss = 0.0803
# Epoch 905: loss = 0.0802
# Epoch 906: loss = 0.0802
# Epoch 907: loss = 0.0802
# Epoch 908: loss = 0.0801
# Epoch 909: loss = 0.0801
# Epoch 910: loss = 0.0800
# Epoch 911: loss = 0.0800
# Epoch 912: loss = 0.0800
# Epoch 913: loss = 0.0800
# Epoch 914: loss = 0.0799
# Epoch 915: loss = 0.0799
# Epoch 916: loss = 0.0799
# Epoch 917: loss = 0.0798
# Epoch 918: loss = 0.0798
# Epoch 919: loss = 0.0798
# Epoch 920: loss = 0.0797
# Epoch 921: loss = 0.0797
# Epoch 922: loss = 0.0797
# Epoch 923: loss = 0.0796
# Epoch 924: loss = 0.0796
# Epoch 925: loss = 0.0796
# Epoch 926: loss = 0.0795
# Epoch 927: loss = 0.0795
# Epoch 928: loss = 0.0795
# Epoch 929: loss = 0.0794
# Epoch 930: loss = 0.0794
# Epoch 931: loss = 0.0794
# Epoch 932: loss = 0.0793
# Epoch 933: loss = 0.0793
# Epoch 934: loss = 0.0793
# Epoch 935: loss = 0.0793
# Epoch 936: loss = 0.0792
# Epoch 937: loss = 0.0792
# Epoch 938: loss = 0.0792
# Epoch 939: loss = 0.0791
# Epoch 940: loss = 0.0791
# Epoch 941: loss = 0.0791
# Epoch 942: loss = 0.0790
# Epoch 943: loss = 0.0790
# Epoch 944: loss = 0.0790
# Epoch 945: loss = 0.0789
# Epoch 946: loss = 0.0789
# Epoch 947: loss = 0.0789
# Epoch 948: loss = 0.0788
# Epoch 949: loss = 0.0788
# Epoch 950: loss = 0.0788
# Epoch 951: loss = 0.0788
# Epoch 952: loss = 0.0787
# Epoch 953: loss = 0.0787
# Epoch 954: loss = 0.0787
# Epoch 955: loss = 0.0786
# Epoch 956: loss = 0.0786
# Epoch 957: loss = 0.0786
# Epoch 958: loss = 0.0785
# Epoch 959: loss = 0.0785
# Epoch 960: loss = 0.0785
# Epoch 961: loss = 0.0784
# Epoch 962: loss = 0.0784
# Epoch 963: loss = 0.0784
# Epoch 964: loss = 0.0783
# Epoch 965: loss = 0.0783
# Epoch 966: loss = 0.0783
# Epoch 967: loss = 0.0782
# Epoch 968: loss = 0.0782
# Epoch 969: loss = 0.0782
# Epoch 970: loss = 0.0782
# Epoch 971: loss = 0.0781
# Epoch 972: loss = 0.0781
# Epoch 973: loss = 0.0781
# Epoch 974: loss = 0.0780
# Epoch 975: loss = 0.0780
# Epoch 976: loss = 0.0780
# Epoch 977: loss = 0.0779
# Epoch 978: loss = 0.0779
# Epoch 979: loss = 0.0779
# Epoch 980: loss = 0.0779
# Epoch 981: loss = 0.0778
# Epoch 982: loss = 0.0778
# Epoch 983: loss = 0.0778
# Epoch 984: loss = 0.0777
# Epoch 985: loss = 0.0777
# Epoch 986: loss = 0.0777
# Epoch 987: loss = 0.0776
# Epoch 988: loss = 0.0776
# Epoch 989: loss = 0.0776
# Epoch 990: loss = 0.0775
# Epoch 991: loss = 0.0775
# Epoch 992: loss = 0.0775
# Epoch 993: loss = 0.0774
# Epoch 994: loss = 0.0774
# Epoch 995: loss = 0.0774
# Epoch 996: loss = 0.0773
# Epoch 997: loss = 0.0773
# Epoch 998: loss = 0.0773
# Epoch 999: loss = 0.0772

# %%
X1 = X.to(device)
X2 = torch.Tensor(test2.to_numpy()).to(device)

pred_train = model(X1)
pred_test = model(X2)

# reconstruction error
loss_train = []
loss_test = []

for i in range(len(X1)) :
    loss = criterion(pred_train[1][i], X1[i]).detach().cpu().numpy()
    loss_train.append(loss)
for j in range(len(X2)) :
    loss = criterion(pred_test[1][j], X2[j]).detach().cpu().numpy()
    loss_test.append(loss)

# encoding values
enco_train = pred_train[0].detach().cpu().numpy()
enco_test = pred_test[0].detach().cpu().numpy()

trainLoss = pd.DataFrame(data=loss_train, columns=['ae_loss'])
testLoss = pd.DataFrame(data=loss_test, columns=['ae_loss'])

ae_train = pd.DataFrame(data=enco_train, columns=['ae_'+str(x) for x in range(enco_train.shape[1])])
ae_test = pd.DataFrame(data=enco_test, columns=['ae_'+str(x) for x in range(enco_train.shape[1])])

train3 = pd.concat([train2, trainLoss, ae_train], axis=1)
test3 = pd.concat([test2, testLoss, ae_test], axis=1)

train3.info(), test3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 59 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  256 non-null    uint8
#  1   SNP_01_A G  256 non-null    uint8
#  2   SNP_01_G G  256 non-null    uint8
#  3   SNP_02_A A  256 non-null    uint8
#  4   SNP_02_A G  256 non-null    uint8
#  5   SNP_02_G G  256 non-null    uint8
#  6   SNP_03_A A  256 non-null    uint8
#  7   SNP_03_C A  256 non-null    uint8
#  8   SNP_03_C C  256 non-null    uint8
#  9   SNP_04_A A  256 non-null    uint8
#  10  SNP_04_G A  256 non-null    uint8
#  11  SNP_04_G G  256 non-null    uint8
#  12  SNP_05_A A  256 non-null    uint8
#  13  SNP_05_C A  256 non-null    uint8
#  14  SNP_05_C C  256 non-null    uint8
#  15  SNP_06_A A  256 non-null    uint8
#  16  SNP_06_A G  256 non-null    uint8
#  17  SNP_06_G G  256 non-null    uint8
#  18  SNP_07_A A  256 non-null    uint8
#  19  SNP_07_G A  256 non-null    uint8
#  20  SNP_07_G G  256 non-null    uint8
#  21  SNP_08_A A  256 non-null    uint8
#  22  SNP_08_G A  256 non-null    uint8
#  23  SNP_08_G G  256 non-null    uint8
#  24  SNP_09_A A  256 non-null    uint8
#  25  SNP_09_G A  256 non-null    uint8
#  26  SNP_09_G G  256 non-null    uint8
#  27  SNP_10_A A  256 non-null    uint8
#  28  SNP_10_A G  256 non-null    uint8
#  29  SNP_10_G G  256 non-null    uint8
#  30  SNP_11_A A  256 non-null    uint8
#  31  SNP_11_A G  256 non-null    uint8
#  32  SNP_11_G G  256 non-null    uint8
#  33  SNP_12_A A  256 non-null    uint8
#  34  SNP_12_G A  256 non-null    uint8
#  35  SNP_12_G G  256 non-null    uint8
#  36  SNP_13_A A  256 non-null    uint8
#  37  SNP_13_A G  256 non-null    uint8
#  38  SNP_13_G G  256 non-null    uint8
#  39  SNP_14_A A  256 non-null    uint8
#  40  SNP_14_C A  256 non-null    uint8
#  41  SNP_14_C C  256 non-null    uint8
#  42  SNP_15_A A  256 non-null    uint8
#  43  SNP_15_G A  256 non-null    uint8
#  44  SNP_15_G G  256 non-null    uint8
#  45  class       256 non-null    object
#  46  ae_loss     256 non-null    float32
#  47  ae_0        256 non-null    float32
#  48  ae_1        256 non-null    float32
#  49  ae_2        256 non-null    float32
#  50  ae_3        256 non-null    float32
#  51  ae_4        256 non-null    float32
#  52  ae_5        256 non-null    float32
#  53  ae_6        256 non-null    float32
#  54  ae_7        256 non-null    float32
#  55  ae_8        256 non-null    float32
#  56  ae_9        256 non-null    float32
#  57  ae_10       256 non-null    float32
#  58  ae_11       256 non-null    float32
# dtypes: float32(13), object(1), uint8(45)
# memory usage: 26.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 58 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  175 non-null    uint8
#  1   SNP_01_A G  175 non-null    uint8
#  2   SNP_01_G G  175 non-null    uint8
#  3   SNP_02_A A  175 non-null    uint8
#  4   SNP_02_A G  175 non-null    uint8
#  5   SNP_02_G G  175 non-null    uint8
#  6   SNP_03_A A  175 non-null    uint8
#  7   SNP_03_C A  175 non-null    uint8
#  8   SNP_03_C C  175 non-null    uint8
#  9   SNP_04_A A  175 non-null    uint8
#  10  SNP_04_G A  175 non-null    uint8
#  11  SNP_04_G G  175 non-null    uint8
#  12  SNP_05_A A  175 non-null    uint8
#  13  SNP_05_C A  175 non-null    uint8
#  14  SNP_05_C C  175 non-null    uint8
#  15  SNP_06_A A  175 non-null    uint8
#  16  SNP_06_A G  175 non-null    uint8
#  17  SNP_06_G G  175 non-null    uint8
#  18  SNP_07_A A  175 non-null    uint8
#  19  SNP_07_G A  175 non-null    uint8
#  20  SNP_07_G G  175 non-null    uint8
#  21  SNP_08_A A  175 non-null    uint8
#  22  SNP_08_G A  175 non-null    uint8
#  23  SNP_08_G G  175 non-null    uint8
#  24  SNP_09_A A  175 non-null    uint8
#  25  SNP_09_G A  175 non-null    uint8
#  26  SNP_09_G G  175 non-null    uint8
#  27  SNP_10_A A  175 non-null    uint8
#  28  SNP_10_A G  175 non-null    uint8
#  29  SNP_10_G G  175 non-null    uint8
#  30  SNP_11_A A  175 non-null    uint8
#  31  SNP_11_A G  175 non-null    uint8
#  32  SNP_11_G G  175 non-null    uint8
#  33  SNP_12_A A  175 non-null    uint8
#  34  SNP_12_G A  175 non-null    uint8
#  35  SNP_12_G G  175 non-null    uint8
#  36  SNP_13_A A  175 non-null    uint8
#  37  SNP_13_A G  175 non-null    uint8
#  38  SNP_13_G G  175 non-null    uint8
#  39  SNP_14_A A  175 non-null    uint8
#  40  SNP_14_C A  175 non-null    uint8
#  41  SNP_14_C C  175 non-null    uint8
#  42  SNP_15_A A  175 non-null    uint8
#  43  SNP_15_G A  175 non-null    uint8
#  44  SNP_15_G G  175 non-null    uint8
#  45  ae_loss     175 non-null    float32
#  46  ae_0        175 non-null    float32
#  47  ae_1        175 non-null    float32
#  48  ae_2        175 non-null    float32
#  49  ae_3        175 non-null    float32
#  50  ae_4        175 non-null    float32
#  51  ae_5        175 non-null    float32
#  52  ae_6        175 non-null    float32
#  53  ae_7        175 non-null    float32
#  54  ae_8        175 non-null    float32
#  55  ae_9        175 non-null    float32
#  56  ae_10       175 non-null    float32
#  57  ae_11       175 non-null    float32
# dtypes: float32(13), uint8(45)
# memory usage: 16.7 KB
# (None, None)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X = torch.Tensor(train2.drop(columns=['class']).to_numpy())

input_dim = X.shape[1]
latent_dim = 12
batch_size = 64
num_epochs = 1000

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_data = X
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_data = X
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

model = VAE(input_dim, latent_dim).to(device)
optimizer = torch.optim.Adam(model.parameters())

for epoch in range(num_epochs):
    train_loss = train(model, optimizer, train_loader, device)
    test_loss = test(model, test_loader, device)
    print(f"Epoch {epoch}: Train loss = {train_loss}, Test loss = {test_loss}")
# Out:
# Epoch 0: Train loss = 14.535635948181152, Test loss = 13.893090724945068
# Epoch 1: Train loss = 13.59974980354309, Test loss = 13.023449182510376
# Epoch 2: Train loss = 12.665371179580688, Test loss = 12.062449932098389
# Epoch 3: Train loss = 11.742890357971191, Test loss = 11.09129023551941
# Epoch 4: Train loss = 10.851985931396484, Test loss = 10.396318197250366
# Epoch 5: Train loss = 10.167058229446411, Test loss = 9.96699571609497
# Epoch 6: Train loss = 9.89912724494934, Test loss = 9.783190727233887
# Epoch 7: Train loss = 9.767432928085327, Test loss = 9.489997625350952
# Epoch 8: Train loss = 9.491695880889893, Test loss = 9.329458475112915
# Epoch 9: Train loss = 9.305176496505737, Test loss = 9.349501132965088
# Epoch 10: Train loss = 9.331107139587402, Test loss = 9.255607604980469
# Epoch 11: Train loss = 9.283725500106812, Test loss = 9.219717741012573
# Epoch 12: Train loss = 9.22048544883728, Test loss = 9.22669005393982
# Epoch 13: Train loss = 9.204759120941162, Test loss = 9.20655608177185
# Epoch 14: Train loss = 9.14496922492981, Test loss = 9.141492366790771
# Epoch 15: Train loss = 9.1872718334198, Test loss = 9.196964502334595
# Epoch 16: Train loss = 9.16861867904663, Test loss = 9.111491203308105
# Epoch 17: Train loss = 9.138822555541992, Test loss = 9.127474308013916
# Epoch 18: Train loss = 9.110144853591919, Test loss = 9.10157299041748
# Epoch 19: Train loss = 9.13103199005127, Test loss = 9.119693279266357
# Epoch 20: Train loss = 9.137850999832153, Test loss = 9.116324663162231
# Epoch 21: Train loss = 9.141321182250977, Test loss = 9.105205535888672
# Epoch 65: Train loss = 8.913050651550293, Test loss = 8.914806604385376
# Epoch 66: Train loss = 8.910387992858887, Test loss = 8.871031999588013
# Epoch 67: Train loss = 8.850867748260498, Test loss = 8.756218671798706
# Epoch 68: Train loss = 8.80366849899292, Test loss = 8.71623945236206
# Epoch 69: Train loss = 8.729172468185425, Test loss = 8.762852668762207
# Epoch 70: Train loss = 8.711137533187866, Test loss = 8.713958740234375
# Epoch 71: Train loss = 8.66553521156311, Test loss = 8.636741876602173
# Epoch 72: Train loss = 8.613311052322388, Test loss = 8.600523233413696
# Epoch 73: Train loss = 8.588032245635986, Test loss = 8.544525384902954
# Epoch 74: Train loss = 8.566498279571533, Test loss = 8.447888135910034
# Epoch 75: Train loss = 8.527578592300415, Test loss = 8.481723308563232
# Epoch 76: Train loss = 8.45150089263916, Test loss = 8.445741176605225
# Epoch 77: Train loss = 8.469707250595093, Test loss = 8.294473648071289
# Epoch 78: Train loss = 8.382457256317139, Test loss = 8.362873315811157
# Epoch 79: Train loss = 8.349025964736938, Test loss = 8.437460899353027
# Epoch 80: Train loss = 8.149266123771667, Test loss = 8.358174800872803
# Epoch 81: Train loss = 8.30999231338501, Test loss = 8.391799211502075
# Epoch 82: Train loss = 8.167248129844666, Test loss = 8.304140090942383
# Epoch 83: Train loss = 8.16991126537323, Test loss = 8.264237403869629
# Epoch 84: Train loss = 8.261175632476807, Test loss = 8.347737312316895
# Epoch 85: Train loss = 8.167690753936768, Test loss = 8.340125322341919
# Epoch 86: Train loss = 8.226734399795532, Test loss = 8.081388592720032
# Epoch 87: Train loss = 8.243088483810425, Test loss = 8.304119348526001
# Epoch 88: Train loss = 8.198471546173096, Test loss = 8.088193416595459
# Epoch 89: Train loss = 8.120540857315063, Test loss = 8.10195243358612
# Epoch 90: Train loss = 8.150559067726135, Test loss = 8.141222715377808
# Epoch 91: Train loss = 8.17968213558197, Test loss = 8.089288234710693
# Epoch 92: Train loss = 8.175431609153748, Test loss = 8.126692295074463
# Epoch 93: Train loss = 8.00160014629364, Test loss = 8.080240726470947
# Epoch 94: Train loss = 8.024195909500122, Test loss = 8.249820947647095
# Epoch 95: Train loss = 8.011263489723206, Test loss = 8.118686556816101
# Epoch 96: Train loss = 7.961677551269531, Test loss = 8.10693073272705
# Epoch 97: Train loss = 8.122830033302307, Test loss = 8.085904359817505
# Epoch 98: Train loss = 8.099350690841675, Test loss = 7.972089767456055
# Epoch 99: Train loss = 8.169643998146057, Test loss = 8.016717076301575
# Epoch 100: Train loss = 8.139617443084717, Test loss = 8.093812346458435
# Epoch 101: Train loss = 8.034852266311646, Test loss = 8.123027443885803
# Epoch 102: Train loss = 8.133036255836487, Test loss = 8.084521174430847
# Epoch 103: Train loss = 8.16156005859375, Test loss = 8.045711636543274
# Epoch 104: Train loss = 8.078300476074219, Test loss = 8.128681898117065
# Epoch 105: Train loss = 7.93609356880188, Test loss = 8.088044881820679
# Epoch 106: Train loss = 8.166486978530884, Test loss = 8.166550397872925
# Epoch 107: Train loss = 8.108861327171326, Test loss = 7.93161416053772
# Epoch 108: Train loss = 7.943294048309326, Test loss = 8.022237658500671
# Epoch 109: Train loss = 8.039737105369568, Test loss = 7.99345600605011
# Epoch 110: Train loss = 7.911139011383057, Test loss = 8.20998477935791
# Epoch 111: Train loss = 7.937387228012085, Test loss = 8.102373838424683
# Epoch 112: Train loss = 8.002890467643738, Test loss = 8.013994216918945
# Epoch 113: Train loss = 8.131719946861267, Test loss = 8.19560694694519
# Epoch 114: Train loss = 8.004410147666931, Test loss = 8.082294940948486
# Epoch 115: Train loss = 7.988994479179382, Test loss = 7.8941463232040405
# Epoch 116: Train loss = 8.056658387184143, Test loss = 8.04882562160492
# Epoch 117: Train loss = 8.200454473495483, Test loss = 8.064802765846252
# Epoch 118: Train loss = 8.024061679840088, Test loss = 8.11238980293274
# Epoch 119: Train loss = 8.09741199016571, Test loss = 7.952376484870911
# Epoch 120: Train loss = 7.942586898803711, Test loss = 8.018819808959961
# Epoch 121: Train loss = 7.996557116508484, Test loss = 8.11970567703247
# Epoch 122: Train loss = 8.199495553970337, Test loss = 8.064517140388489
# Epoch 123: Train loss = 8.008341670036316, Test loss = 7.977021336555481
# Epoch 124: Train loss = 8.129472374916077, Test loss = 8.01905906200409
# Epoch 125: Train loss = 8.064526319503784, Test loss = 8.00294315814972
# Epoch 126: Train loss = 7.984155535697937, Test loss = 8.061573386192322
# Epoch 127: Train loss = 8.170894503593445, Test loss = 7.868969917297363
# Epoch 128: Train loss = 8.070586085319519, Test loss = 7.910936236381531
# Epoch 129: Train loss = 8.031757116317749, Test loss = 7.993945240974426
# Epoch 130: Train loss = 8.065085768699646, Test loss = 7.9968650341033936
# Epoch 131: Train loss = 7.887647747993469, Test loss = 8.01543116569519
# Epoch 132: Train loss = 7.841204285621643, Test loss = 7.942984580993652
# Epoch 133: Train loss = 8.036351680755615, Test loss = 7.955515503883362
# Epoch 134: Train loss = 8.000440835952759, Test loss = 8.016589522361755
# Epoch 135: Train loss = 7.910290956497192, Test loss = 7.9857423305511475
# Epoch 136: Train loss = 8.008707046508789, Test loss = 7.9521404504776
# Epoch 137: Train loss = 7.963003039360046, Test loss = 7.881530523300171
# Epoch 138: Train loss = 8.042282104492188, Test loss = 7.977340221405029
# Epoch 139: Train loss = 8.058791875839233, Test loss = 7.888450264930725
# Epoch 140: Train loss = 7.961711645126343, Test loss = 7.973272800445557
# Epoch 141: Train loss = 7.895355463027954, Test loss = 7.952122330665588
# Epoch 142: Train loss = 8.068885445594788, Test loss = 7.8456597328186035
# Epoch 143: Train loss = 7.953366756439209, Test loss = 7.894542574882507
# Epoch 144: Train loss = 7.855437994003296, Test loss = 7.962778568267822
# Epoch 145: Train loss = 7.742815136909485, Test loss = 7.960085511207581
# Epoch 146: Train loss = 7.956388473510742, Test loss = 7.948362588882446
# Epoch 147: Train loss = 7.922861695289612, Test loss = 7.883187294006348
# Epoch 148: Train loss = 7.809504270553589, Test loss = 7.889124393463135
# Epoch 989: Train loss = 7.3883925676345825, Test loss = 7.428638935089111
# Epoch 990: Train loss = 7.4082101583480835, Test loss = 7.446700692176819
# Epoch 991: Train loss = 7.3464003801345825, Test loss = 7.370978236198425
# Epoch 992: Train loss = 7.439685106277466, Test loss = 7.317019581794739
# Epoch 993: Train loss = 7.434510111808777, Test loss = 7.502988576889038
# Epoch 994: Train loss = 7.535308480262756, Test loss = 7.404277682304382
# Epoch 995: Train loss = 7.466979265213013, Test loss = 7.462101578712463
# Epoch 996: Train loss = 7.518468856811523, Test loss = 7.386377692222595
# Epoch 997: Train loss = 7.442594408988953, Test loss = 7.453722953796387
# Epoch 998: Train loss = 7.449991941452026, Test loss = 7.517802000045776
# Epoch 999: Train loss = 7.338151454925537, Test loss = 7.435803651809692

# %%
X1 = X.to(device)
X2 = torch.Tensor(test2.to_numpy()).to(device)

pred_train = model(X1)
pred_test = model(X2)

# reconstruction error
loss_train = []
loss_test = []

for i in range(len(X1)) :
    loss = criterion(pred_train[0][i], X1[i]).detach().cpu().numpy()
    loss_train.append(loss)
for j in range(len(X2)) :
    loss = criterion(pred_test[0][j], X2[j]).detach().cpu().numpy()
    loss_test.append(loss)

# encoding values
enco_train = pred_train[1].detach().cpu().numpy()
enco_test = pred_test[1].detach().cpu().numpy()

trainLoss = pd.DataFrame(data=loss_train, columns=['vae_loss'])
testLoss = pd.DataFrame(data=loss_test, columns=['vae_loss'])

ae_train = pd.DataFrame(data=enco_train, columns=['vae_'+str(x) for x in range(enco_train.shape[1])])
ae_test = pd.DataFrame(data=enco_test, columns=['vae_'+str(x) for x in range(enco_train.shape[1])])

train4 = pd.concat([train3, trainLoss, ae_train], axis=1)
test4 = pd.concat([test3, testLoss, ae_test], axis=1)

train4.info(), test4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 72 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  256 non-null    uint8
#  1   SNP_01_A G  256 non-null    uint8
#  2   SNP_01_G G  256 non-null    uint8
#  3   SNP_02_A A  256 non-null    uint8
#  4   SNP_02_A G  256 non-null    uint8
#  5   SNP_02_G G  256 non-null    uint8
#  6   SNP_03_A A  256 non-null    uint8
#  7   SNP_03_C A  256 non-null    uint8
#  8   SNP_03_C C  256 non-null    uint8
#  9   SNP_04_A A  256 non-null    uint8
#  10  SNP_04_G A  256 non-null    uint8
#  11  SNP_04_G G  256 non-null    uint8
#  12  SNP_05_A A  256 non-null    uint8
#  13  SNP_05_C A  256 non-null    uint8
#  14  SNP_05_C C  256 non-null    uint8
#  15  SNP_06_A A  256 non-null    uint8
#  16  SNP_06_A G  256 non-null    uint8
#  17  SNP_06_G G  256 non-null    uint8
#  18  SNP_07_A A  256 non-null    uint8
#  19  SNP_07_G A  256 non-null    uint8
#  20  SNP_07_G G  256 non-null    uint8
#  21  SNP_08_A A  256 non-null    uint8
#  22  SNP_08_G A  256 non-null    uint8
#  23  SNP_08_G G  256 non-null    uint8
#  24  SNP_09_A A  256 non-null    uint8
#  25  SNP_09_G A  256 non-null    uint8
#  26  SNP_09_G G  256 non-null    uint8
#  27  SNP_10_A A  256 non-null    uint8
#  28  SNP_10_A G  256 non-null    uint8
#  29  SNP_10_G G  256 non-null    uint8
#  30  SNP_11_A A  256 non-null    uint8
#  31  SNP_11_A G  256 non-null    uint8
#  32  SNP_11_G G  256 non-null    uint8
#  33  SNP_12_A A  256 non-null    uint8
#  34  SNP_12_G A  256 non-null    uint8
#  35  SNP_12_G G  256 non-null    uint8
#  36  SNP_13_A A  256 non-null    uint8
#  37  SNP_13_A G  256 non-null    uint8
#  38  SNP_13_G G  256 non-null    uint8
#  39  SNP_14_A A  256 non-null    uint8
#  40  SNP_14_C A  256 non-null    uint8
#  41  SNP_14_C C  256 non-null    uint8
#  42  SNP_15_A A  256 non-null    uint8
#  43  SNP_15_G A  256 non-null    uint8
#  44  SNP_15_G G  256 non-null    uint8
#  45  class       256 non-null    object
#  46  ae_loss     256 non-null    float32
#  47  ae_0        256 non-null    float32
#  48  ae_1        256 non-null    float32
#  49  ae_2        256 non-null    float32
#  50  ae_3        256 non-null    float32
#  51  ae_4        256 non-null    float32
#  52  ae_5        256 non-null    float32
#  53  ae_6        256 non-null    float32
#  54  ae_7        256 non-null    float32
#  55  ae_8        256 non-null    float32
#  56  ae_9        256 non-null    float32
#  57  ae_10       256 non-null    float32
#  58  ae_11       256 non-null    float32
#  59  vae_loss    256 non-null    float32
#  60  vae_0       256 non-null    float32
#  61  vae_1       256 non-null    float32
#  62  vae_2       256 non-null    float32
#  63  vae_3       256 non-null    float32
#  64  vae_4       256 non-null    float32
#  65  vae_5       256 non-null    float32
#  66  vae_6       256 non-null    float32
#  67  vae_7       256 non-null    float32
#  68  vae_8       256 non-null    float32
#  69  vae_9       256 non-null    float32
#  70  vae_10      256 non-null    float32
#  71  vae_11      256 non-null    float32
# dtypes: float32(26), object(1), uint8(45)
# memory usage: 39.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 71 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  175 non-null    uint8
#  1   SNP_01_A G  175 non-null    uint8
#  2   SNP_01_G G  175 non-null    uint8
#  3   SNP_02_A A  175 non-null    uint8
#  4   SNP_02_A G  175 non-null    uint8
#  5   SNP_02_G G  175 non-null    uint8
#  6   SNP_03_A A  175 non-null    uint8
#  7   SNP_03_C A  175 non-null    uint8
#  8   SNP_03_C C  175 non-null    uint8
#  9   SNP_04_A A  175 non-null    uint8
#  10  SNP_04_G A  175 non-null    uint8
#  11  SNP_04_G G  175 non-null    uint8
#  12  SNP_05_A A  175 non-null    uint8
#  13  SNP_05_C A  175 non-null    uint8
#  14  SNP_05_C C  175 non-null    uint8
#  15  SNP_06_A A  175 non-null    uint8
#  16  SNP_06_A G  175 non-null    uint8
#  17  SNP_06_G G  175 non-null    uint8
#  18  SNP_07_A A  175 non-null    uint8
#  19  SNP_07_G A  175 non-null    uint8
#  20  SNP_07_G G  175 non-null    uint8
#  21  SNP_08_A A  175 non-null    uint8
#  22  SNP_08_G A  175 non-null    uint8
#  23  SNP_08_G G  175 non-null    uint8
#  24  SNP_09_A A  175 non-null    uint8
#  25  SNP_09_G A  175 non-null    uint8
#  26  SNP_09_G G  175 non-null    uint8
#  27  SNP_10_A A  175 non-null    uint8
#  28  SNP_10_A G  175 non-null    uint8
#  29  SNP_10_G G  175 non-null    uint8
#  30  SNP_11_A A  175 non-null    uint8
#  31  SNP_11_A G  175 non-null    uint8
#  32  SNP_11_G G  175 non-null    uint8
#  33  SNP_12_A A  175 non-null    uint8
#  34  SNP_12_G A  175 non-null    uint8
#  35  SNP_12_G G  175 non-null    uint8
#  36  SNP_13_A A  175 non-null    uint8
#  37  SNP_13_A G  175 non-null    uint8
#  38  SNP_13_G G  175 non-null    uint8
#  39  SNP_14_A A  175 non-null    uint8
#  40  SNP_14_C A  175 non-null    uint8
#  41  SNP_14_C C  175 non-null    uint8
#  42  SNP_15_A A  175 non-null    uint8
#  43  SNP_15_G A  175 non-null    uint8
#  44  SNP_15_G G  175 non-null    uint8
#  45  ae_loss     175 non-null    float32
#  46  ae_0        175 non-null    float32
#  47  ae_1        175 non-null    float32
#  48  ae_2        175 non-null    float32
#  49  ae_3        175 non-null    float32
#  50  ae_4        175 non-null    float32
#  51  ae_5        175 non-null    float32
#  52  ae_6        175 non-null    float32
#  53  ae_7        175 non-null    float32
#  54  ae_8        175 non-null    float32
#  55  ae_9        175 non-null    float32
#  56  ae_10       175 non-null    float32
#  57  ae_11       175 non-null    float32
#  58  vae_loss    175 non-null    float32
#  59  vae_0       175 non-null    float32
#  60  vae_1       175 non-null    float32
#  61  vae_2       175 non-null    float32
#  62  vae_3       175 non-null    float32
#  63  vae_4       175 non-null    float32
#  64  vae_5       175 non-null    float32
#  65  vae_6       175 non-null    float32
#  66  vae_7       175 non-null    float32
#  67  vae_8       175 non-null    float32
#  68  vae_9       175 non-null    float32
#  69  vae_10      175 non-null    float32
#  70  vae_11      175 non-null    float32
# dtypes: float32(26), uint8(45)
# memory usage: 25.6 KB
# (None, None)

# %% [markdown]
# # BaseModeling

# %%
train4.iloc[:, :45] = train4.iloc[:, :45].astype('category')
test4.iloc[:, :45] = test4.iloc[:, :45].astype('category')
train4.info(), test4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 72 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  256 non-null    category
#  1   SNP_01_A G  256 non-null    category
#  2   SNP_01_G G  256 non-null    category
#  3   SNP_02_A A  256 non-null    category
#  4   SNP_02_A G  256 non-null    category
#  5   SNP_02_G G  256 non-null    category
#  6   SNP_03_A A  256 non-null    category
#  7   SNP_03_C A  256 non-null    category
#  8   SNP_03_C C  256 non-null    category
#  9   SNP_04_A A  256 non-null    category
#  10  SNP_04_G A  256 non-null    category
#  11  SNP_04_G G  256 non-null    category
#  12  SNP_05_A A  256 non-null    category
#  13  SNP_05_C A  256 non-null    category
#  14  SNP_05_C C  256 non-null    category
#  15  SNP_06_A A  256 non-null    category
#  16  SNP_06_A G  256 non-null    category
#  17  SNP_06_G G  256 non-null    category
#  18  SNP_07_A A  256 non-null    category
#  19  SNP_07_G A  256 non-null    category
#  20  SNP_07_G G  256 non-null    category
#  21  SNP_08_A A  256 non-null    category
#  22  SNP_08_G A  256 non-null    category
#  23  SNP_08_G G  256 non-null    category
#  24  SNP_09_A A  256 non-null    category
#  25  SNP_09_G A  256 non-null    category
#  26  SNP_09_G G  256 non-null    category
#  27  SNP_10_A A  256 non-null    category
#  28  SNP_10_A G  256 non-null    category
#  29  SNP_10_G G  256 non-null    category
#  30  SNP_11_A A  256 non-null    category
#  31  SNP_11_A G  256 non-null    category
#  32  SNP_11_G G  256 non-null    category
#  33  SNP_12_A A  256 non-null    category
#  34  SNP_12_G A  256 non-null    category
#  35  SNP_12_G G  256 non-null    category
#  36  SNP_13_A A  256 non-null    category
#  37  SNP_13_A G  256 non-null    category
#  38  SNP_13_G G  256 non-null    category
#  39  SNP_14_A A  256 non-null    category
#  40  SNP_14_C A  256 non-null    category
#  41  SNP_14_C C  256 non-null    category
#  42  SNP_15_A A  256 non-null    category
#  43  SNP_15_G A  256 non-null    category
#  44  SNP_15_G G  256 non-null    category
#  45  class       256 non-null    object
#  46  ae_loss     256 non-null    float32
#  47  ae_0        256 non-null    float32
#  48  ae_1        256 non-null    float32
#  49  ae_2        256 non-null    float32
#  50  ae_3        256 non-null    float32
#  51  ae_4        256 non-null    float32
#  52  ae_5        256 non-null    float32
#  53  ae_6        256 non-null    float32
#  54  ae_7        256 non-null    float32
#  55  ae_8        256 non-null    float32
#  56  ae_9        256 non-null    float32
#  57  ae_10       256 non-null    float32
#  58  ae_11       256 non-null    float32
#  59  vae_loss    256 non-null    float32
#  60  vae_0       256 non-null    float32
#  61  vae_1       256 non-null    float32
#  62  vae_2       256 non-null    float32
#  63  vae_3       256 non-null    float32
#  64  vae_4       256 non-null    float32
#  65  vae_5       256 non-null    float32
#  66  vae_6       256 non-null    float32
#  67  vae_7       256 non-null    float32
#  68  vae_8       256 non-null    float32
#  69  vae_9       256 non-null    float32
#  70  vae_10      256 non-null    float32
#  71  vae_11      256 non-null    float32
# dtypes: category(45), float32(26), object(1)
# memory usage: 44.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 71 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SNP_01_A A  175 non-null    category
#  1   SNP_01_A G  175 non-null    category
#  2   SNP_01_G G  175 non-null    category
#  3   SNP_02_A A  175 non-null    category
#  4   SNP_02_A G  175 non-null    category
#  5   SNP_02_G G  175 non-null    category
#  6   SNP_03_A A  175 non-null    category
#  7   SNP_03_C A  175 non-null    category
#  8   SNP_03_C C  175 non-null    category
#  9   SNP_04_A A  175 non-null    category
#  10  SNP_04_G A  175 non-null    category
#  11  SNP_04_G G  175 non-null    category
#  12  SNP_05_A A  175 non-null    category
#  13  SNP_05_C A  175 non-null    category
#  14  SNP_05_C C  175 non-null    category
#  15  SNP_06_A A  175 non-null    category
#  16  SNP_06_A G  175 non-null    category
#  17  SNP_06_G G  175 non-null    category
#  18  SNP_07_A A  175 non-null    category
#  19  SNP_07_G A  175 non-null    category
#  20  SNP_07_G G  175 non-null    category
#  21  SNP_08_A A  175 non-null    category
#  22  SNP_08_G A  175 non-null    category
#  23  SNP_08_G G  175 non-null    category
#  24  SNP_09_A A  175 non-null    category
#  25  SNP_09_G A  175 non-null    category
#  26  SNP_09_G G  175 non-null    category
#  27  SNP_10_A A  175 non-null    category
#  28  SNP_10_A G  175 non-null    category
#  29  SNP_10_G G  175 non-null    category
#  30  SNP_11_A A  175 non-null    category
#  31  SNP_11_A G  175 non-null    category
#  32  SNP_11_G G  175 non-null    category
#  33  SNP_12_A A  175 non-null    category
#  34  SNP_12_G A  175 non-null    category
#  35  SNP_12_G G  175 non-null    category
#  36  SNP_13_A A  175 non-null    category
#  37  SNP_13_A G  175 non-null    category
#  38  SNP_13_G G  175 non-null    category
#  39  SNP_14_A A  175 non-null    category
#  40  SNP_14_C A  175 non-null    category
#  41  SNP_14_C C  175 non-null    category
#  42  SNP_15_A A  175 non-null    category
#  43  SNP_15_G A  175 non-null    category
#  44  SNP_15_G G  175 non-null    category
#  45  ae_loss     175 non-null    float32
#  46  ae_0        175 non-null    float32
#  47  ae_1        175 non-null    float32
#  48  ae_2        175 non-null    float32
#  49  ae_3        175 non-null    float32
#  50  ae_4        175 non-null    float32
#  51  ae_5        175 non-null    float32
#  52  ae_6        175 non-null    float32
#  53  ae_7        175 non-null    float32
#  54  ae_8        175 non-null    float32
#  55  ae_9        175 non-null    float32
#  56  ae_10       175 non-null    float32
#  57  ae_11       175 non-null    float32
#  58  vae_loss    175 non-null    float32
#  59  vae_0       175 non-null    float32
#  60  vae_1       175 non-null    float32
#  61  vae_2       175 non-null    float32
#  62  vae_3       175 non-null    float32
#  63  vae_4       175 non-null    float32
#  64  vae_5       175 non-null    float32
#  65  vae_6       175 non-null    float32
#  66  vae_7       175 non-null    float32
#  67  vae_8       175 non-null    float32
#  68  vae_9       175 non-null    float32
#  69  vae_10      175 non-null    float32
#  70  vae_11      175 non-null    float32
# dtypes: category(45), float32(26)
# memory usage: 31.0 KB
# (None, None)

# %%
from catboost import Pool, cv

def catcv(inputX, inputY, validX, validY, params, cv_count) :  
    
    var_categ = inputX.columns.tolist()[:45]
    
    cv_dataset = Pool(data=inputX,
                      label=inputY,
                      cat_features=var_categ)
    
    scores = cv(cv_dataset,
                params,
                fold_count=cv_count,
                stratified=True,
                plot=True)

# %%
def catgbmc(inputX, inputY, validX, validY, params) :  
    var_categ = inputX.columns.tolist()[:45]
    model = CatBoostClassifier(
        cat_features=var_categ,
        **params,
        task_type='GPU',
        devices='0',
        )
  
    model.fit(
        inputX, inputY,
        eval_set=(inputX, inputY)
        );     

    pred = model.predict(validX)
    score = f1_score(validY, pred, average='macro')
    print(score)
    
    return model

# %%
from imblearn.under_sampling import RandomUnderSampler

X, y = train2.drop(columns='class'), (train2['class']=='A').astype(int)
X_test = test2.copy()

strategy1 = {0:50, 1:50}
strategy2 = {0:1000, 1:1000}

smote1 = RandomUnderSampler(sampling_strategy=strategy1)
smote2 = SMOTEN(sampling_strategy=strategy2, k_neighbors=20)

X1, y1 = smote1.fit_resample(X, y)
X2, y2 = smote2.fit_resample(X, y)

# %%
params = {'iterations':300,
          'learning_rate':0.3,
          'l2_leaf_reg' : 10,
          # 'grow_policy' : 'Lossguide',
        #   'auto_class_weights' : 'SqrtBalanced',
          'loss_function' : 'CrossEntropy',
          'eval_metric' : 'F1',
          # 'early_stopping_rounds' : 50,
          'verbose':0,
          'random_seed':0}

# %%
catcv(X, y, X, y, params, cv_count=5)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
#
# bestTest = 1
# bestIteration = 1
#
# Training on fold [1/5]
#
# bestTest = 1
# bestIteration = 2
#
# Training on fold [2/5]
#
# bestTest = 1
# bestIteration = 2
#
# Training on fold [3/5]
#
# bestTest = 1
# bestIteration = 3
#
# Training on fold [4/5]
#
# bestTest = 0.9565217391
# bestIteration = 1

# %%
catcv(X1, y1, X, y, params, cv_count=3)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/3]
#
# bestTest = 1
# bestIteration = 70
#
# Training on fold [1/3]
#
# bestTest = 1
# bestIteration = 4
#
# Training on fold [2/3]
#
# bestTest = 1
# bestIteration = 12

# %%
catcv(X2, y2, X, y, params, cv_count=10)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/10]
#
# bestTest = 1
# bestIteration = 1
#
# Training on fold [1/10]
#
# bestTest = 1
# bestIteration = 1
#
# Training on fold [2/10]
#
# bestTest = 1
# bestIteration = 2
#
# Training on fold [3/10]
#
# bestTest = 0.9949748744
# bestIteration = 0
#
# Training on fold [4/10]
#
# bestTest = 1
# bestIteration = 0
#
# Training on fold [5/10]
#
# bestTest = 1
# bestIteration = 0
#
# Training on fold [6/10]
#
# bestTest = 1
# bestIteration = 3
#
# Training on fold [7/10]
#
# bestTest = 1
# bestIteration = 2
#
# Training on fold [8/10]
#
# bestTest = 1
# bestIteration = 0
#
# Training on fold [9/10]
#
# bestTest = 1
# bestIteration = 0

# %%
params = {'iterations':500,
          'learning_rate':0.03,
          'l2_leaf_reg' : 3,
          # 'grow_policy' : 'Lossguide',
        #   'auto_class_weights' : 'SqrtBalanced',
          'loss_function' : 'CrossEntropy',
          'eval_metric' : 'F1',
          # 'early_stopping_rounds' : 50,
          'verbose':0,
          'random_seed':0}

# %%
modelA = catgbmc(X1, y1, X, y, params)
# Out:
# 1.0

# %%
modelA.predict(X_test).sum()
# Out:
# 49

# %% [markdown]
# ## B & not B

# %%
from imblearn.under_sampling import RandomUnderSampler

X, y = train2.drop(columns='class'), (train2['class']=='B').astype(int)
X_test = test2.copy()

strategy1 = {0:50, 1:50}
strategy2 = {0:1000, 1:1000}

smote1 = RandomUnderSampler(sampling_strategy=strategy1)
smote2 = SMOTEN(sampling_strategy=strategy2, k_neighbors=20)

X1, y1 = smote1.fit_resample(X, y)
X2, y2 = smote2.fit_resample(X, y)

# %%
params = {'iterations':500,
          'learning_rate':0.03,
          'l2_leaf_reg' : 3,
          # 'grow_policy' : 'Lossguide',
        #   'auto_class_weights' : 'SqrtBalanced',
          'loss_function' : 'CrossEntropy',
          'eval_metric' : 'F1',
          # 'early_stopping_rounds' : 50,
          'verbose':0,
          'random_seed':0}

# %%
catcv(X, y, X, y, params, cv_count=5)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
#
# bestTest = 0.92
# bestIteration = 9
#
# Training on fold [1/5]
#
# bestTest = 0.9787234043
# bestIteration = 0
#
# Training on fold [2/5]
#
# bestTest = 0.9387755102
# bestIteration = 52
#
# Training on fold [3/5]
#
# bestTest = 0.9090909091
# bestIteration = 0
#
# Training on fold [4/5]
#
# bestTest = 0.9777777778
# bestIteration = 16

# %%
catcv(X1, y1, X, y, params, cv_count=3)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/3]
#
# bestTest = 0.9189189189
# bestIteration = 0
#
# Training on fold [1/3]
#
# bestTest = 0.9411764706
# bestIteration = 1
#
# Training on fold [2/3]
#
# bestTest = 0.9411764706
# bestIteration = 20

# %%
catcv(X2, y2, X, y, params, cv_count=5)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
#
# bestTest = 0.9974937343
# bestIteration = 75
#
# Training on fold [1/5]
#
# bestTest = 0.992481203
# bestIteration = 199
#
# Training on fold [2/5]
#
# bestTest = 0.9975062344
# bestIteration = 23
#
# Training on fold [3/5]
#
# bestTest = 0.9900497512
# bestIteration = 32
#
# Training on fold [4/5]
#
# bestTest = 0.995
# bestIteration = 56

# %%
params = {'iterations':500,
          'learning_rate':0.03,
          'l2_leaf_reg' : 3,
          # 'grow_policy' : 'Lossguide',
        #   'auto_class_weights' : 'SqrtBalanced',
          'loss_function' : 'CrossEntropy',
          'eval_metric' : 'F1',
          # 'early_stopping_rounds' : 50,
          'verbose':0,
          'random_seed':0}

# %%
modelB = catgbmc(X2, y2, X, y, params)
# Out:
# 1.0

# %%
modelB.predict(X_test).sum()
# Out:
# 85

# %% [markdown]
# ## C & not C

# %%
from imblearn.under_sampling import RandomUnderSampler

X, y = train2.drop(columns='class'), (train2['class']=='C').astype(int)
X_test = test2.copy()

strategy1 = {0:50, 1:50}
strategy2 = {0:1000, 1:1000}

smote1 = RandomUnderSampler(sampling_strategy=strategy1)
smote2 = SMOTEN(sampling_strategy=strategy2, k_neighbors=20)

X1, y1 = smote1.fit_resample(X, y)
X2, y2 = smote2.fit_resample(X, y)

# %%
params = {'iterations':500,
          'learning_rate':0.03,
          'l2_leaf_reg' : 3,
          # 'grow_policy' : 'Lossguide',
        #   'auto_class_weights' : 'SqrtBalanced',
          'loss_function' : 'CrossEntropy',
          'eval_metric' : 'F1',
          # 'early_stopping_rounds' : 50,
          'verbose':0,
          'random_seed':0}

# %%
catcv(X, y, X, y, params, cv_count=5)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
#
# bestTest = 0.8387096774
# bestIteration = 60
#
# Training on fold [1/5]
#
# bestTest = 0.9375
# bestIteration = 94
#
# Training on fold [2/5]
#
# bestTest = 0.8965517241
# bestIteration = 122
#
# Training on fold [3/5]
#
# bestTest = 0.9375
# bestIteration = 111
#
# Training on fold [4/5]
#
# bestTest = 0.9677419355
# bestIteration = 46

# %%
catcv(X1, y1, X, y, params, cv_count=5)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
#
# bestTest = 1
# bestIteration = 8
#
# Training on fold [1/5]
#
# bestTest = 0.8421052632
# bestIteration = 4
#
# Training on fold [2/5]
#
# bestTest = 1
# bestIteration = 166
#
# Training on fold [3/5]
#
# bestTest = 1
# bestIteration = 10
#
# Training on fold [4/5]
#
# bestTest = 0.9
# bestIteration = 84

# %%
catcv(X2, y2, X, y, params, cv_count=5)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Training on fold [0/5]
#
# bestTest = 0.9975062344
# bestIteration = 213
#
# Training on fold [1/5]
#
# bestTest = 0.9875311721
# bestIteration = 114
#
# Training on fold [2/5]
#
# bestTest = 0.9924433249
# bestIteration = 1
#
# Training on fold [3/5]
#
# bestTest = 0.9898989899
# bestIteration = 3
#
# Training on fold [4/5]
#
# bestTest = 0.9925187032
# bestIteration = 163

# %%
params = {'iterations':500,
          'learning_rate':0.03,
          'l2_leaf_reg' : 3,
          # 'grow_policy' : 'Lossguide',
        #   'auto_class_weights' : 'SqrtBalanced',
          'loss_function' : 'CrossEntropy',
          'eval_metric' : 'F1',
          # 'early_stopping_rounds' : 50,
          'verbose':0,
          'random_seed':0}

# %%
modelC = catgbmc(X2, y2, X, y, params)
# Out:
# 1.0

# %%
modelC.predict(X_test).sum()
# Out:
# 39

# %%
sample = pd.read_csv("./data/test.csv")[['id']].copy()
sample['class_A'] = modelA.predict_proba(X_test)[:,1]
sample['class_B'] = modelB.predict_proba(X_test)[:,1]
sample['class_C'] = modelC.predict_proba(X_test)[:,1]
sample['total'] = np.argmax(sample[['class_A', 'class_B', 'class_C']].values, axis=1)
sample
# Out:
#            id   class_A   class_B   class_C  total
# 0    TEST_000  0.618000  0.003390  0.009222      0
# 1    TEST_001  0.334375  0.995504  0.010459      1
# 2    TEST_002  0.470204  0.001677  0.996923      2
# 3    TEST_003  0.309502  0.870278  0.369231      1
# 4    TEST_004  0.651448  0.001689  0.001710      0
# ..        ...       ...       ...       ...    ...
# 170  TEST_170  0.352781  0.983192  0.007799      1
# 171  TEST_171  0.365122  0.000684  0.999645      2
# 172  TEST_172  0.388396  0.024013  0.993668      2
# 173  TEST_173  0.309240  0.999085  0.001330      1
# 174  TEST_174  0.388464  0.912137  0.007556      1
#
# [175 rows x 5 columns]

# %%
sample[(sample.class_A > 0.5) & ((sample.class_B > 0.1) | (sample.class_C > 0.1))]
# Out:
# Empty DataFrame
# Columns: [id, class_A, class_B, class_C, total]
# Index: []

# %%
sample[(sample.class_B > 0.5) & ((sample.class_A > 0.5) | (sample.class_C > 0.5))]
# Out:
#            id   class_A   class_B   class_C  total
# 119  TEST_119  0.355428  0.569391  0.776953      2

# %%
sample[(sample.class_B < 0.5) & (sample.class_A < 0.5) & (sample.class_C < 0.5)]
# Out:
#           id   class_A   class_B   class_C  total
# 28  TEST_028  0.495003  0.003697  0.007200      0
# 60  TEST_060  0.413473  0.013395  0.125204      0
# 66  TEST_066  0.410908  0.384954  0.019929      0

# %%
sample['total'].value_counts()
# Out:
# 1    84
# 0    52
# 2    39
# Name: total, dtype: int64

# %%
df = pd.read_csv("submit_high1.csv")
df['class'] = sample['total'].map(lambda x : 'A' if x==0 else ('B' if x==1 else 'C'))
df.to_csv("submit.csv", index=False)
df
# Out:
#            id class
# 0    TEST_000     A
# 1    TEST_001     B
# 2    TEST_002     C
# 3    TEST_003     B
# 4    TEST_004     A
# ..        ...   ...
# 170  TEST_170     B
# 171  TEST_171     C
# 172  TEST_172     C
# 173  TEST_173     B
# 174  TEST_174     B
#
# [175 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# B    84
# A    52
# C    39
# Name: class, dtype: int64

# %% [markdown]
# # 0.9719
