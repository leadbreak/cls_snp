# %% [markdown]
# # CONCEPT
#
# - 데이터를 증강하지 않고, A와 notA를 분류
# - A 데이터를 제외하고, B&C 데이터만을 남겨두기
# - B&C 데이터에 대한 Label Encoder 변수 추가
# - B&C 데이터에 대한 AE 및 VAE Encoding 값 및 error 값 추가
# - B&C 데이터에 대한 데이터 증강 유무에 따른 성능 확인

# %% [markdown]
# # STEP 01. 데이터를 증강하지 않고 A와 notA를 분류

# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import gc
import math
import random
import pickle
import pandas as pd
import numpy as np
import multiprocessing
from tqdm.auto import tqdm

from sklearn.metrics import f1_score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset, sampler

from xgboost import XGBClassifier, XGBRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from imblearn.over_sampling import SMOTE, SMOTENC, SMOTEN

# %%
device = torch.device('cuda:1') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda', index=1)

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')              
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      262 non-null    object
#  1   father  262 non-null    int64
#  2   mother  262 non-null    int64
#  3   gender  262 non-null    int64
#  4   trait   262 non-null    int64
#  5   SNP_01  262 non-null    object
#  6   SNP_02  262 non-null    object
#  7   SNP_03  262 non-null    object
#  8   SNP_04  262 non-null    object
#  9   SNP_05  262 non-null    object
#  10  SNP_06  262 non-null    object
#  11  SNP_07  262 non-null    object
#  12  SNP_08  262 non-null    object
#  13  SNP_09  262 non-null    object
#  14  SNP_10  262 non-null    object
#  15  SNP_11  262 non-null    object
#  16  SNP_12  262 non-null    object
#  17  SNP_13  262 non-null    object
#  18  SNP_14  262 non-null    object
#  19  SNP_15  262 non-null    object
#  20  class   262 non-null    object
# dtypes: int64(4), object(17)
# memory usage: 43.1+ KB

# %%
df_train['class'].value_counts()
# Out:
# B    114
# C     79
# A     69
# Name: class, dtype: int64

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      175 non-null    object
#  1   father  175 non-null    int64
#  2   mother  175 non-null    int64
#  3   gender  175 non-null    int64
#  4   trait   175 non-null    int64
#  5   SNP_01  175 non-null    object
#  6   SNP_02  175 non-null    object
#  7   SNP_03  175 non-null    object
#  8   SNP_04  175 non-null    object
#  9   SNP_05  175 non-null    object
#  10  SNP_06  175 non-null    object
#  11  SNP_07  175 non-null    object
#  12  SNP_08  175 non-null    object
#  13  SNP_09  175 non-null    object
#  14  SNP_10  175 non-null    object
#  15  SNP_11  175 non-null    object
#  16  SNP_12  175 non-null    object
#  17  SNP_13  175 non-null    object
#  18  SNP_14  175 non-null    object
#  19  SNP_15  175 non-null    object
# dtypes: int64(4), object(16)
# memory usage: 27.5+ KB

# %%
df_train.describe()
# Out:
#        father  mother  gender       trait
# count   262.0   262.0   262.0  262.000000
# mean      0.0     0.0     0.0    1.736641
# std       0.0     0.0     0.0    0.441298
# min       0.0     0.0     0.0    1.000000
# 25%       0.0     0.0     0.0    1.000000
# 50%       0.0     0.0     0.0    2.000000
# 75%       0.0     0.0     0.0    2.000000
# max       0.0     0.0     0.0    2.000000

# %%
df_test.describe()
# Out:
#        father  mother  gender       trait
# count   175.0   175.0   175.0  175.000000
# mean      0.0     0.0     0.0    1.708571
# std       0.0     0.0     0.0    0.455724
# min       0.0     0.0     0.0    1.000000
# 25%       0.0     0.0     0.0    1.000000
# 50%       0.0     0.0     0.0    2.000000
# 75%       0.0     0.0     0.0    2.000000
# max       0.0     0.0     0.0    2.000000

# %%
# trait와 Label A의 상관계수가 1로, 다른 변수에 대한 영향력이 학습되지 않을 정도로 높으므로 배제해보고 진행
df_train2 = df_train.drop(columns=['father', 'mother', 'gender','trait','SNP_06'])
df_test2 = df_test.drop(columns=['father', 'mother', 'gender', 'trait','SNP_06'])

smote = SMOTEN()
X, y = df_train2.iloc[:, 1:-1], (df_train2['class'].values == 'A').astype(int)
X2, y2 = smote.fit_resample(X, y)

# %%
def catgbmc(inputX, inputY, validX, validY, params) :  
    var_categ = inputX.columns.tolist()
    model = CatBoostClassifier(
        cat_features=var_categ,
        **params,
        task_type='GPU',
        devices='0',
        )
  
    model.fit(
        inputX, inputY,
        eval_set=(inputX, inputY)
        );     

    pred = model.predict(validX)
    score = f1_score(validY, pred, average='macro')
    print(score)
    
    return model

# %%
params = {'iterations':100,
          'learning_rate':0.1,
          'l2_leaf_reg' : 0,
        #   'grow_policy' : 'Depthwise',
          'verbose':0,
          'random_seed':0}

model1 = catgbmc(X2, y2, X, y, params)
model2 = catgbmc(X, y, X, y, params)
# Out:
# 1.0
# 1.0

# %%
pd.DataFrame(data=model1.get_feature_importance(), index=model1.feature_names_, columns=['feature_importance']).sort_values('feature_importance', ascending=False)
# Out:
#         feature_importance
# SNP_10           33.877307
# SNP_07           26.358528
# SNP_12           18.584903
# SNP_08           11.123008
# SNP_04            6.514777
# SNP_03            1.997152
# SNP_01            1.018393
# SNP_09            0.525932
# SNP_02            0.000000
# SNP_05            0.000000
# SNP_11            0.000000
# SNP_13            0.000000
# SNP_14            0.000000
# SNP_15            0.000000

# %%
pd.DataFrame(data=model2.get_feature_importance(), index=model2.feature_names_, columns=['feature_importance']).sort_values('feature_importance', ascending=False)
# Out:
#         feature_importance
# SNP_07           23.641925
# SNP_03           18.978285
# SNP_12           15.133577
# SNP_14            9.732432
# SNP_11            9.523872
# SNP_01            8.971842
# SNP_13            8.686420
# SNP_04            2.906656
# SNP_15            2.424992
# SNP_02            0.000000
# SNP_05            0.000000
# SNP_08            0.000000
# SNP_09            0.000000
# SNP_10            0.000000

# %%
pred = model1.predict_proba(X)[:,1] > 0.97
score = f1_score(y, pred, average='macro')
print(score)
# Out:
# 0.9950583752994211

# %%
pred = model2.predict_proba(X)[:,1] > 0.93
score = f1_score(y, pred, average='macro')
print(score)
# Out:
# 1.0

# %% [markdown]
# - 본래의 성능을 해치지 않는 선에서 threshold를 최대로 높여보기

# %%
pred1 = model1.predict_proba(df_test2.iloc[:, 1:])[:,1] > 0.97
sum(pred1)
# Out:
# 45

# %%
pred2 = model2.predict_proba(df_test2.iloc[:, 1:])[:,1] > 0.93
sum(pred2)
# Out:
# 48

# %%
train2 = df_train[df_train['class'] != 'A'].copy().reset_index(drop=True).drop(columns=['father', 'mother', 'gender','trait'])
test2 = df_test[~pred1.astype(bool)].copy().reset_index(drop=True).drop(columns=['father', 'mother', 'gender','trait'])
test2
# Out:
#            id SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_07 SNP_08 SNP_09  \
# 0    TEST_001    G G    A G    C C    G G    C C    A A    A A    A A    A A
# 1    TEST_002    G G    A G    A A    A A    C A    A G    A A    A A    A A
# 2    TEST_003    G G    A G    C A    A A    C C    A A    A A    A A    A A
# 3    TEST_005    G G    A G    C A    A A    C A    A A    A A    G A    A A
# 4    TEST_006    A A    A G    C A    A A    C A    A G    A A    A A    A A
# ..        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 125  TEST_170    A G    G G    C C    A A    C A    A G    A A    G G    A A
# 126  TEST_171    G G    A A    A A    A A    C A    A G    A A    A A    A A
# 127  TEST_172    G G    A A    A A    A A    C A    A G    A A    A A    A A
# 128  TEST_173    A G    G G    C A    G A    C C    G G    A A    G A    A A
# 129  TEST_174    G G    G G    C C    G A    C A    A A    G A    G G    A A
#
#     SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15
# 0      G G    A G    A A    A A    A A    A A
# 1      A G    A A    G A    G G    A A    G G
# 2      G G    A A    G A    A G    A A    A A
# 3      G G    G G    A A    A G    A A    A A
# 4      A G    A G    G A    A G    A A    G A
# ..     ...    ...    ...    ...    ...    ...
# 125    G G    G G    A A    A A    A A    G A
# 126    A G    A A    A A    A G    A A    G A
# 127    G G    A G    A A    A G    A A    G G
# 128    G G    A G    A A    A A    A A    A A
# 129    G G    G G    A A    A A    A A    A A
#
# [130 rows x 16 columns]

# %% [markdown]
# ### Summay 01
# - 이전의 과정들에서 수차례 증명되었듯, A와 notA를 분류하는 것은 아주 쉽다.
#  (기본적으로 trait 변수 하나만으로도 기계적인 분류가 가능하다)
# - 때문에 우선적으로 A와 notA를 분류해놓고, B와 C만이 존재하는 데이터를 대상으로 파생변수 생성, 증강 등의 과정을 진행한다.

# %% [markdown]
# # STEP 02. 파생변수 추가

# %% [markdown]
# ## 1) B와 C에 대한 Target Labeling

# %%
# categorical 변수 중 train에만 있거나, test에만 있는 칼럼 확인

train3 = pd.get_dummies(train2.iloc[:, 1:-1]).copy()
test3 = pd.get_dummies(test2.iloc[:, 1:]).copy()

target1 = train3.columns.tolist()
target2 = test3.columns.tolist()
[x for x in target1 if x not in target2], [y for y in target2 if y not in target1]
# Out:
# (['SNP_09_G G'], ['SNP_07_G G'])

# %%
train2.drop(columns=['SNP_07', 'SNP_09'], inplace=True)
test2.drop(columns=['SNP_07', 'SNP_09'], inplace=True)

# %%
# text 형태의 categorical 변수들을 숫자형태로 변경

for i in tqdm(range(1, 15+1)) :
    if (i == 7) | (i==9) :
        continue
    target = str(i) if i >= 10 else "0"+str(i)
    cols = sorted(train2[f"SNP_{target}"].unique().tolist())
    train2[f"SNP_{target}"] = train2[f"SNP_{target}"].map(lambda x : 0 if x==cols[0] else (1 if x==cols[1] else 2))
    test2[f"SNP_{target}"] = test2[f"SNP_{target}"].map(lambda x : 0 if x==cols[0] else (1 if x==cols[1] else 2))

train2.info(), test2.info()
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      193 non-null    object
#  1   SNP_01  193 non-null    int64
#  2   SNP_02  193 non-null    int64
#  3   SNP_03  193 non-null    int64
#  4   SNP_04  193 non-null    int64
#  5   SNP_05  193 non-null    int64
#  6   SNP_06  193 non-null    int64
#  7   SNP_08  193 non-null    int64
#  8   SNP_10  193 non-null    int64
#  9   SNP_11  193 non-null    int64
#  10  SNP_12  193 non-null    int64
#  11  SNP_13  193 non-null    int64
#  12  SNP_14  193 non-null    int64
#  13  SNP_15  193 non-null    int64
#  14  class   193 non-null    object
# dtypes: int64(13), object(2)
# memory usage: 22.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      130 non-null    object
#  1   SNP_01  130 non-null    int64
#  2   SNP_02  130 non-null    int64
#  3   SNP_03  130 non-null    int64
#  4   SNP_04  130 non-null    int64
#  5   SNP_05  130 non-null    int64
#  6   SNP_06  130 non-null    int64
#  7   SNP_08  130 non-null    int64
#  8   SNP_10  130 non-null    int64
#  9   SNP_11  130 non-null    int64
#  10  SNP_12  130 non-null    int64
#  11  SNP_13  130 non-null    int64
#  12  SNP_14  130 non-null    int64
#  13  SNP_15  130 non-null    int64
# dtypes: int64(13), object(1)
# memory usage: 14.3+ KB
# (None, None)

# %%
train2['class_B'] = train2['class'].map(lambda x : 1 if x=='B' else 0)
train2['class_C'] = train2['class'].map(lambda x : 1 if x=='C' else 0)

for i in range(1, 15+1) :
    if (i == 7) | (i==9) :
        continue
    target = str(i) if i >= 10 else "0"+str(i)
    target2 = train2.groupby(f'SNP_{target}')['class_B', 'class_C'].sum()
    target2['total'] = target2[['class_B', 'class_C']].sum(axis=1)
    for j in range(len(target2)) :
        if (target2['total'][j] < 3) : # 전체 표본이 너무 적은 경우 제외(확률 반반으로)
            target2['class_B'][j] = 1
            target2['class_C'][j] = 1
            
    value = target2['class_B'] / (target2['class_B']+target2['class_C'])    

    train2[f"SNP_{target}_ratio"] = train2[f"SNP_{target}"].map(lambda x : value[0] if x==0 else (value[1] if x==1 else value[2]))
    test2[f"SNP_{target}_ratio"] = test2[f"SNP_{target}"].map(lambda x : value[0] if x==0 else (value[1] if x==1 else value[2]))    

train2.drop(columns=['class_B', 'class_C'], inplace=True)
train2.info(), test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            193 non-null    object
#  1   SNP_01        193 non-null    int64
#  2   SNP_02        193 non-null    int64
#  3   SNP_03        193 non-null    int64
#  4   SNP_04        193 non-null    int64
#  5   SNP_05        193 non-null    int64
#  6   SNP_06        193 non-null    int64
#  7   SNP_08        193 non-null    int64
#  8   SNP_10        193 non-null    int64
#  9   SNP_11        193 non-null    int64
#  10  SNP_12        193 non-null    int64
#  11  SNP_13        193 non-null    int64
#  12  SNP_14        193 non-null    int64
#  13  SNP_15        193 non-null    int64
#  14  class         193 non-null    object
#  15  SNP_01_ratio  193 non-null    float64
#  16  SNP_02_ratio  193 non-null    float64
#  17  SNP_03_ratio  193 non-null    float64
#  18  SNP_04_ratio  193 non-null    float64
#  19  SNP_05_ratio  193 non-null    float64
#  20  SNP_06_ratio  193 non-null    float64
#  21  SNP_08_ratio  193 non-null    float64
#  22  SNP_10_ratio  193 non-null    float64
#  23  SNP_11_ratio  193 non-null    float64
#  24  SNP_12_ratio  193 non-null    float64
#  25  SNP_13_ratio  193 non-null    float64
#  26  SNP_14_ratio  193 non-null    float64
#  27  SNP_15_ratio  193 non-null    float64
# dtypes: float64(13), int64(13), object(2)
# memory usage: 42.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            130 non-null    object
#  1   SNP_01        130 non-null    int64
#  2   SNP_02        130 non-null    int64
#  3   SNP_03        130 non-null    int64
#  4   SNP_04        130 non-null    int64
#  5   SNP_05        130 non-null    int64
#  6   SNP_06        130 non-null    int64
#  7   SNP_08        130 non-null    int64
#  8   SNP_10        130 non-null    int64
#  9   SNP_11        130 non-null    int64
#  10  SNP_12        130 non-null    int64
#  11  SNP_13        130 non-null    int64
#  12  SNP_14        130 non-null    int64
#  13  SNP_15        130 non-null    int64
#  14  SNP_01_ratio  130 non-null    float64
#  15  SNP_02_ratio  130 non-null    float64
#  16  SNP_03_ratio  130 non-null    float64
#  17  SNP_04_ratio  130 non-null    float64
#  18  SNP_05_ratio  130 non-null    float64
#  19  SNP_06_ratio  130 non-null    float64
#  20  SNP_08_ratio  130 non-null    float64
#  21  SNP_10_ratio  130 non-null    float64
#  22  SNP_11_ratio  130 non-null    float64
#  23  SNP_12_ratio  130 non-null    float64
#  24  SNP_13_ratio  130 non-null    float64
#  25  SNP_14_ratio  130 non-null    float64
#  26  SNP_15_ratio  130 non-null    float64
# dtypes: float64(13), int64(13), object(1)
# memory usage: 27.5+ KB
# (None, None)

# %% [markdown]
# ## 2) AE & VAE 정의

# %%
class Autoencoder(nn.Module):
    def __init__(self, encoding_dim):
        super().__init__()
        self.encoding_dim = encoding_dim
        self.encoder = nn.Sequential(
            nn.Linear(26, 64),
            nn.GELU(),
            nn.Linear(64, 16),
            nn.GELU(),
            nn.Linear(16, encoding_dim),
            nn.GELU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 16),
            nn.GELU(),
            nn.Linear(16, 64),
            nn.GELU(),
            nn.Linear(64, 26)
        )

    def forward(self, x):
        x1 = self.encoder(x)
        x2 = self.decoder(x1)
        return x1, x2

def ae_train(model, data_loader, criterion, optimizer, device, epochs=10):
    model.to(device)
    for epoch in range(epochs):
        epoch_loss = 0
        for x in data_loader:
            x = x[0].to(device)
            _, x_hat = model(x)
            loss = criterion(x_hat, x)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f'Epoch {epoch}: loss = {epoch_loss / len(data_loader):.4f}')

# %%
X = torch.randn(320, train2.shape[1]-2)  # generate some example data

# Create a dataset and data loader
dataset = torch.utils.data.TensorDataset(X)
data_loader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)

# Initialize the model, criterion, and optimizer
encoding_dim = 6
model = Autoencoder(encoding_dim)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters())

# Train the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
ae_train(model, data_loader, criterion, optimizer, device)
# Out:
# Epoch 0: loss = 0.9920
# Epoch 1: loss = 0.9879
# Epoch 2: loss = 0.9853
# Epoch 3: loss = 0.9831
# Epoch 4: loss = 0.9783
# Epoch 5: loss = 0.9692
# Epoch 6: loss = 0.9536
# Epoch 7: loss = 0.9345
# Epoch 8: loss = 0.9152
# Epoch 9: loss = 0.8981

# %%
class VAE(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super(VAE, self).__init__()
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, input_dim*2),
            nn.ReLU(),
            nn.Linear(input_dim*2, input_dim),
            nn.ReLU(),
            nn.Linear(input_dim, input_dim//2),
            nn.ReLU()
            )
        self.fc_mu = nn.Linear(input_dim//2, latent_dim)
        self.fc_logvar = nn.Linear(input_dim//2, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, input_dim//2),
            nn.ReLU(),
            nn.Linear(input_dim//2, input_dim),
            nn.ReLU(),
            nn.Linear(input_dim, input_dim*2),
            nn.ReLU(),
            nn.Linear(input_dim*2, input_dim)
        )

    def encode(self, x):
        h = self.encoder(x)
        return self.fc_mu(h), self.fc_logvar(h)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

def loss_fn(recon_x, x, mu, logvar):
    reconstruction_loss = F.mse_loss(recon_x, x, reduction='sum')
    kl_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return reconstruction_loss + kl_loss

def train(model, optimizer, train_loader, device):
    model.train()
    train_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss = loss_fn(recon_batch, data, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        
        optimizer.step()
        
    return train_loss / len(train_loader.dataset)

def test(model, test_loader, device):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)
            recon_batch, mu, logvar = model(data)
            test_loss += loss_fn(recon_batch, data, mu, logvar).item()
    return test_loss / len(test_loader.dataset)

# %%
input_dim = train2.shape[1]-1
latent_dim = 8
batch_size = 32
num_epochs = 10

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_data = torch.randn(100, input_dim)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
test_data = torch.randn(10, input_dim)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

model = VAE(input_dim, latent_dim).to(device)
optimizer = torch.optim.Adam(model.parameters())

for epoch in range(num_epochs):
    train_loss = train(model, optimizer, train_loader, device)
    test_loss = test(model, test_loader, device)
    print(f"Epoch {epoch}: Train loss = {train_loss}, Test loss = {test_loss}")
# Out:
# Epoch 0: Train loss = 26.811466903686522, Test loss = 25.53804168701172
# Epoch 1: Train loss = 26.729301300048828, Test loss = 25.714266967773437
# Epoch 2: Train loss = 26.62572006225586, Test loss = 25.841311645507812
# Epoch 3: Train loss = 26.589081420898438, Test loss = 25.58756866455078
# Epoch 4: Train loss = 26.556602325439453, Test loss = 25.871975708007813
# Epoch 5: Train loss = 26.488694534301757, Test loss = 25.827731323242187
# Epoch 6: Train loss = 26.453925857543947, Test loss = 25.74207458496094
# Epoch 7: Train loss = 26.453749160766602, Test loss = 25.704693603515626
# Epoch 8: Train loss = 26.398755950927736, Test loss = 25.678756713867188
# Epoch 9: Train loss = 26.38263229370117, Test loss = 25.709365844726562

# %% [markdown]
# ## 3) AE & VAE 학습 및 변수 추가

# %% [markdown]
# ### AutoEncoder

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X = torch.Tensor(train2.drop(columns=['id', 'class']).to_numpy())

# Create a dataset and data loader
dataset = torch.utils.data.TensorDataset(X)
data_loader = torch.utils.data.DataLoader(dataset, batch_size=8, shuffle=True)

# Initialize the model, criterion, and optimizer
encoding_dim = 8
model = Autoencoder(encoding_dim)
criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters())
epochs=1000

# Train the model
ae_train(model, data_loader, criterion, optimizer, device, epochs)
# Out:
# Epoch 0: loss = 0.7983
# Epoch 1: loss = 0.4548
# Epoch 2: loss = 0.2218
# Epoch 3: loss = 0.1937
# Epoch 4: loss = 0.1897
# Epoch 5: loss = 0.1883
# Epoch 6: loss = 0.1867
# Epoch 7: loss = 0.1816
# Epoch 8: loss = 0.1810
# Epoch 9: loss = 0.1801
# Epoch 10: loss = 0.1710
# Epoch 11: loss = 0.1609
# Epoch 12: loss = 0.1461
# Epoch 13: loss = 0.1403
# Epoch 14: loss = 0.1362
# Epoch 15: loss = 0.1347
# Epoch 16: loss = 0.1294
# Epoch 17: loss = 0.1295
# Epoch 18: loss = 0.1280
# Epoch 19: loss = 0.1269
# Epoch 20: loss = 0.1234
# Epoch 21: loss = 0.1187
# Epoch 22: loss = 0.1194
# Epoch 23: loss = 0.1123
# Epoch 24: loss = 0.1069
# Epoch 25: loss = 0.1073
# Epoch 26: loss = 0.1064
# Epoch 27: loss = 0.1000
# Epoch 28: loss = 0.0940
# Epoch 29: loss = 0.0940
# Epoch 30: loss = 0.0941
# Epoch 31: loss = 0.0937
# Epoch 32: loss = 0.0897
# Epoch 33: loss = 0.0900
# Epoch 34: loss = 0.0917
# Epoch 35: loss = 0.0896
# Epoch 36: loss = 0.0895
# Epoch 37: loss = 0.0895
# Epoch 38: loss = 0.0836
# Epoch 39: loss = 0.0840
# Epoch 40: loss = 0.0816
# Epoch 41: loss = 0.0799
# Epoch 42: loss = 0.0801
# Epoch 43: loss = 0.0817
# Epoch 44: loss = 0.0813
# Epoch 45: loss = 0.0763
# Epoch 46: loss = 0.0755
# Epoch 47: loss = 0.0727
# Epoch 48: loss = 0.0771
# Epoch 49: loss = 0.0708
# Epoch 50: loss = 0.0713
# Epoch 51: loss = 0.0711
# Epoch 52: loss = 0.0689
# Epoch 53: loss = 0.0665
# Epoch 54: loss = 0.0649
# Epoch 55: loss = 0.0607
# Epoch 56: loss = 0.0608
# Epoch 57: loss = 0.0594
# Epoch 58: loss = 0.0583
# Epoch 59: loss = 0.0600
# Epoch 60: loss = 0.0569
# Epoch 61: loss = 0.0572
# Epoch 62: loss = 0.0561
# Epoch 63: loss = 0.0543
# Epoch 64: loss = 0.0559
# Epoch 65: loss = 0.0543
# Epoch 66: loss = 0.0542
# Epoch 67: loss = 0.0544
# Epoch 68: loss = 0.0548
# Epoch 69: loss = 0.0532
# Epoch 70: loss = 0.0546
# Epoch 71: loss = 0.0528
# Epoch 72: loss = 0.0511
# Epoch 73: loss = 0.0570
# Epoch 74: loss = 0.0533
# Epoch 75: loss = 0.0520
# Epoch 76: loss = 0.0499
# Epoch 77: loss = 0.0514
# Epoch 78: loss = 0.0491
# Epoch 79: loss = 0.0504
# Epoch 80: loss = 0.0505
# Epoch 81: loss = 0.0486
# Epoch 82: loss = 0.0492
# Epoch 83: loss = 0.0510
# Epoch 84: loss = 0.0495
# Epoch 85: loss = 0.0481
# Epoch 86: loss = 0.0468
# Epoch 87: loss = 0.0474
# Epoch 88: loss = 0.0484
# Epoch 89: loss = 0.0475
# Epoch 90: loss = 0.0469
# Epoch 91: loss = 0.0465
# Epoch 92: loss = 0.0465
# Epoch 93: loss = 0.0468
# Epoch 94: loss = 0.0474
# Epoch 95: loss = 0.0452
# Epoch 96: loss = 0.0441
# Epoch 97: loss = 0.0436
# Epoch 98: loss = 0.0426
# Epoch 99: loss = 0.0469
# Epoch 100: loss = 0.0461
# Epoch 101: loss = 0.0440
# Epoch 102: loss = 0.0439
# Epoch 103: loss = 0.0461
# Epoch 104: loss = 0.0432
# Epoch 105: loss = 0.0417
# Epoch 106: loss = 0.0432
# Epoch 107: loss = 0.0415
# Epoch 108: loss = 0.0434
# Epoch 109: loss = 0.0407
# Epoch 110: loss = 0.0411
# Epoch 111: loss = 0.0401
# Epoch 112: loss = 0.0420
# Epoch 113: loss = 0.0429
# Epoch 114: loss = 0.0413
# Epoch 115: loss = 0.0408
# Epoch 116: loss = 0.0402
# Epoch 117: loss = 0.0400
# Epoch 118: loss = 0.0401
# Epoch 119: loss = 0.0421
# Epoch 120: loss = 0.0411
# Epoch 121: loss = 0.0397
# Epoch 122: loss = 0.0395
# Epoch 123: loss = 0.0390
# Epoch 124: loss = 0.0383
# Epoch 125: loss = 0.0398
# Epoch 126: loss = 0.0401
# Epoch 127: loss = 0.0386
# Epoch 128: loss = 0.0380
# Epoch 129: loss = 0.0391
# Epoch 130: loss = 0.0392
# Epoch 131: loss = 0.0404
# Epoch 132: loss = 0.0375
# Epoch 133: loss = 0.0381
# Epoch 134: loss = 0.0395
# Epoch 135: loss = 0.0414
# Epoch 136: loss = 0.0371
# Epoch 137: loss = 0.0376
# Epoch 138: loss = 0.0384
# Epoch 139: loss = 0.0364
# Epoch 140: loss = 0.0358
# Epoch 141: loss = 0.0389
# Epoch 142: loss = 0.0389
# Epoch 143: loss = 0.0379
# Epoch 144: loss = 0.0357
# Epoch 145: loss = 0.0390
# Epoch 146: loss = 0.0373
# Epoch 147: loss = 0.0352
# Epoch 148: loss = 0.0364
# Epoch 149: loss = 0.0374
# Epoch 150: loss = 0.0349
# Epoch 151: loss = 0.0346
# Epoch 152: loss = 0.0359
# Epoch 153: loss = 0.0355
# Epoch 154: loss = 0.0349
# Epoch 155: loss = 0.0341
# Epoch 156: loss = 0.0338
# Epoch 157: loss = 0.0350
# Epoch 158: loss = 0.0352
# Epoch 159: loss = 0.0336
# Epoch 160: loss = 0.0338
# Epoch 161: loss = 0.0341
# Epoch 162: loss = 0.0370
# Epoch 163: loss = 0.0352
# Epoch 164: loss = 0.0329
# Epoch 165: loss = 0.0318
# Epoch 166: loss = 0.0326
# Epoch 167: loss = 0.0355
# Epoch 168: loss = 0.0353
# Epoch 169: loss = 0.0336
# Epoch 170: loss = 0.0340
# Epoch 171: loss = 0.0329
# Epoch 172: loss = 0.0334
# Epoch 173: loss = 0.0365
# Epoch 174: loss = 0.0347
# Epoch 175: loss = 0.0319
# Epoch 176: loss = 0.0322
# Epoch 177: loss = 0.0321
# Epoch 178: loss = 0.0306
# Epoch 179: loss = 0.0317
# Epoch 180: loss = 0.0306
# Epoch 181: loss = 0.0308
# Epoch 182: loss = 0.0310
# Epoch 183: loss = 0.0311
# Epoch 184: loss = 0.0303
# Epoch 185: loss = 0.0307
# Epoch 186: loss = 0.0302
# Epoch 278: loss = 0.0252
# Epoch 279: loss = 0.0209
# Epoch 280: loss = 0.0201
# Epoch 281: loss = 0.0202
# Epoch 282: loss = 0.0200
# Epoch 283: loss = 0.0201
# Epoch 284: loss = 0.0203
# Epoch 285: loss = 0.0196
# Epoch 286: loss = 0.0195
# Epoch 287: loss = 0.0196
# Epoch 288: loss = 0.0192
# Epoch 289: loss = 0.0197
# Epoch 290: loss = 0.0201
# Epoch 291: loss = 0.0204
# Epoch 292: loss = 0.0202
# Epoch 293: loss = 0.0199
# Epoch 294: loss = 0.0192
# Epoch 295: loss = 0.0183
# Epoch 296: loss = 0.0192
# Epoch 297: loss = 0.0192
# Epoch 298: loss = 0.0193
# Epoch 299: loss = 0.0186
# Epoch 300: loss = 0.0182
# Epoch 301: loss = 0.0186
# Epoch 302: loss = 0.0179
# Epoch 303: loss = 0.0178
# Epoch 304: loss = 0.0176
# Epoch 305: loss = 0.0180
# Epoch 306: loss = 0.0180
# Epoch 307: loss = 0.0187
# Epoch 308: loss = 0.0176
# Epoch 309: loss = 0.0187
# Epoch 310: loss = 0.0188
# Epoch 311: loss = 0.0184
# Epoch 312: loss = 0.0177
# Epoch 313: loss = 0.0194
# Epoch 314: loss = 0.0214
# Epoch 315: loss = 0.0194
# Epoch 316: loss = 0.0178
# Epoch 317: loss = 0.0173
# Epoch 318: loss = 0.0166
# Epoch 319: loss = 0.0180
# Epoch 320: loss = 0.0185
# Epoch 321: loss = 0.0186
# Epoch 322: loss = 0.0195
# Epoch 323: loss = 0.0175
# Epoch 324: loss = 0.0173
# Epoch 325: loss = 0.0168
# Epoch 326: loss = 0.0173
# Epoch 327: loss = 0.0179
# Epoch 328: loss = 0.0170
# Epoch 329: loss = 0.0186
# Epoch 330: loss = 0.0175
# Epoch 331: loss = 0.0185
# Epoch 332: loss = 0.0169
# Epoch 333: loss = 0.0174
# Epoch 334: loss = 0.0178
# Epoch 335: loss = 0.0180
# Epoch 336: loss = 0.0167
# Epoch 337: loss = 0.0166
# Epoch 338: loss = 0.0160
# Epoch 339: loss = 0.0161
# Epoch 340: loss = 0.0170
# Epoch 341: loss = 0.0158
# Epoch 342: loss = 0.0166
# Epoch 343: loss = 0.0167
# Epoch 344: loss = 0.0156
# Epoch 345: loss = 0.0159
# Epoch 346: loss = 0.0156
# Epoch 347: loss = 0.0152
# Epoch 348: loss = 0.0166
# Epoch 349: loss = 0.0160
# Epoch 350: loss = 0.0154
# Epoch 351: loss = 0.0154
# Epoch 352: loss = 0.0150
# Epoch 353: loss = 0.0151
# Epoch 354: loss = 0.0155
# Epoch 355: loss = 0.0156
# Epoch 356: loss = 0.0145
# Epoch 357: loss = 0.0147
# Epoch 358: loss = 0.0159
# Epoch 359: loss = 0.0155
# Epoch 360: loss = 0.0153
# Epoch 361: loss = 0.0150
# Epoch 362: loss = 0.0145
# Epoch 363: loss = 0.0139
# Epoch 364: loss = 0.0143
# Epoch 365: loss = 0.0149
# Epoch 366: loss = 0.0150
# Epoch 367: loss = 0.0138
# Epoch 368: loss = 0.0139
# Epoch 369: loss = 0.0136
# Epoch 370: loss = 0.0142
# Epoch 371: loss = 0.0148
# Epoch 372: loss = 0.0142
# Epoch 373: loss = 0.0141
# Epoch 374: loss = 0.0136
# Epoch 375: loss = 0.0141
# Epoch 376: loss = 0.0141
# Epoch 377: loss = 0.0143
# Epoch 378: loss = 0.0139
# Epoch 379: loss = 0.0134
# Epoch 380: loss = 0.0145
# Epoch 381: loss = 0.0140
# Epoch 382: loss = 0.0136
# Epoch 383: loss = 0.0147
# Epoch 384: loss = 0.0146
# Epoch 385: loss = 0.0134
# Epoch 386: loss = 0.0138
# Epoch 387: loss = 0.0134
# Epoch 388: loss = 0.0129
# Epoch 389: loss = 0.0133
# Epoch 390: loss = 0.0133
# Epoch 391: loss = 0.0134
# Epoch 392: loss = 0.0132
# Epoch 393: loss = 0.0132
# Epoch 394: loss = 0.0134
# Epoch 395: loss = 0.0136
# Epoch 396: loss = 0.0162
# Epoch 397: loss = 0.0139
# Epoch 398: loss = 0.0131
# Epoch 399: loss = 0.0123
# Epoch 400: loss = 0.0129
# Epoch 401: loss = 0.0129
# Epoch 402: loss = 0.0123
# Epoch 403: loss = 0.0128
# Epoch 404: loss = 0.0127
# Epoch 405: loss = 0.0137
# Epoch 406: loss = 0.0127
# Epoch 407: loss = 0.0122
# Epoch 408: loss = 0.0121
# Epoch 409: loss = 0.0132
# Epoch 410: loss = 0.0144
# Epoch 411: loss = 0.0134
# Epoch 412: loss = 0.0128
# Epoch 413: loss = 0.0128
# Epoch 414: loss = 0.0127
# Epoch 415: loss = 0.0121
# Epoch 416: loss = 0.0132
# Epoch 417: loss = 0.0125
# Epoch 418: loss = 0.0117
# Epoch 419: loss = 0.0129
# Epoch 420: loss = 0.0123
# Epoch 421: loss = 0.0122
# Epoch 422: loss = 0.0127
# Epoch 423: loss = 0.0120
# Epoch 424: loss = 0.0117
# Epoch 425: loss = 0.0116
# Epoch 426: loss = 0.0134
# Epoch 427: loss = 0.0135
# Epoch 428: loss = 0.0122
# Epoch 429: loss = 0.0117
# Epoch 430: loss = 0.0122
# Epoch 431: loss = 0.0116
# Epoch 432: loss = 0.0113
# Epoch 433: loss = 0.0116
# Epoch 434: loss = 0.0112
# Epoch 435: loss = 0.0107
# Epoch 436: loss = 0.0118
# Epoch 437: loss = 0.0125
# Epoch 438: loss = 0.0158
# Epoch 439: loss = 0.0126
# Epoch 440: loss = 0.0117
# Epoch 441: loss = 0.0110
# Epoch 442: loss = 0.0125
# Epoch 443: loss = 0.0124
# Epoch 444: loss = 0.0123
# Epoch 445: loss = 0.0120
# Epoch 446: loss = 0.0123
# Epoch 447: loss = 0.0175
# Epoch 448: loss = 0.0135
# Epoch 449: loss = 0.0126
# Epoch 450: loss = 0.0120
# Epoch 451: loss = 0.0117
# Epoch 452: loss = 0.0108
# Epoch 453: loss = 0.0107
# Epoch 454: loss = 0.0122
# Epoch 455: loss = 0.0123
# Epoch 456: loss = 0.0125
# Epoch 457: loss = 0.0117
# Epoch 458: loss = 0.0120
# Epoch 459: loss = 0.0112
# Epoch 460: loss = 0.0108
# Epoch 461: loss = 0.0109
# Epoch 462: loss = 0.0105
# Epoch 463: loss = 0.0105
# Epoch 464: loss = 0.0102
# Epoch 465: loss = 0.0104
# Epoch 466: loss = 0.0104
# Epoch 467: loss = 0.0106
# Epoch 468: loss = 0.0111
# Epoch 469: loss = 0.0108
# Epoch 470: loss = 0.0111
# Epoch 471: loss = 0.0118
# Epoch 472: loss = 0.0116
# Epoch 473: loss = 0.0109
# Epoch 474: loss = 0.0108
# Epoch 475: loss = 0.0103
# Epoch 476: loss = 0.0102
# Epoch 477: loss = 0.0106
# Epoch 478: loss = 0.0100
# Epoch 479: loss = 0.0099
# Epoch 480: loss = 0.0103
# Epoch 481: loss = 0.0101
# Epoch 482: loss = 0.0104
# Epoch 483: loss = 0.0105
# Epoch 484: loss = 0.0110
# Epoch 485: loss = 0.0120
# Epoch 486: loss = 0.0110
# Epoch 487: loss = 0.0111
# Epoch 488: loss = 0.0100
# Epoch 489: loss = 0.0104
# Epoch 490: loss = 0.0113
# Epoch 491: loss = 0.0107
# Epoch 492: loss = 0.0098
# Epoch 493: loss = 0.0097
# Epoch 494: loss = 0.0120
# Epoch 495: loss = 0.0109
# Epoch 496: loss = 0.0104
# Epoch 497: loss = 0.0101
# Epoch 498: loss = 0.0103
# Epoch 499: loss = 0.0101
# Epoch 500: loss = 0.0104
# Epoch 501: loss = 0.0096
# Epoch 502: loss = 0.0104
# Epoch 503: loss = 0.0104
# Epoch 504: loss = 0.0104
# Epoch 505: loss = 0.0108
# Epoch 506: loss = 0.0109
# Epoch 507: loss = 0.0102
# Epoch 508: loss = 0.0098
# Epoch 509: loss = 0.0092
# Epoch 510: loss = 0.0097
# Epoch 511: loss = 0.0093
# Epoch 512: loss = 0.0100
# Epoch 513: loss = 0.0104
# Epoch 514: loss = 0.0094
# Epoch 515: loss = 0.0093
# Epoch 516: loss = 0.0093
# Epoch 517: loss = 0.0095
# Epoch 518: loss = 0.0091
# Epoch 519: loss = 0.0095
# Epoch 520: loss = 0.0090
# Epoch 521: loss = 0.0090
# Epoch 522: loss = 0.0090
# Epoch 523: loss = 0.0100
# Epoch 524: loss = 0.0100
# Epoch 525: loss = 0.0089
# Epoch 526: loss = 0.0094
# Epoch 527: loss = 0.0097
# Epoch 528: loss = 0.0112
# Epoch 529: loss = 0.0109
# Epoch 530: loss = 0.0092
# Epoch 531: loss = 0.0092
# Epoch 532: loss = 0.0091
# Epoch 533: loss = 0.0088
# Epoch 534: loss = 0.0101
# Epoch 535: loss = 0.0092
# Epoch 536: loss = 0.0097
# Epoch 537: loss = 0.0102
# Epoch 538: loss = 0.0085
# Epoch 539: loss = 0.0086
# Epoch 540: loss = 0.0084
# Epoch 541: loss = 0.0084
# Epoch 542: loss = 0.0085
# Epoch 543: loss = 0.0089
# Epoch 544: loss = 0.0098
# Epoch 545: loss = 0.0093
# Epoch 546: loss = 0.0086
# Epoch 547: loss = 0.0089
# Epoch 548: loss = 0.0083
# Epoch 549: loss = 0.0081
# Epoch 550: loss = 0.0083
# Epoch 551: loss = 0.0087
# Epoch 552: loss = 0.0098
# Epoch 553: loss = 0.0089
# Epoch 554: loss = 0.0087
# Epoch 555: loss = 0.0088
# Epoch 556: loss = 0.0090
# Epoch 557: loss = 0.0085
# Epoch 558: loss = 0.0085
# Epoch 559: loss = 0.0086
# Epoch 560: loss = 0.0088
# Epoch 561: loss = 0.0083
# Epoch 562: loss = 0.0083
# Epoch 563: loss = 0.0094
# Epoch 564: loss = 0.0087
# Epoch 565: loss = 0.0088
# Epoch 566: loss = 0.0089
# Epoch 567: loss = 0.0098
# Epoch 568: loss = 0.0103
# Epoch 569: loss = 0.0090
# Epoch 570: loss = 0.0093
# Epoch 571: loss = 0.0090
# Epoch 572: loss = 0.0087
# Epoch 573: loss = 0.0081
# Epoch 574: loss = 0.0092
# Epoch 575: loss = 0.0082
# Epoch 576: loss = 0.0091
# Epoch 577: loss = 0.0090
# Epoch 578: loss = 0.0081
# Epoch 579: loss = 0.0084
# Epoch 580: loss = 0.0086
# Epoch 581: loss = 0.0084
# Epoch 582: loss = 0.0081
# Epoch 583: loss = 0.0075
# Epoch 584: loss = 0.0075
# Epoch 585: loss = 0.0088
# Epoch 586: loss = 0.0084
# Epoch 587: loss = 0.0092
# Epoch 588: loss = 0.0102
# Epoch 589: loss = 0.0095
# Epoch 590: loss = 0.0087
# Epoch 591: loss = 0.0080
# Epoch 592: loss = 0.0075
# Epoch 593: loss = 0.0078
# Epoch 594: loss = 0.0075
# Epoch 595: loss = 0.0074
# Epoch 596: loss = 0.0085
# Epoch 597: loss = 0.0086
# Epoch 598: loss = 0.0075
# Epoch 599: loss = 0.0077
# Epoch 600: loss = 0.0078
# Epoch 601: loss = 0.0080
# Epoch 602: loss = 0.0087
# Epoch 603: loss = 0.0090
# Epoch 604: loss = 0.0091
# Epoch 605: loss = 0.0082
# Epoch 606: loss = 0.0079
# Epoch 607: loss = 0.0077
# Epoch 608: loss = 0.0073
# Epoch 609: loss = 0.0073
# Epoch 610: loss = 0.0100
# Epoch 611: loss = 0.0096
# Epoch 612: loss = 0.0088
# Epoch 613: loss = 0.0081
# Epoch 614: loss = 0.0072
# Epoch 615: loss = 0.0076
# Epoch 616: loss = 0.0071
# Epoch 617: loss = 0.0071
# Epoch 618: loss = 0.0074
# Epoch 619: loss = 0.0077
# Epoch 620: loss = 0.0076
# Epoch 621: loss = 0.0086
# Epoch 622: loss = 0.0082
# Epoch 623: loss = 0.0079
# Epoch 624: loss = 0.0071
# Epoch 625: loss = 0.0072
# Epoch 626: loss = 0.0075
# Epoch 627: loss = 0.0082
# Epoch 628: loss = 0.0077
# Epoch 629: loss = 0.0078
# Epoch 630: loss = 0.0073
# Epoch 631: loss = 0.0069
# Epoch 632: loss = 0.0078
# Epoch 633: loss = 0.0071
# Epoch 634: loss = 0.0067
# Epoch 635: loss = 0.0071
# Epoch 636: loss = 0.0068
# Epoch 637: loss = 0.0074
# Epoch 638: loss = 0.0074
# Epoch 639: loss = 0.0075
# Epoch 640: loss = 0.0075
# Epoch 641: loss = 0.0070
# Epoch 642: loss = 0.0075
# Epoch 643: loss = 0.0079
# Epoch 644: loss = 0.0082
# Epoch 645: loss = 0.0082
# Epoch 646: loss = 0.0072
# Epoch 647: loss = 0.0077
# Epoch 648: loss = 0.0083
# Epoch 649: loss = 0.0069
# Epoch 650: loss = 0.0071
# Epoch 651: loss = 0.0068
# Epoch 652: loss = 0.0064
# Epoch 653: loss = 0.0065
# Epoch 654: loss = 0.0067
# Epoch 655: loss = 0.0067
# Epoch 656: loss = 0.0068
# Epoch 657: loss = 0.0070
# Epoch 658: loss = 0.0074
# Epoch 659: loss = 0.0073
# Epoch 660: loss = 0.0068
# Epoch 661: loss = 0.0065
# Epoch 662: loss = 0.0067
# Epoch 663: loss = 0.0077
# Epoch 664: loss = 0.0075
# Epoch 665: loss = 0.0063
# Epoch 666: loss = 0.0067
# Epoch 667: loss = 0.0064
# Epoch 668: loss = 0.0072
# Epoch 669: loss = 0.0071
# Epoch 670: loss = 0.0096
# Epoch 671: loss = 0.0136
# Epoch 672: loss = 0.0092
# Epoch 673: loss = 0.0084
# Epoch 674: loss = 0.0072
# Epoch 675: loss = 0.0073
# Epoch 676: loss = 0.0072
# Epoch 677: loss = 0.0069
# Epoch 678: loss = 0.0071
# Epoch 679: loss = 0.0068
# Epoch 680: loss = 0.0064
# Epoch 681: loss = 0.0064
# Epoch 682: loss = 0.0065
# Epoch 683: loss = 0.0066
# Epoch 684: loss = 0.0067
# Epoch 685: loss = 0.0061
# Epoch 686: loss = 0.0066
# Epoch 687: loss = 0.0064
# Epoch 688: loss = 0.0064
# Epoch 689: loss = 0.0064
# Epoch 690: loss = 0.0065
# Epoch 691: loss = 0.0061
# Epoch 692: loss = 0.0063
# Epoch 693: loss = 0.0060
# Epoch 694: loss = 0.0059
# Epoch 695: loss = 0.0060
# Epoch 696: loss = 0.0067
# Epoch 697: loss = 0.0071
# Epoch 698: loss = 0.0070
# Epoch 699: loss = 0.0072
# Epoch 700: loss = 0.0110
# Epoch 701: loss = 0.0108
# Epoch 702: loss = 0.0084
# Epoch 703: loss = 0.0068
# Epoch 704: loss = 0.0073
# Epoch 705: loss = 0.0077
# Epoch 706: loss = 0.0106
# Epoch 707: loss = 0.0105
# Epoch 708: loss = 0.0081
# Epoch 709: loss = 0.0067
# Epoch 710: loss = 0.0066
# Epoch 711: loss = 0.0067
# Epoch 712: loss = 0.0065
# Epoch 713: loss = 0.0064
# Epoch 714: loss = 0.0064
# Epoch 715: loss = 0.0065
# Epoch 716: loss = 0.0060
# Epoch 717: loss = 0.0063
# Epoch 718: loss = 0.0068
# Epoch 719: loss = 0.0064
# Epoch 720: loss = 0.0063
# Epoch 721: loss = 0.0070
# Epoch 722: loss = 0.0063
# Epoch 723: loss = 0.0062
# Epoch 724: loss = 0.0069
# Epoch 725: loss = 0.0067
# Epoch 726: loss = 0.0073
# Epoch 727: loss = 0.0061
# Epoch 728: loss = 0.0058
# Epoch 729: loss = 0.0059
# Epoch 730: loss = 0.0069
# Epoch 731: loss = 0.0063
# Epoch 732: loss = 0.0066
# Epoch 823: loss = 0.0061
# Epoch 824: loss = 0.0066
# Epoch 825: loss = 0.0058
# Epoch 826: loss = 0.0070
# Epoch 827: loss = 0.0073
# Epoch 828: loss = 0.0064
# Epoch 829: loss = 0.0061
# Epoch 830: loss = 0.0052
# Epoch 831: loss = 0.0053
# Epoch 832: loss = 0.0068
# Epoch 833: loss = 0.0067
# Epoch 834: loss = 0.0068
# Epoch 835: loss = 0.0071
# Epoch 836: loss = 0.0064
# Epoch 837: loss = 0.0061
# Epoch 838: loss = 0.0053
# Epoch 839: loss = 0.0053
# Epoch 840: loss = 0.0054
# Epoch 841: loss = 0.0056
# Epoch 842: loss = 0.0060
# Epoch 843: loss = 0.0056
# Epoch 844: loss = 0.0055
# Epoch 845: loss = 0.0053
# Epoch 846: loss = 0.0063
# Epoch 847: loss = 0.0063
# Epoch 848: loss = 0.0072
# Epoch 849: loss = 0.0063
# Epoch 850: loss = 0.0061
# Epoch 851: loss = 0.0053
# Epoch 852: loss = 0.0058
# Epoch 853: loss = 0.0136
# Epoch 854: loss = 0.0094
# Epoch 855: loss = 0.0062
# Epoch 856: loss = 0.0057
# Epoch 857: loss = 0.0051
# Epoch 858: loss = 0.0051
# Epoch 859: loss = 0.0051
# Epoch 860: loss = 0.0059
# Epoch 861: loss = 0.0057
# Epoch 862: loss = 0.0052
# Epoch 863: loss = 0.0056
# Epoch 864: loss = 0.0057
# Epoch 865: loss = 0.0051
# Epoch 866: loss = 0.0050
# Epoch 867: loss = 0.0048
# Epoch 868: loss = 0.0046
# Epoch 869: loss = 0.0047
# Epoch 870: loss = 0.0051
# Epoch 871: loss = 0.0048
# Epoch 872: loss = 0.0050
# Epoch 873: loss = 0.0052
# Epoch 874: loss = 0.0050
# Epoch 875: loss = 0.0054
# Epoch 876: loss = 0.0051
# Epoch 877: loss = 0.0047
# Epoch 878: loss = 0.0056
# Epoch 879: loss = 0.0050
# Epoch 880: loss = 0.0052
# Epoch 881: loss = 0.0051
# Epoch 882: loss = 0.0047
# Epoch 883: loss = 0.0050
# Epoch 884: loss = 0.0054
# Epoch 885: loss = 0.0050
# Epoch 886: loss = 0.0050
# Epoch 887: loss = 0.0046
# Epoch 888: loss = 0.0048
# Epoch 889: loss = 0.0053
# Epoch 890: loss = 0.0060
# Epoch 891: loss = 0.0069
# Epoch 892: loss = 0.0065
# Epoch 893: loss = 0.0059
# Epoch 894: loss = 0.0061
# Epoch 895: loss = 0.0060
# Epoch 896: loss = 0.0056
# Epoch 897: loss = 0.0049
# Epoch 898: loss = 0.0057
# Epoch 899: loss = 0.0059
# Epoch 900: loss = 0.0057
# Epoch 901: loss = 0.0053
# Epoch 902: loss = 0.0049
# Epoch 903: loss = 0.0052
# Epoch 904: loss = 0.0051
# Epoch 905: loss = 0.0055
# Epoch 906: loss = 0.0058
# Epoch 907: loss = 0.0055
# Epoch 908: loss = 0.0050
# Epoch 909: loss = 0.0047
# Epoch 910: loss = 0.0045
# Epoch 911: loss = 0.0048
# Epoch 912: loss = 0.0053
# Epoch 913: loss = 0.0060
# Epoch 914: loss = 0.0067
# Epoch 915: loss = 0.0060
# Epoch 916: loss = 0.0054
# Epoch 917: loss = 0.0060
# Epoch 918: loss = 0.0064
# Epoch 919: loss = 0.0060
# Epoch 920: loss = 0.0053
# Epoch 921: loss = 0.0050
# Epoch 922: loss = 0.0047
# Epoch 923: loss = 0.0047
# Epoch 924: loss = 0.0049
# Epoch 925: loss = 0.0045
# Epoch 926: loss = 0.0049
# Epoch 927: loss = 0.0065
# Epoch 928: loss = 0.0055
# Epoch 929: loss = 0.0046
# Epoch 930: loss = 0.0047
# Epoch 931: loss = 0.0054
# Epoch 932: loss = 0.0052
# Epoch 933: loss = 0.0053
# Epoch 934: loss = 0.0054
# Epoch 935: loss = 0.0052
# Epoch 936: loss = 0.0049
# Epoch 937: loss = 0.0047
# Epoch 938: loss = 0.0055
# Epoch 939: loss = 0.0060
# Epoch 940: loss = 0.0050
# Epoch 941: loss = 0.0060
# Epoch 942: loss = 0.0059
# Epoch 943: loss = 0.0054
# Epoch 944: loss = 0.0052
# Epoch 945: loss = 0.0050
# Epoch 946: loss = 0.0043
# Epoch 947: loss = 0.0042
# Epoch 948: loss = 0.0044
# Epoch 949: loss = 0.0044
# Epoch 950: loss = 0.0045
# Epoch 951: loss = 0.0048
# Epoch 952: loss = 0.0051
# Epoch 953: loss = 0.0054
# Epoch 954: loss = 0.0049
# Epoch 955: loss = 0.0043
# Epoch 956: loss = 0.0046
# Epoch 957: loss = 0.0049
# Epoch 958: loss = 0.0058
# Epoch 959: loss = 0.0053
# Epoch 960: loss = 0.0045
# Epoch 961: loss = 0.0048
# Epoch 962: loss = 0.0047
# Epoch 963: loss = 0.0048
# Epoch 964: loss = 0.0047
# Epoch 965: loss = 0.0054
# Epoch 966: loss = 0.0053
# Epoch 967: loss = 0.0047
# Epoch 968: loss = 0.0049
# Epoch 969: loss = 0.0049
# Epoch 970: loss = 0.0057
# Epoch 971: loss = 0.0067
# Epoch 972: loss = 0.0054
# Epoch 973: loss = 0.0057
# Epoch 974: loss = 0.0055
# Epoch 975: loss = 0.0053
# Epoch 976: loss = 0.0053
# Epoch 977: loss = 0.0051
# Epoch 978: loss = 0.0064
# Epoch 979: loss = 0.0050
# Epoch 980: loss = 0.0048
# Epoch 981: loss = 0.0057
# Epoch 982: loss = 0.0050
# Epoch 983: loss = 0.0050
# Epoch 984: loss = 0.0056
# Epoch 985: loss = 0.0056
# Epoch 986: loss = 0.0054
# Epoch 987: loss = 0.0048
# Epoch 988: loss = 0.0048
# Epoch 989: loss = 0.0051
# Epoch 990: loss = 0.0059
# Epoch 991: loss = 0.0059
# Epoch 992: loss = 0.0066
# Epoch 993: loss = 0.0071
# Epoch 994: loss = 0.0060
# Epoch 995: loss = 0.0054
# Epoch 996: loss = 0.0048
# Epoch 997: loss = 0.0042
# Epoch 998: loss = 0.0043
# Epoch 999: loss = 0.0042

# %%
X1 = X.to(device)
X2 = torch.Tensor(test2.drop(columns=['id']).to_numpy()).to(device)

pred_train = model(X1)
pred_test = model(X2)

# reconstruction error
loss_train = []
loss_test = []

for i in range(len(X1)) :
    loss = criterion(pred_train[1][i], X1[i]).detach().cpu().numpy()
    loss_train.append(loss)
for j in range(len(X2)) :
    loss = criterion(pred_test[1][j], X2[j]).detach().cpu().numpy()
    loss_test.append(loss)

# encoding values
enco_train = pred_train[0].detach().cpu().numpy()
enco_test = pred_test[0].detach().cpu().numpy()

trainLoss = pd.DataFrame(data=loss_train, columns=['ae_loss'])
testLoss = pd.DataFrame(data=loss_test, columns=['ae_loss'])

ae_train = pd.DataFrame(data=enco_train, columns=['ae_'+str(x) for x in range(enco_train.shape[1])])
ae_test = pd.DataFrame(data=enco_test, columns=['ae_'+str(x) for x in range(enco_train.shape[1])])

train3 = pd.concat([train2, trainLoss, ae_train], axis=1)
test3 = pd.concat([test2, testLoss, ae_test], axis=1)

train3.info(), test3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 37 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            193 non-null    object
#  1   SNP_01        193 non-null    int64
#  2   SNP_02        193 non-null    int64
#  3   SNP_03        193 non-null    int64
#  4   SNP_04        193 non-null    int64
#  5   SNP_05        193 non-null    int64
#  6   SNP_06        193 non-null    int64
#  7   SNP_08        193 non-null    int64
#  8   SNP_10        193 non-null    int64
#  9   SNP_11        193 non-null    int64
#  10  SNP_12        193 non-null    int64
#  11  SNP_13        193 non-null    int64
#  12  SNP_14        193 non-null    int64
#  13  SNP_15        193 non-null    int64
#  14  class         193 non-null    object
#  15  SNP_01_ratio  193 non-null    float64
#  16  SNP_02_ratio  193 non-null    float64
#  17  SNP_03_ratio  193 non-null    float64
#  18  SNP_04_ratio  193 non-null    float64
#  19  SNP_05_ratio  193 non-null    float64
#  20  SNP_06_ratio  193 non-null    float64
#  21  SNP_08_ratio  193 non-null    float64
#  22  SNP_10_ratio  193 non-null    float64
#  23  SNP_11_ratio  193 non-null    float64
#  24  SNP_12_ratio  193 non-null    float64
#  25  SNP_13_ratio  193 non-null    float64
#  26  SNP_14_ratio  193 non-null    float64
#  27  SNP_15_ratio  193 non-null    float64
#  28  ae_loss       193 non-null    float32
#  29  ae_0          193 non-null    float32
#  30  ae_1          193 non-null    float32
#  31  ae_2          193 non-null    float32
#  32  ae_3          193 non-null    float32
#  33  ae_4          193 non-null    float32
#  34  ae_5          193 non-null    float32
#  35  ae_6          193 non-null    float32
#  36  ae_7          193 non-null    float32
# dtypes: float32(9), float64(13), int64(13), object(2)
# memory usage: 49.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 36 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            130 non-null    object
#  1   SNP_01        130 non-null    int64
#  2   SNP_02        130 non-null    int64
#  3   SNP_03        130 non-null    int64
#  4   SNP_04        130 non-null    int64
#  5   SNP_05        130 non-null    int64
#  6   SNP_06        130 non-null    int64
#  7   SNP_08        130 non-null    int64
#  8   SNP_10        130 non-null    int64
#  9   SNP_11        130 non-null    int64
#  10  SNP_12        130 non-null    int64
#  11  SNP_13        130 non-null    int64
#  12  SNP_14        130 non-null    int64
#  13  SNP_15        130 non-null    int64
#  14  SNP_01_ratio  130 non-null    float64
#  15  SNP_02_ratio  130 non-null    float64
#  16  SNP_03_ratio  130 non-null    float64
#  17  SNP_04_ratio  130 non-null    float64
#  18  SNP_05_ratio  130 non-null    float64
#  19  SNP_06_ratio  130 non-null    float64
#  20  SNP_08_ratio  130 non-null    float64
#  21  SNP_10_ratio  130 non-null    float64
#  22  SNP_11_ratio  130 non-null    float64
#  23  SNP_12_ratio  130 non-null    float64
#  24  SNP_13_ratio  130 non-null    float64
#  25  SNP_14_ratio  130 non-null    float64
#  26  SNP_15_ratio  130 non-null    float64
#  27  ae_loss       130 non-null    float32
#  28  ae_0          130 non-null    float32
#  29  ae_1          130 non-null    float32
#  30  ae_2          130 non-null    float32
#  31  ae_3          130 non-null    float32
#  32  ae_4          130 non-null    float32
#  33  ae_5          130 non-null    float32
#  34  ae_6          130 non-null    float32
#  35  ae_7          130 non-null    float32
# dtypes: float32(9), float64(13), int64(13), object(1)
# memory usage: 32.1+ KB
# (None, None)

# %% [markdown]
# ### Variational AutoEncoder

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X = torch.Tensor(train2.drop(columns=['id', 'class']).to_numpy())

input_dim = X.shape[1]
latent_dim = 8
batch_size = 32
num_epochs = 1000

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_data = X
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_data = X
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

model = VAE(input_dim, latent_dim).to(device)
optimizer = torch.optim.Adam(model.parameters())

for epoch in range(num_epochs):
    train_loss = train(model, optimizer, train_loader, device)
    test_loss = test(model, test_loader, device)
    print(f"Epoch {epoch}: Train loss = {train_loss}, Test loss = {test_loss}")
# Out:
# Epoch 0: Train loss = 23.727877241342178, Test loss = 22.580428978322082
# Epoch 1: Train loss = 21.924934426737572, Test loss = 20.800747569978547
# Epoch 2: Train loss = 20.12178102305516, Test loss = 18.702853800719264
# Epoch 3: Train loss = 17.56872311527865, Test loss = 15.712776999399452
# Epoch 4: Train loss = 14.462522862488742, Test loss = 12.564648939537879
# Epoch 5: Train loss = 11.421667983494892, Test loss = 10.033523984523635
# Epoch 6: Train loss = 9.656345917153235, Test loss = 8.732481744005272
# Epoch 7: Train loss = 8.501931331318277, Test loss = 7.944884749891845
# Epoch 8: Train loss = 7.832404487491272, Test loss = 6.967996528111591
# Epoch 9: Train loss = 7.018926067055816, Test loss = 7.021194781664122
# Epoch 10: Train loss = 6.841889574120081, Test loss = 6.661000785432331
# Epoch 11: Train loss = 6.446276911799772, Test loss = 6.420134371426439
# Epoch 12: Train loss = 6.34838374785191, Test loss = 6.18799270867066
# Epoch 13: Train loss = 6.227492269456695, Test loss = 6.248046699583222
# Epoch 14: Train loss = 6.053100296870414, Test loss = 6.009281788465272
# Epoch 15: Train loss = 6.073664435450895, Test loss = 6.124984795565433
# Epoch 16: Train loss = 6.164060617357956, Test loss = 6.1215083413791165
# Epoch 17: Train loss = 6.000570262651987, Test loss = 6.0087116246396395
# Epoch 18: Train loss = 6.073980180710708, Test loss = 6.059183580270085
# Epoch 19: Train loss = 6.034738863070394, Test loss = 5.926722311602973
# Epoch 20: Train loss = 6.016867899524115, Test loss = 5.914241988424193
# Epoch 21: Train loss = 5.998831479660588, Test loss = 5.98649213968781
# Epoch 22: Train loss = 5.92948244519802, Test loss = 5.892467738433205
# Epoch 23: Train loss = 5.98219654597149, Test loss = 6.027249163296556
X1 = X.to(device)
X2 = torch.Tensor(test2.drop(columns=['id']).to_numpy()).to(device)

pred_train = model(X1)
pred_test = model(X2)

# reconstruction error
loss_train = []
loss_test = []

for i in range(len(X1)) :
    loss = criterion(pred_train[0][i], X1[i]).detach().cpu().numpy()
    loss_train.append(loss)
for j in range(len(X2)) :
    loss = criterion(pred_test[0][j], X2[j]).detach().cpu().numpy()
    loss_test.append(loss)

# encoding values
enco_train = pred_train[1].detach().cpu().numpy()
enco_test = pred_test[1].detach().cpu().numpy()

trainLoss = pd.DataFrame(data=loss_train, columns=['vae_loss'])
testLoss = pd.DataFrame(data=loss_test, columns=['vae_loss'])

ae_train = pd.DataFrame(data=enco_train, columns=['vae_'+str(x) for x in range(enco_train.shape[1])])
ae_test = pd.DataFrame(data=enco_test, columns=['vae_'+str(x) for x in range(enco_train.shape[1])])

train4 = pd.concat([train3, trainLoss, ae_train], axis=1)
test4 = pd.concat([test3, testLoss, ae_test], axis=1)

train4.info(), test4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 46 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            193 non-null    object
#  1   SNP_01        193 non-null    int64
#  2   SNP_02        193 non-null    int64
#  3   SNP_03        193 non-null    int64
#  4   SNP_04        193 non-null    int64
#  5   SNP_05        193 non-null    int64
#  6   SNP_06        193 non-null    int64
#  7   SNP_08        193 non-null    int64
#  8   SNP_10        193 non-null    int64
#  9   SNP_11        193 non-null    int64
#  10  SNP_12        193 non-null    int64
#  11  SNP_13        193 non-null    int64
#  12  SNP_14        193 non-null    int64
#  13  SNP_15        193 non-null    int64
#  14  class         193 non-null    object
#  15  SNP_01_ratio  193 non-null    float64
#  16  SNP_02_ratio  193 non-null    float64
#  17  SNP_03_ratio  193 non-null    float64
#  18  SNP_04_ratio  193 non-null    float64
#  19  SNP_05_ratio  193 non-null    float64
#  20  SNP_06_ratio  193 non-null    float64
#  21  SNP_08_ratio  193 non-null    float64
#  22  SNP_10_ratio  193 non-null    float64
#  23  SNP_11_ratio  193 non-null    float64
#  24  SNP_12_ratio  193 non-null    float64
#  25  SNP_13_ratio  193 non-null    float64
#  26  SNP_14_ratio  193 non-null    float64
#  27  SNP_15_ratio  193 non-null    float64
#  28  ae_loss       193 non-null    float32
#  29  ae_0          193 non-null    float32
#  30  ae_1          193 non-null    float32
#  31  ae_2          193 non-null    float32
#  32  ae_3          193 non-null    float32
#  33  ae_4          193 non-null    float32
#  34  ae_5          193 non-null    float32
#  35  ae_6          193 non-null    float32
#  36  ae_7          193 non-null    float32
#  37  vae_loss      193 non-null    float32
#  38  vae_0         193 non-null    float32
#  39  vae_1         193 non-null    float32
#  40  vae_2         193 non-null    float32
#  41  vae_3         193 non-null    float32
#  42  vae_4         193 non-null    float32
#  43  vae_5         193 non-null    float32
#  44  vae_6         193 non-null    float32
#  45  vae_7         193 non-null    float32
# dtypes: float32(18), float64(13), int64(13), object(2)
# memory usage: 55.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 45 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            130 non-null    object
#  1   SNP_01        130 non-null    int64
#  2   SNP_02        130 non-null    int64
#  3   SNP_03        130 non-null    int64
#  4   SNP_04        130 non-null    int64
#  5   SNP_05        130 non-null    int64
#  6   SNP_06        130 non-null    int64
#  7   SNP_08        130 non-null    int64
#  8   SNP_10        130 non-null    int64
#  9   SNP_11        130 non-null    int64
#  10  SNP_12        130 non-null    int64
#  11  SNP_13        130 non-null    int64
#  12  SNP_14        130 non-null    int64
#  13  SNP_15        130 non-null    int64
#  14  SNP_01_ratio  130 non-null    float64
#  15  SNP_02_ratio  130 non-null    float64
#  16  SNP_03_ratio  130 non-null    float64
#  17  SNP_04_ratio  130 non-null    float64
#  18  SNP_05_ratio  130 non-null    float64
#  19  SNP_06_ratio  130 non-null    float64
#  20  SNP_08_ratio  130 non-null    float64
#  21  SNP_10_ratio  130 non-null    float64
#  22  SNP_11_ratio  130 non-null    float64
#  23  SNP_12_ratio  130 non-null    float64
#  24  SNP_13_ratio  130 non-null    float64
#  25  SNP_14_ratio  130 non-null    float64
#  26  SNP_15_ratio  130 non-null    float64
#  27  ae_loss       130 non-null    float32
#  28  ae_0          130 non-null    float32
#  29  ae_1          130 non-null    float32
#  30  ae_2          130 non-null    float32
#  31  ae_3          130 non-null    float32
#  32  ae_4          130 non-null    float32
#  33  ae_5          130 non-null    float32
#  34  ae_6          130 non-null    float32
#  35  ae_7          130 non-null    float32
#  36  vae_loss      130 non-null    float32
#  37  vae_0         130 non-null    float32
#  38  vae_1         130 non-null    float32
#  39  vae_2         130 non-null    float32
#  40  vae_3         130 non-null    float32
#  41  vae_4         130 non-null    float32
#  42  vae_5         130 non-null    float32
#  43  vae_6         130 non-null    float32
#  44  vae_7         130 non-null    float32
# dtypes: float32(18), float64(13), int64(13), object(1)
# memory usage: 36.7+ KB
# (None, None)

# %% [markdown]
# ### Summary 02
# - Target Labeling을 통해 15개의 파생변수를 생성
# - AE와 VAE를 통해 encoding한 값 8개와 reconstruction error 1개를 각기 추가해, 18개의 파생변수를 생성
# - 총 33개의 파생변수가 추가되어 49개의 변수를 이용해 B와 C를 구분

# %%
train4.to_csv("./data/train44.csv", index=False)
test4.to_csv("./data/test44.csv", index=False)

# %% [markdown]
# ## Categorical Features
# - 전체 변수들을 CATEGORY 타입으로 변환

# %%
train = pd.read_csv("./data/train44.csv")
test = pd.read_csv("./data/test44.csv")
train.iloc[:, 1:14] = train.iloc[:, 1:14].astype('category')
test.iloc[:, 1:14] = test.iloc[:, 1:14].astype('category')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 46 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            193 non-null    object
#  1   SNP_01        193 non-null    category
#  2   SNP_02        193 non-null    category
#  3   SNP_03        193 non-null    category
#  4   SNP_04        193 non-null    category
#  5   SNP_05        193 non-null    category
#  6   SNP_06        193 non-null    category
#  7   SNP_08        193 non-null    category
#  8   SNP_10        193 non-null    category
#  9   SNP_11        193 non-null    category
#  10  SNP_12        193 non-null    category
#  11  SNP_13        193 non-null    category
#  12  SNP_14        193 non-null    category
#  13  SNP_15        193 non-null    category
#  14  class         193 non-null    object
#  15  SNP_01_ratio  193 non-null    float64
#  16  SNP_02_ratio  193 non-null    float64
#  17  SNP_03_ratio  193 non-null    float64
#  18  SNP_04_ratio  193 non-null    float64
#  19  SNP_05_ratio  193 non-null    float64
#  20  SNP_06_ratio  193 non-null    float64
#  21  SNP_08_ratio  193 non-null    float64
#  22  SNP_10_ratio  193 non-null    float64
#  23  SNP_11_ratio  193 non-null    float64
#  24  SNP_12_ratio  193 non-null    float64
#  25  SNP_13_ratio  193 non-null    float64
#  26  SNP_14_ratio  193 non-null    float64
#  27  SNP_15_ratio  193 non-null    float64
#  28  ae_loss       193 non-null    float64
#  29  ae_0          193 non-null    float64
#  30  ae_1          193 non-null    float64
#  31  ae_2          193 non-null    float64
#  32  ae_3          193 non-null    float64
#  33  ae_4          193 non-null    float64
#  34  ae_5          193 non-null    float64
#  35  ae_6          193 non-null    float64
#  36  ae_7          193 non-null    float64
#  37  vae_loss      193 non-null    float64
#  38  vae_0         193 non-null    float64
#  39  vae_1         193 non-null    float64
#  40  vae_2         193 non-null    float64
#  41  vae_3         193 non-null    float64
#  42  vae_4         193 non-null    float64
#  43  vae_5         193 non-null    float64
#  44  vae_6         193 non-null    float64
#  45  vae_7         193 non-null    float64
# dtypes: category(13), float64(31), object(2)
# memory usage: 54.0+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 45 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            130 non-null    object
#  1   SNP_01        130 non-null    category
#  2   SNP_02        130 non-null    category
#  3   SNP_03        130 non-null    category
#  4   SNP_04        130 non-null    category
#  5   SNP_05        130 non-null    category
#  6   SNP_06        130 non-null    category
#  7   SNP_08        130 non-null    category
#  8   SNP_10        130 non-null    category
#  9   SNP_11        130 non-null    category
#  10  SNP_12        130 non-null    category
#  11  SNP_13        130 non-null    category
#  12  SNP_14        130 non-null    category
#  13  SNP_15        130 non-null    category
#  14  SNP_01_ratio  130 non-null    float64
#  15  SNP_02_ratio  130 non-null    float64
#  16  SNP_03_ratio  130 non-null    float64
#  17  SNP_04_ratio  130 non-null    float64
#  18  SNP_05_ratio  130 non-null    float64
#  19  SNP_06_ratio  130 non-null    float64
#  20  SNP_08_ratio  130 non-null    float64
#  21  SNP_10_ratio  130 non-null    float64
#  22  SNP_11_ratio  130 non-null    float64
#  23  SNP_12_ratio  130 non-null    float64
#  24  SNP_13_ratio  130 non-null    float64
#  25  SNP_14_ratio  130 non-null    float64
#  26  SNP_15_ratio  130 non-null    float64
#  27  ae_loss       130 non-null    float64
#  28  ae_0          130 non-null    float64
#  29  ae_1          130 non-null    float64
#  30  ae_2          130 non-null    float64
#  31  ae_3          130 non-null    float64
#  32  ae_4          130 non-null    float64
#  33  ae_5          130 non-null    float64
#  34  ae_6          130 non-null    float64
#  35  ae_7          130 non-null    float64
#  36  vae_loss      130 non-null    float64
#  37  vae_0         130 non-null    float64
#  38  vae_1         130 non-null    float64
#  39  vae_2         130 non-null    float64
#  40  vae_3         130 non-null    float64
#  41  vae_4         130 non-null    float64
#  42  vae_5         130 non-null    float64
#  43  vae_6         130 non-null    float64
#  44  vae_7         130 non-null    float64
# dtypes: category(13), float64(31), object(1)
# memory usage: 36.0+ KB

# %% [markdown]
# # STEP 02. MODELING & VALIDATION
# - 데이터 증강여부에 따른 성능향상 유무를 확인
# - Classifier와 Regressor를 동시에 사용해 자체적인 ensemble 효과 추가 고려

# %% [markdown]
# ## without Aug

# %%
import warnings
warnings.filterwarnings(action='ignore')

import os
import gc
import math
import random
import pickle
import pandas as pd
import numpy as np
from tqdm.auto import tqdm

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split, StratifiedKFold

from xgboost import XGBClassifier, XGBRegressor
from catboost import CatBoostClassifier, CatBoostRegressor
from imblearn.over_sampling import SMOTE, SMOTENC, SMOTEN

# %%
X, y = train.drop(columns=['id', 'class']), (train['class'].values == 'B').astype(int)

strategy = {0:1000, 1:1000}
smote = SMOTENC(categorical_features=[x for x in range(16)], sampling_strategy=strategy)
X2, y2 = smote.fit_resample(X, y)
X_test = test.drop(columns=['id'])
X2
# Out:
#      SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_08 SNP_10 SNP_11 SNP_12  \
# 0         2      1      0      1      1      0      2      2      1      0
# 1         1      1      1      0      0      1      1      1      0      1
# 2         2      2      0      1      2      2      1      1      0      0
# 3         2      2      2      0      2      0      0      2      0      0
# 4         2      2      1      0      2      0      1      2      0      0
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1995      2      1      1      0      2      1      2      2      1      1
# 1996      2      1      1      1      2      1      1      2      1      0
# 1997      2      2      1      1      2      1      2      2      0      0
# 1998      2      1      1      0      2      1      0      2      1      0
# 1999      2      1      1      0      2      1      2      2      1      0
#
#       ...      ae_7  vae_loss     vae_0     vae_1     vae_2     vae_3  \
# 0     ...  5.486553  0.159097  0.026900  0.013049  0.013923  0.033346
# 1     ...  2.338903  0.116361 -0.019236 -0.014687 -0.008318  0.005216
# 2     ...  1.768928  0.247609  0.009370 -0.001504 -0.000892 -0.003537
# 3     ...  0.339235  0.252251  0.017040  0.011551 -0.009094  0.002984
# 4     ...  2.536202  0.152769  0.010032  0.001370  0.002682 -0.001705
# ...   ...       ...       ...       ...       ...       ...       ...
# 1995  ...  6.495145  0.111825 -0.003409 -0.016987  0.009645  0.002217
# 1996  ...  4.159630  0.075199  0.006012 -0.001055  0.006392 -0.002621
# 1997  ...  4.411622  0.100652  0.006155 -0.004872  0.012770 -0.000462
# 1998  ...  5.485061  0.153012  0.019608  0.007032  0.002611  0.011005
# 1999  ...  4.369602  0.172797  0.020075  0.008519  0.000783  0.012203
#
#          vae_4     vae_5     vae_6     vae_7
# 0    -0.003520  0.019434  0.021099 -0.485469
# 1    -0.012849  0.009623  0.006137  0.787507
# 2     0.012318 -0.038352  0.048411 -0.931604
# 3     0.004547 -0.016042  0.015548 -0.531253
# 4     0.008241 -0.018646  0.002630 -0.752838
# ...        ...       ...       ...       ...
# 1995  0.000824  0.000554 -0.012569 -0.053378
# 1996  0.010449 -0.022174  0.008716 -0.915039
# 1997  0.011297 -0.015483 -0.001564 -0.901721
# 1998  0.009639 -0.004662  0.017610 -0.533441
# 1999  0.007284 -0.007422  0.026952 -0.545697
#
# [2000 rows x 44 columns]

# %%
y2
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
X_test
# Out:
#     SNP_01 SNP_02 SNP_03 SNP_04 SNP_05 SNP_06 SNP_08 SNP_10 SNP_11 SNP_12  \
# 0        2      1      2      2      2      0      0      2      1      0
# 1        2      1      0      0      1      1      0      1      0      1
# 2        2      1      1      0      2      0      0      2      0      1
# 3        2      1      1      0      1      0      1      2      2      0
# 4        0      1      1      0      1      1      0      1      1      1
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 125      1      2      2      0      1      1      2      2      2      0
# 126      2      0      0      0      1      1      0      1      0      0
# 127      2      0      0      0      1      1      0      2      1      0
# 128      1      2      1      1      2      2      1      2      1      0
# 129      2      2      2      1      1      0      2      2      2      0
#
#      ...      ae_7  vae_loss     vae_0     vae_1     vae_2     vae_3  \
# 0    ...  4.125077  0.259566  0.007233  0.000595  0.004058  0.001307
# 1    ...  0.291936  0.179799  0.005518  0.003180 -0.014739 -0.000426
# 2    ...  2.690188  0.193094  0.023213  0.009246  0.000727  0.014192
# 3    ...  7.017147  0.169372  0.013033 -0.000339 -0.001256  0.008897
# 4    ...  3.536815  0.297773  0.028503  0.033139 -0.017028 -0.007630
# ..   ...       ...       ...       ...       ...       ...       ...
# 125  ...  7.183743  0.310557  0.005143  0.002828 -0.001291 -0.006450
# 126  ...  0.695514  0.083908  0.005572 -0.004586 -0.011555 -0.000225
# 127  ...  3.456507  0.257170  0.011699  0.001440 -0.015009 -0.006651
# 128  ...  4.759387  0.149449 -0.001189 -0.005570  0.003619 -0.012381
# 129  ...  6.922738  0.209637  0.004803 -0.001117  0.012798  0.000772
#
#         vae_4     vae_5     vae_6     vae_7
# 0    0.006137 -0.016166  0.006052 -0.829781
# 1   -0.009431  0.000003  0.008960  1.387121
# 2    0.000707  0.001943  0.010248 -0.156940
# 3    0.001023 -0.001493  0.005045 -0.240011
# 4    0.010288  0.000265 -0.009831  1.565095
# ..        ...       ...       ...       ...
# 125  0.003664 -0.021391 -0.010427 -0.808265
# 126 -0.008561 -0.004601  0.020345  1.381729
# 127  0.002078 -0.006705 -0.005611  0.888649
# 128  0.009763 -0.039792  0.015342 -1.128698
# 129  0.009558 -0.008425 -0.014825 -0.889432
#
# [130 rows x 44 columns]

# %%
def catgbmc(inputX, inputY, validX, validY, params) :  
    var_categ = inputX.columns.tolist()[:13]
    model = CatBoostClassifier(
        cat_features=var_categ,
        **params,
        task_type='GPU',
        devices='0',
        # l2_leaf_reg=10
        # random_state=random_seed
        )
  
    model.fit(
        inputX, inputY,
        eval_set=(inputX, inputY),
        );     

    pred = model.predict(validX)
    score = f1_score(validY, pred, average='macro')
    print(score)
    
    return model

# %%
def catgbmr(inputX, inputY, validX, validY, params) :  
    var_categ = inputX.columns.tolist()[:13]
    model = CatBoostRegressor(
        cat_features=var_categ,
        **params,
        task_type='GPU',
        devices='0',
        # l2_leaf_reg=10
        # random_state=random_seed
        )
  
    model.fit(
        inputX, inputY,
        eval_set=(inputX, inputY),
        );     

    pred = model.predict(validX)
    score = f1_score(validY, np.round(pred), average='macro')
    print(score)
    
    return model

# %%
params = {'iterations':300,
          'learning_rate':0.03,
          # 'l2_leaf_reg' : 10,
        #   'auto_class_weights' : 'Balanced',
          # 'grow_policy' : 'Depthwise',
          'verbose':0}

model3 = catgbmc(X2, y2, X, y, params)
model4 = catgbmc(X, y, X, y,params)
# Out:
# 1.0
# 1.0

# %%
pd.DataFrame(data=model3.get_feature_importance(), index=model3.feature_names_, columns=['feature_importance']).sort_values('feature_importance', ascending=False)
# Out:
#               feature_importance
# vae_7                  37.267535
# ae_2                    9.938607
# vae_2                   9.817353
# ae_5                    3.289630
# SNP_04                  3.067442
# ae_6                    2.802314
# SNP_15                  2.773697
# SNP_02_ratio            2.495930
# SNP_04_ratio            2.244201
# SNP_10_ratio            2.190313
# SNP_08_ratio            1.906094
# SNP_08                  1.797885
# SNP_15_ratio            1.785751
# ae_7                    1.771340
# vae_loss                1.485606
# SNP_05                  1.352757
# ae_4                    1.253236
# ae_1                    1.016686
# ae_3                    0.974999
# SNP_03_ratio            0.949812
# ae_0                    0.945450
# vae_3                   0.892081
# vae_6                   0.793844
# SNP_14_ratio            0.675762
# SNP_13_ratio            0.615942
# SNP_01_ratio            0.612443
# vae_1                   0.563424
# SNP_06_ratio            0.500839
# SNP_03                  0.499624
# vae_4                   0.487823
# ae_loss                 0.482501
# vae_5                   0.442378
# SNP_05_ratio            0.428317
# SNP_10                  0.428155
# vae_0                   0.358165
# SNP_02                  0.286487
# SNP_11                  0.283179
# SNP_11_ratio            0.178657
# SNP_06                  0.168314
# SNP_12_ratio            0.060151
# SNP_01                  0.058876
# SNP_12                  0.030247
# SNP_13                  0.026153
# SNP_14                  0.000000

# %%
pd.DataFrame(data=model4.get_feature_importance(), index=model4.feature_names_, columns=['feature_importance']).sort_values('feature_importance', ascending=False)
# Out:
#               feature_importance
# vae_7                  42.077305
# vae_2                   7.498149
# ae_5                    6.934725
# ae_2                    3.908171
# SNP_15_ratio            2.420094
# SNP_05_ratio            2.357751
# ae_1                    2.082757
# SNP_04_ratio            2.023048
# SNP_08_ratio            1.969687
# ae_3                    1.700320
# SNP_12_ratio            1.528710
# SNP_02_ratio            1.515257
# vae_3                   1.396031
# ae_7                    1.374829
# ae_6                    1.351204
# SNP_04                  1.276458
# SNP_03_ratio            1.239440
# SNP_10_ratio            1.233179
# ae_loss                 1.219924
# ae_0                    1.127081
# SNP_15                  0.982988
# SNP_06_ratio            0.912868
# vae_0                   0.899547
# vae_6                   0.887516
# SNP_11_ratio            0.828887
# vae_5                   0.808463
# SNP_12                  0.783238
# vae_1                   0.733591
# SNP_01                  0.700155
# ae_4                    0.676759
# vae_loss                0.649657
# vae_4                   0.519619
# SNP_03                  0.511809
# SNP_14_ratio            0.474959
# SNP_05                  0.463608
# SNP_08                  0.443327
# SNP_11                  0.384093
# SNP_01_ratio            0.361429
# SNP_14                  0.343328
# SNP_13                  0.331138
# SNP_02                  0.275337
# SNP_10                  0.274860
# SNP_13_ratio            0.268628
# SNP_06                  0.250073

# %%
total = pd.DataFrame()

test00 = pd.read_csv("./data/test.csv")
X_test1 = test00.drop(columns=['id', 'father', 'mother', 'gender', 'trait','SNP_06'])
X_test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SNP_01  175 non-null    object
#  1   SNP_02  175 non-null    object
#  2   SNP_03  175 non-null    object
#  3   SNP_04  175 non-null    object
#  4   SNP_05  175 non-null    object
#  5   SNP_07  175 non-null    object
#  6   SNP_08  175 non-null    object
#  7   SNP_09  175 non-null    object
#  8   SNP_10  175 non-null    object
#  9   SNP_11  175 non-null    object
#  10  SNP_12  175 non-null    object
#  11  SNP_13  175 non-null    object
#  12  SNP_14  175 non-null    object
#  13  SNP_15  175 non-null    object
# dtypes: object(14)
# memory usage: 19.3+ KB

# %%
total['pred1'] = (model1.predict_proba(X_test1)[:,1] > 0.97).astype(int)
pred2 = model3.predict_proba(X_test)[:,1]
pred3 = model4.predict_proba(X_test)[:,1]
total['pred2'] = 0
total['pred3'] = 0

total.loc[total.pred1==0, 'pred2'] = pred2
total.loc[total.pred1==0, 'pred3'] = pred3
total
# Out:
#      pred1     pred2     pred3
# 0        1  0.000000  0.000000
# 1        0  0.999828  0.996950
# 2        0  0.000463  0.007232
# 3        0  0.995427  0.967965
# 4        1  0.000000  0.000000
# ..     ...       ...       ...
# 170      0  0.997832  0.994602
# 171      0  0.000279  0.003781
# 172      0  0.003883  0.017411
# 173      0  0.999792  0.998398
# 174      0  0.999863  0.998490
#
# [175 rows x 3 columns]

# %%
total[(total.pred2 >= 0.7) & (total.pred3 < 0.7)]
# Out:
# Empty DataFrame
# Columns: [pred1, pred2, pred3]
# Index: []

# %%
total[(total.pred2 < 0.7) & (total.pred3 >= 0.7)]
# Out:
#      pred1     pred2     pred3
# 162      0  0.262244  0.936088

# %%
total['answer1'] = total['pred1'].map(lambda x : 'A' if x==1 else 'D')
total['answer2'] = total['pred1'].map(lambda x : 'A' if x==1 else 'D')
total['answer3'] = total['pred1'].map(lambda x : 'A' if x==1 else 'D')

total.loc[total.answer1=='D', 'answer1'] = (pred2 > 0.9).astype(int)
total.loc[total.answer2=='D', 'answer2'] = (pred3 > 0.9).astype(int)
total.loc[total.answer3=='D', 'answer3'] = (np.mean([pred2, pred3], axis=0) > 0.9).astype(int)

total['answer1'] = total['answer1'].map(lambda x : 'A' if x=='A' else ('B' if x==1 else ('C' if x==0 else 'D')))
total['answer2'] = total['answer2'].map(lambda x : 'A' if x=='A' else ('B' if x==1 else ('C' if x==0 else 'D')))
total['answer3'] = total['answer3'].map(lambda x : 'A' if x=='A' else ('B' if x==1 else ('C' if x==0 else 'D')))

total.answer1.value_counts()
# Out:
# B    84
# C    46
# A    45
# Name: answer1, dtype: int64

# %%
total.answer2.value_counts()
# Out:
# B    85
# A    45
# C    45
# Name: answer2, dtype: int64

# %%
total.answer3.value_counts()
# Out:
# B    83
# C    47
# A    45
# Name: answer3, dtype: int64

# %%
total.iloc[[3,5,12,119,126,162,168]]
# Out:
#      pred1     pred2     pred3 answer1 answer2 answer3
# 3        0  0.995427  0.967965       B       B       B
# 5        0  0.994140  0.976174       B       B       B
# 12       0  0.134592  0.228385       C       C       C
# 119      0  0.159007  0.501302       C       C       C
# 126      0  0.987937  0.989209       B       B       B
# 162      0  0.262244  0.936088       C       B       C
# 168      0  0.990872  0.987864       B       B       B

# %%
submit = pd.read_csv("./data/sample_submission.csv")
submit['class'] = total['answer3']
submit['class'].value_counts()
submit.to_csv("./submit.csv", index=False)
